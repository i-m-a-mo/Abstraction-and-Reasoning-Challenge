# %%
import numpy as np
import pandas as pd
import random 
from random import randint
import time

import os
import json
from pathlib import Path

import tensorflow.keras as keras
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras import layers
#from tensorflow.keras.datasets import mnist
from tensorflow.keras import backend as K
#from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt
from matplotlib import colors

# %%
data_path = Path('./kaggle_input/')
training_path = data_path / 'training'      # 400 X-train ('train'), y-train('test') input-output pairs
evaluation_path = data_path / 'evaluation'  # 400
test_path = data_path / 'test'              # 100 pairs X-train ('train') (input-output),
                                            #           y-train (input only) pairs

training_tasks_files = sorted(os.listdir(training_path))#[1:]
eval_tasks_files = sorted(os.listdir(evaluation_path))
test_task_files = sorted(os.listdir(test_path))

# %%
training_tasks_files[40]
# Out:
# '22168020.json'

# %%
def load_files(path):
    path_files = sorted(os.listdir(path))
    tasks = []
    for task_file in path_files:
        with open(str(path / task_file), 'r') as f:
            task = json.load(f)
            tasks.append(task)
    return tasks

# %%
training_tasks = load_files(training_path)          ### this is for building / training the algorithm
test_tasks = load_files(test_path)                  ### this is the input for the actual prediction!!!
evaluation_tasks = load_files(evaluation_path)      ### testing the algorithm

# %%
len(training_tasks), training_tasks[0]['test']
# Out:
# (400,
#  [{'input': [[7, 0, 7], [7, 0, 7], [7, 7, 0]],
#    'output': [[7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 7, 0, 0, 0, 0, 7, 7, 0],
#     [7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 7, 0, 0, 0, 0, 7, 7, 0],
#     [7, 0, 7, 7, 0, 7, 0, 0, 0],
#     [7, 0, 7, 7, 0, 7, 0, 0, 0],
#     [7, 7, 0, 7, 7, 0, 0, 0, 0]]}])

# %%
len(evaluation_tasks), evaluation_tasks[0]['test']
# Out:
# (400,
#  [{'input': [[3, 2], [7, 8]],
#    'output': [[3, 2, 3, 2, 3, 2],
#     [7, 8, 7, 8, 7, 8],
#     [2, 3, 2, 3, 2, 3],
#     [8, 7, 8, 7, 8, 7],
#     [3, 2, 3, 2, 3, 2],
#     [7, 8, 7, 8, 7, 8]]}])

# %%
len(test_tasks),test_tasks[0]['test']
# Out:
# (100, [{'input': [[3, 2], [7, 8]]}])

# %% [markdown]
#
#  ---
#  ---

# %% [markdown]
# ### 1. Create Train - Test - Split

# %%
def tts(input_list):
    Xs_test, ys_test, Xs_train, ys_train = [], [], [], []

    for task in input_list:
        X_test, y_test, X_train, y_train = [], [], [], []

        for pair in task["test"]:
            X_test.append(pair["input"])
            y_test.append(pair["output"])      ### to be predicted !!!

        for pair in task["train"]:
            X_train.append(pair["input"])
            y_train.append(pair["output"])

        Xs_test.append(X_test)
        ys_test.append(y_test)
        Xs_train.append(X_train)
        ys_train.append(y_train)
    return Xs_test, ys_test, Xs_train, ys_train

# %% [markdown]
#
# #### Create origanl sized Train-Test-Split for reference

# %%
Xs_test_orig, ys_test_orig, Xs_train_orig, ys_train_orig = tts(training_tasks)

# %%
len(Xs_train_orig), len(ys_train_orig), len(Xs_test_orig), len(ys_test_orig)
# Out:
# (400, 400, 400, 400)

# %%
len(Xs_train_orig[1]), len(ys_train_orig[1]), len(Xs_test_orig[1]), len(ys_test_orig[1])
# Out:
# (5, 5, 1, 1)

# %% [markdown]
#
# #### Create actual Train-Test-Split

# %%
Xs_test, ys_test, Xs_train, ys_train = tts(training_tasks)

# %%
len(Xs_train), len(ys_train), len(Xs_test), len(ys_test)
# Out:
# (400, 400, 400, 400)

# %%
len(Xs_train[1]), len(ys_train[1]), len(Xs_test[1]), len(ys_test[1])
# Out:
# (5, 5, 1, 1)

# %%
len(Xs_test[8][0]),len(Xs_test[8][0][0])
# Out:
# (26, 26)

# %%
len(ys_test[8][0]),len(ys_test[8][0][0])
# Out:
# (26, 26)

# %% [markdown]
# ## Data Augmentation of the training data

# %%
#### color
def color_change(arr):
    x = arr*3
#     x = x/(x.max()+0.1)
    x = np.interp(x, (0.3, 2.7), (0, 0.9))
    x = np.ndarray.round(x,1)
    return x

# %%
def augm(X_list, y_list):
    idx = 1
    X_list_new = []
    y_list_new = []
    
    for task_X, task_y in zip(X_list, y_list):
        task_li_x = []
        task_li_y = []
        print("TASK",idx)
        length = len(Xs_train_orig[idx-1])
#         print(length)
        max_li=[]
        for i in range(length):
            max_a = max(len(task_X[i]),len(task_X[i][0]))
            max_b = max(len(task_y[i]),len(task_y[i][0]))
            max_c = max(len(Xs_test[idx-1][0]),len(Xs_test[idx-1][0][0]))
            max_d = max(len(ys_test[idx-1][0]),len(ys_test[idx-1][0][0]))
            max_abcd = max(max_a,max_b, max_c, max_d)
            max_li.append(max_abcd)
#             print(f"max_a = max({len(task_X[i])},{len(task_X[i][0])})")
#             print(f"max_b = max({len(task_y[i])},{len(task_y[i][0])})")
#             print(max_int)
        max_int = max(max_li)
            
        for e_x,e_y in zip(task_X, task_y):
            e_x = (np.array(e_x))/10.     
            e_y = (np.array(e_y))/10.
#             print(e_x.shape,e_y.shape, max_int)
            e_x = np.pad(e_x, [(0, max_int-e_x.shape[0]), (0, max_int-e_x.shape[1])], mode='constant')
            e_y = np.pad(e_y, [(0, max_int-e_y.shape[0]), (0, max_int-e_y.shape[1])], mode='constant')
#             print(e_x.shape,e_y.shape, max_int, "\n")
            task_li_x.append(e_x.reshape(e_x.shape + (1,) ))
            task_li_y.append(e_y.reshape(e_y.shape + (1,) ))
        # ========================
         
        while len(task_li_x) < 50*length:    ###################
#             print(len(task_li_x))
            """
            choose a random method and append new array
            """
            i = randint(0,length-1) 
            new_x = (np.array(task_X[i]))/10.
#             print((new_x))
            new_y = (np.array(task_y[i]))/10.
            
            
            times = randint(1,5)
#             print(f"LENGTH: {len(task_X)} // INDEX: {i} // TIMES: {times}" )
            for j in range(times):
                
                method = random.choice([np.fliplr, np.flipud, np.rot90])#,color_change])
                new_x = method(new_x)
                new_y = method(new_y)

            new_x = np.pad(new_x, [(0, max_int-new_x.shape[0]), (0, max_int-new_x.shape[1])], mode='constant')

            new_y = np.pad(new_y, [(0, max_int-new_y.shape[0]), (0, max_int-new_y.shape[1])], mode='constant')

            
            task_li_x.append(new_x.reshape(new_x.shape + (1,) ))
            task_li_y.append(new_y.reshape(new_y.shape + (1,) ))
 
        X_list_new.append(np.array(task_li_x))
        y_list_new.append(np.array(task_li_y))

        idx +=1
    return     X_list_new, y_list_new

# %%
# TASK 216
# TASK 217
# TASK 218
# TASK 219
# TASK 220
# TASK 221
# TASK 222
# TASK 223
# TASK 224
# TASK 225
# TASK 226
# TASK 227
# TASK 228
# TASK 229
# TASK 230
# TASK 231
# TASK 232
# TASK 233
# TASK 234
# TASK 235
# TASK 236
# TASK 237
# TASK 238
# TASK 239
# TASK 240
# TASK 241
# TASK 242
# TASK 243
# TASK 244
# TASK 245
# TASK 246
# TASK 247
# TASK 248
# TASK 249
# TASK 250
# TASK 251
# TASK 252
# TASK 253
# TASK 254
# TASK 255
# TASK 256
# TASK 257
# TASK 258
# TASK 259
# TASK 260
# TASK 261
# TASK 262
# TASK 263
# TASK 264
# TASK 265
# TASK 266
# TASK 267
# TASK 268
# TASK 269
# TASK 270
# TASK 271
# TASK 272
# TASK 273
# TASK 274
# TASK 275
# TASK 276
# TASK 277
# TASK 278
# TASK 279
# TASK 280
# TASK 281
# TASK 282
# TASK 283
# TASK 284
# TASK 285
# TASK 286
# TASK 287
# TASK 288
# TASK 289
# TASK 290
# TASK 291
# TASK 292
# TASK 293
# TASK 294
# TASK 295
# TASK 296
# TASK 297
# TASK 298
# TASK 299
# TASK 300
# TASK 301
# TASK 302
# TASK 303
# TASK 304
# TASK 305
# TASK 306
# TASK 307
# TASK 308
# TASK 309
# TASK 310
# TASK 311
# TASK 312
# TASK 313
# TASK 314
# TASK 315
# TASK 316
# TASK 317
# TASK 318
# TASK 319
# TASK 320
# TASK 321
# TASK 322
# TASK 323
# TASK 324
# TASK 325
# TASK 326
# TASK 327
# TASK 328
# TASK 329
# TASK 330
# TASK 331
# TASK 332
# TASK 333
# TASK 334
# TASK 335
# TASK 336
# TASK 337
# TASK 338
# TASK 339
# TASK 340
# TASK 341
# TASK 342
# TASK 343
# TASK 344
# TASK 345
# TASK 346
# TASK 347
# TASK 348
# TASK 349
# TASK 350
# TASK 351
# TASK 352
# TASK 353
# TASK 354
# TASK 355
# TASK 356
# TASK 357
# TASK 358
# TASK 359
# TASK 360
# TASK 361
# TASK 362
# TASK 363
# TASK 364
# TASK 365
# TASK 366
# TASK 367
# TASK 368
# TASK 369
# TASK 370
# TASK 371
# TASK 372
# TASK 373
# TASK 374
# TASK 375
# TASK 376
# TASK 377
# TASK 378
# TASK 379
# TASK 380
# TASK 381
# TASK 382
# TASK 383
# TASK 384
# TASK 385
# TASK 386
# TASK 387
# TASK 388
# TASK 389
# TASK 390
# TASK 391
# TASK 392
# TASK 393
# TASK 394
# TASK 395
# TASK 396
# TASK 397
# TASK 398
# TASK 399
# TASK 400

# %%
type(Xs_train_aug),len(Xs_train_aug)   ### number of Tasks
# Out:
# (list, 400)

# %%
type(Xs_train_aug[0]),len(Xs_train_aug[0]) ### number of sets
# Out:
# (numpy.ndarray, 250)

# %%
type(Xs_train_aug[0][0]),Xs_train_aug[0][0].shape ### number of inputs (pairs)
# Out:
# (numpy.ndarray, (9, 9, 1))

# %% [markdown]
# #### format test data

# %%
def t2l(X_list, y_list):
    li_x =[]
    li_y =[]
    idx = 0
    for task_x, task_y in zip(X_list, y_list):
#         print("TASK", idx)
        task_x_arr = np.array(task_x)
        task_y_arr = np.array(task_y)
        li2_x = []
        li2_y = []
#         j = 0
        for e_x, e_y in zip(task_x_arr, task_y_arr):
            e_x = np.array(e_x)
            e_y = np.array(e_y)
            max_train = Xs_train_aug[idx].shape[1]
            max_int = max(max(e_x.shape),max(e_y.shape),max_train)
#             j+=1
            
            e_x = np.pad(e_x, [(0, max_int-e_x.shape[0]), (0, max_int-e_x.shape[1])], mode='constant')
            e_x = e_x / 10.
            e_x = e_x.reshape(e_x.shape + (1,) )
#             print(e_x.shape, e_y.shape, max_int)
            e_y = np.pad(e_y, [(0, max_int-e_y.shape[0]), (0, max_int-e_y.shape[1])], mode='constant')
            e_y = e_y / 10.
            e_y = e_y.reshape(e_y.shape + (1,) )
#             print(e_x.shape, e_y.shape, "\n")
            li2_x.append(e_x)
            li2_y.append(e_y)

#         lenght = len(Xs_train_aug[idx])
        
#         li_x.append([np.array(li2_x)])
#         li_y.append([np.array(li2_y)])
        
        li_x.append(np.array(li2_x))
        li_y.append(np.array(li2_y))
        idx += 1
    return li_x, li_y

# %%
Xs_test_aug, ys_test_aug = t2l(Xs_test, ys_test)
# Out:
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   import sys
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:35: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
type(Xs_train_aug), type(ys_train_aug),type(Xs_test_aug), type(ys_test_aug)
# Out:
# (list, list, list, list)

# %%
len(Xs_train_aug), len(ys_train_aug),len(Xs_test_aug), len(ys_test_aug)
# Out:
# (400, 400, 400, 400)

# %%
type(Xs_train_aug[0]), type(ys_train_aug[0]),type(Xs_test_aug[0]), type(ys_test_aug[0])
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
len(Xs_train_aug[0]), len(ys_train_aug[0]),len(Xs_test_aug[0]), len(ys_test_aug[0])
# Out:
# (250, 250, 1, 1)

# %%
Xs_train_aug[3].shape, ys_train_aug[3].shape,Xs_test_aug[3].shape, ys_test_aug[3].shape
# Out:
# ((100, 14, 14, 1), (100, 14, 14, 1), (1, 14, 14, 1), (1, 14, 14, 1))

# %%
type(Xs_train_aug[0][0]), type(ys_train_aug[0][0]),type(Xs_test_aug[0][0]), type(ys_test_aug[0][0])
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
Xs_train_aug[2][2].shape, ys_train_aug[2][2].shape, Xs_test_aug[2][0].shape, ys_test_aug[2][0].shape
# Out:
# ((9, 9, 1), (9, 9, 1), (9, 9, 1), (9, 9, 1))

# %% [markdown]
# ## Model comp

# %%
class Autoencoder(Model):
    def __init__(self, latent_dim, inp_shape, outp_shape, flat_shape):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.inp_shape = inp_shape
        self.outp_shape = outp_shape
        self.flat_shape = flat_shape
        
        
        self.encoder = Sequential([
            layers.Conv2D(160, (3, 3), activation='relu', padding='same', input_shape = inp_shape), #### 
            layers.MaxPooling2D((2, 2), padding='same'),
            layers.Conv2D(320, (3, 3), activation='relu', padding='same'),
            layers.MaxPooling2D((2, 2), padding='same'),
            layers.Flatten(),
            layers.Dense(latent_dim, activation='relu'),
        ])
        self.decoder = Sequential([
            layers.Dense(flat_shape, activation='sigmoid'),
            layers.Reshape(outp_shape),
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
K.clear_session()  
latent_dim = 50 
idx = 0
pred_train_li = []
pred_test_li = []
#start = time.time()

for X_train, y_train, X_test, y_test in zip(Xs_train_aug, ys_train_aug, Xs_test_aug, ys_test_aug):
    K.clear_session()  
    print(f"TASK {idx}")
    set_no = 0


    ### get input and output shapes to pass to the model
    inp_shape = X_train[0].shape
#         print('in', inp_shape)
    outp_shape = y_train[0].shape#[0]*y_set_train[0].shape[1]
#         print('out',outp_shape)
    flat_shape = outp_shape[0]*outp_shape[1]
#         print('flat',flat_shape)   
    
    verb = 0
    if idx%20 == 0: verb=1
    
    K.clear_session() 
    base_model = Autoencoder(latent_dim, inp_shape, outp_shape, flat_shape)

    base_model.compile(optimizer='adam', 
                              loss='mean_squared_error',
                              metrics=['accuracy'])

    callback = keras.callbacks.EarlyStopping(monitor='accuracy',
                                                 patience=5)

    base_model.fit(X_train, y_train,
                          epochs=100,
                          batch_size=5000,
                          #shuffle=True,
                          verbose=verb,
                          callbacks=[callback])#,
#                           validation_data=(X_set_test, y_set_test))        
#     print(np.array(X_test[idx]).shape)
#     print(np.array(X_test[:1]).shape)
    encoded_imgs_train = base_model.encoder(X_train[:1]).numpy()
    decoded_imgs_train = base_model.decoder(encoded_imgs_train).numpy()

    pred_train = (decoded_imgs_train.reshape(outp_shape[0:2]))*10
    
    encoded_imgs_test = base_model.encoder(Xs_test_aug[idx][:1]).numpy()
    decoded_imgs_test = base_model.decoder(encoded_imgs_test).numpy()

    pred_test = (decoded_imgs_test.reshape(outp_shape[0:2]))*10
    
    pred_train_li.append(pred_train)
    pred_test_li.append(pred_test)
        
    idx += 1

end = time.time()
 
print("Total time: " + str(np.round(end - start, 1)) + " s" + "\n")
# Out:
# TASK 0
# Epoch 1/100
# 1/1 [==============================] - 1s 618ms/step - loss: 0.1902 - accuracy: 0.4030
# Epoch 2/100
# 1/1 [==============================] - 0s 130ms/step - loss: 0.1889 - accuracy: 0.5598
# Epoch 3/100
# 1/1 [==============================] - 0s 133ms/step - loss: 0.1871 - accuracy: 0.5919
# Epoch 4/100
# 1/1 [==============================] - 0s 124ms/step - loss: 0.1847 - accuracy: 0.6104
# Epoch 5/100
# 1/1 [==============================] - 0s 143ms/step - loss: 0.1814 - accuracy: 0.6164
# Epoch 6/100
# 1/1 [==============================] - 0s 129ms/step - loss: 0.1768 - accuracy: 0.6201
# Epoch 7/100
# 1/1 [==============================] - 0s 127ms/step - loss: 0.1707 - accuracy: 0.6218
# Epoch 8/100
# 1/1 [==============================] - 0s 129ms/step - loss: 0.1630 - accuracy: 0.6315
# Epoch 9/100
# 1/1 [==============================] - 0s 120ms/step - loss: 0.1538 - accuracy: 0.6362
# Epoch 10/100
# 1/1 [==============================] - 0s 164ms/step - loss: 0.1437 - accuracy: 0.6356
# Epoch 11/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.1336 - accuracy: 0.6426
# Epoch 12/100
# 1/1 [==============================] - 0s 111ms/step - loss: 0.1240 - accuracy: 0.6478
# Epoch 13/100
# 1/1 [==============================] - 0s 100ms/step - loss: 0.1156 - accuracy: 0.6638
# Epoch 14/100
# 1/1 [==============================] - 0s 125ms/step - loss: 0.1086 - accuracy: 0.6681
# Epoch 15/100
# 1/1 [==============================] - 0s 102ms/step - loss: 0.1033 - accuracy: 0.6681
# Epoch 16/100
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0992 - accuracy: 0.6734
# Epoch 17/100
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0957 - accuracy: 0.6734
# Epoch 18/100
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0919 - accuracy: 0.6765
# Epoch 19/100
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0879 - accuracy: 0.6893
# Epoch 20/100
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0846 - accuracy: 0.7091
# Epoch 21/100
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0830 - accuracy: 0.7091
# Epoch 22/100
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0826 - accuracy: 0.7091
# Epoch 23/100
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0824 - accuracy: 0.7091
# Epoch 24/100
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0823 - accuracy: 0.7091
# Epoch 25/100
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0821 - accuracy: 0.7091
# TASK 1
# TASK 2
# TASK 3
# TASK 4
# TASK 5
# TASK 6
# TASK 7
# TASK 8
# TASK 9
# TASK 10
# TASK 11
# TASK 12
# TASK 13
# TASK 14
# TASK 15
# TASK 16
# TASK 17
# TASK 18
# TASK 19
# TASK 20
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2459 - accuracy: 0.4840
# Epoch 2/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2447 - accuracy: 0.6030
# Epoch 3/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2420 - accuracy: 0.6219
# Epoch 4/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2357 - accuracy: 0.6454
# Epoch 5/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2238 - accuracy: 0.6678
# Epoch 6/100
# 1/1 [==============================] - 1s 916ms/step - loss: 0.2059 - accuracy: 0.6906
# Epoch 7/100
# 1/1 [==============================] - 1s 908ms/step - loss: 0.1855 - accuracy: 0.7105
# Epoch 8/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1676 - accuracy: 0.7350
# Epoch 9/100
# 1/1 [==============================] - 1s 948ms/step - loss: 0.1523 - accuracy: 0.7664
# Epoch 10/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1382 - accuracy: 0.7958
# Epoch 11/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1249 - accuracy: 0.8199
# Epoch 12/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1122 - accuracy: 0.8374
# Epoch 13/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1000 - accuracy: 0.8569
# Epoch 14/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0878 - accuracy: 0.8671
# Epoch 15/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0753 - accuracy: 0.8780
# Epoch 16/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0632 - accuracy: 0.8980
# Epoch 17/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0527 - accuracy: 0.9148
# Epoch 18/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0442 - accuracy: 0.9283
# Epoch 19/100
# 1/1 [==============================] - 1s 913ms/step - loss: 0.0374 - accuracy: 0.9378
# Epoch 20/100
# 1/1 [==============================] - 1s 942ms/step - loss: 0.0316 - accuracy: 0.9422
# Epoch 21/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0265 - accuracy: 0.9488
# Epoch 22/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0221 - accuracy: 0.9559
# Epoch 23/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0183 - accuracy: 0.9587
# Epoch 24/100
# 1/1 [==============================] - 1s 906ms/step - loss: 0.0150 - accuracy: 0.9636
# Epoch 25/100
# 1/1 [==============================] - 1s 921ms/step - loss: 0.0122 - accuracy: 0.9660
# Epoch 26/100
# 1/1 [==============================] - 1s 909ms/step - loss: 0.0102 - accuracy: 0.9692
# Epoch 27/100
# 1/1 [==============================] - 1s 999ms/step - loss: 0.0087 - accuracy: 0.9719
# Epoch 28/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0076 - accuracy: 0.9723
# Epoch 29/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0067 - accuracy: 0.9732
# Epoch 30/100
# 1/1 [==============================] - 1s 978ms/step - loss: 0.0059 - accuracy: 0.9737
# Epoch 31/100
# 1/1 [==============================] - 1s 932ms/step - loss: 0.0053 - accuracy: 0.9751
# Epoch 32/100
# 1/1 [==============================] - 1s 915ms/step - loss: 0.0048 - accuracy: 0.9751
# Epoch 33/100
# 1/1 [==============================] - 1s 891ms/step - loss: 0.0044 - accuracy: 0.9765
# Epoch 34/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0041 - accuracy: 0.9765
# Epoch 35/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0038 - accuracy: 0.9765
# Epoch 36/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0036 - accuracy: 0.9765
# Epoch 37/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0033 - accuracy: 0.9765
# Epoch 38/100
# 1/1 [==============================] - 1s 973ms/step - loss: 0.0030 - accuracy: 0.9773
# Epoch 39/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0028 - accuracy: 0.9778
# Epoch 40/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0028 - accuracy: 0.9778
# Epoch 41/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0027 - accuracy: 0.9778
# Epoch 42/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0027 - accuracy: 0.9778
# Epoch 43/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0027 - accuracy: 0.9778
# Epoch 44/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0026 - accuracy: 0.9778
# TASK 21
# TASK 22
# TASK 23
# TASK 24
# TASK 25
# TASK 26
# TASK 27
# TASK 28
# TASK 29
# TASK 30
# TASK 31
# TASK 32
# TASK 33
# TASK 34
# TASK 35
# TASK 36
# TASK 37
# TASK 38
# TASK 39
# TASK 40
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1960 - accuracy: 0.3637
# Epoch 2/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1936 - accuracy: 0.4809
# Epoch 3/100
# 1/1 [==============================] - 0s 124ms/step - loss: 0.1903 - accuracy: 0.5009
# Epoch 4/100
# 1/1 [==============================] - 0s 115ms/step - loss: 0.1858 - accuracy: 0.5180
# Epoch 5/100
# 1/1 [==============================] - 0s 129ms/step - loss: 0.1799 - accuracy: 0.5332
# Epoch 6/100
# 1/1 [==============================] - 0s 118ms/step - loss: 0.1730 - accuracy: 0.5336
# Epoch 7/100
# 1/1 [==============================] - 0s 129ms/step - loss: 0.1657 - accuracy: 0.5383
# Epoch 8/100
# 1/1 [==============================] - 0s 108ms/step - loss: 0.1587 - accuracy: 0.5457
# Epoch 9/100
# 1/1 [==============================] - 0s 135ms/step - loss: 0.1519 - accuracy: 0.5523
# Epoch 10/100
# 1/1 [==============================] - 0s 110ms/step - loss: 0.1459 - accuracy: 0.5527
# Epoch 11/100
# 1/1 [==============================] - 0s 137ms/step - loss: 0.1404 - accuracy: 0.5595
# Epoch 12/100
# 1/1 [==============================] - 0s 104ms/step - loss: 0.1355 - accuracy: 0.5780
# Epoch 13/100
# 1/1 [==============================] - 0s 105ms/step - loss: 0.1305 - accuracy: 0.5908
# Epoch 14/100
# 1/1 [==============================] - 0s 123ms/step - loss: 0.1254 - accuracy: 0.6052
# Epoch 15/100
# 1/1 [==============================] - 0s 267ms/step - loss: 0.1201 - accuracy: 0.6171
# Epoch 16/100
# 1/1 [==============================] - 0s 153ms/step - loss: 0.1154 - accuracy: 0.6258
# Epoch 17/100
# 1/1 [==============================] - 0s 226ms/step - loss: 0.1107 - accuracy: 0.6373
# Epoch 18/100
# 1/1 [==============================] - 0s 137ms/step - loss: 0.1058 - accuracy: 0.6443
# Epoch 19/100
# 1/1 [==============================] - 0s 147ms/step - loss: 0.1007 - accuracy: 0.6534
# Epoch 20/100
# 1/1 [==============================] - 0s 205ms/step - loss: 0.0956 - accuracy: 0.6685
# Epoch 21/100
# 1/1 [==============================] - 0s 179ms/step - loss: 0.0908 - accuracy: 0.6815
# Epoch 22/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.0865 - accuracy: 0.6892
# Epoch 23/100
# 1/1 [==============================] - 0s 169ms/step - loss: 0.0829 - accuracy: 0.6967
# Epoch 24/100
# 1/1 [==============================] - 0s 189ms/step - loss: 0.0801 - accuracy: 0.6992
# Epoch 25/100
# 1/1 [==============================] - 0s 155ms/step - loss: 0.0780 - accuracy: 0.7004
# Epoch 26/100
# 1/1 [==============================] - 0s 192ms/step - loss: 0.0765 - accuracy: 0.7016
# Epoch 27/100
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0756 - accuracy: 0.7022
# Epoch 28/100
# 1/1 [==============================] - 0s 196ms/step - loss: 0.0749 - accuracy: 0.7022
# Epoch 29/100
# 1/1 [==============================] - 0s 176ms/step - loss: 0.0744 - accuracy: 0.7016
# Epoch 30/100
# 1/1 [==============================] - 0s 162ms/step - loss: 0.0737 - accuracy: 0.7014
# Epoch 31/100
# 1/1 [==============================] - 0s 195ms/step - loss: 0.0728 - accuracy: 0.7008
# Epoch 32/100
# 1/1 [==============================] - 0s 137ms/step - loss: 0.0715 - accuracy: 0.7005
# TASK 41
# TASK 42
# TASK 43
# TASK 44
# TASK 45
# TASK 46
# TASK 47
# TASK 48
# TASK 49
# TASK 50
# TASK 51
# TASK 52
# TASK 53
# TASK 54
# TASK 55
# TASK 56
# TASK 57
# TASK 58
# TASK 59
# TASK 60
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.0781 - accuracy: 0.0000e+00
# Epoch 2/100
# 1/1 [==============================] - 1s 814ms/step - loss: 0.0774 - accuracy: 0.0000e+00
# Epoch 3/100
# 1/1 [==============================] - 1s 764ms/step - loss: 0.0763 - accuracy: 0.0000e+00
# Epoch 4/100
# 1/1 [==============================] - 1s 775ms/step - loss: 0.0749 - accuracy: 0.0000e+00
# Epoch 5/100
# 1/1 [==============================] - 1s 764ms/step - loss: 0.0739 - accuracy: 0.0000e+00
# Epoch 6/100
# 1/1 [==============================] - 1s 763ms/step - loss: 0.0727 - accuracy: 0.0000e+00
# TASK 61
# TASK 62
# TASK 63
# TASK 64
# TASK 65
# TASK 66
# TASK 67
# TASK 68
# TASK 69
# TASK 70
# TASK 71
# TASK 72
# TASK 73
# TASK 74
# TASK 75
# TASK 76
# TASK 77
# TASK 78
# TASK 79
# TASK 80
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2208 - accuracy: 0.4229
# Epoch 2/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2112 - accuracy: 0.5973
# Epoch 3/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1989 - accuracy: 0.6586
# Epoch 4/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1843 - accuracy: 0.6690
# Epoch 5/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1682 - accuracy: 0.6827
# Epoch 6/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1521 - accuracy: 0.6833
# Epoch 7/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1377 - accuracy: 0.7010
# Epoch 8/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1257 - accuracy: 0.7157
# Epoch 9/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1167 - accuracy: 0.7157
# Epoch 10/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1095 - accuracy: 0.7339
# Epoch 11/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1033 - accuracy: 0.7508
# Epoch 12/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0980 - accuracy: 0.7606
# Epoch 13/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0942 - accuracy: 0.7861
# Epoch 14/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0919 - accuracy: 0.7861
# Epoch 15/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0900 - accuracy: 0.7861
# Epoch 16/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0876 - accuracy: 0.7861
# Epoch 17/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0860 - accuracy: 0.7984
# Epoch 18/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0854 - accuracy: 0.7984
# Epoch 19/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0846 - accuracy: 0.7984
# Epoch 20/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0834 - accuracy: 0.7984
# Epoch 21/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0827 - accuracy: 0.7984
# Epoch 22/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0825 - accuracy: 0.7876
# TASK 81
# TASK 82
# TASK 83
# TASK 84
# TASK 85
# TASK 86
# TASK 87
# TASK 88
# TASK 89
# TASK 90
# TASK 91
# TASK 92
# TASK 93
# TASK 94
# TASK 95
# TASK 96
# TASK 97
# TASK 98
# TASK 99
# TASK 100
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.2428 - accuracy: 0.4575
# Epoch 2/100
# 1/1 [==============================] - 1s 835ms/step - loss: 0.2424 - accuracy: 0.6298
# Epoch 3/100
# 1/1 [==============================] - 1s 771ms/step - loss: 0.2418 - accuracy: 0.6345
# Epoch 4/100
# 1/1 [==============================] - 1s 772ms/step - loss: 0.2410 - accuracy: 0.6336
# Epoch 5/100
# 1/1 [==============================] - 1s 863ms/step - loss: 0.2394 - accuracy: 0.6325
# Epoch 6/100
# 1/1 [==============================] - 1s 647ms/step - loss: 0.2365 - accuracy: 0.6408
100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0203 - accuracy: 0.9260
# Epoch 34/100
# 1/1 [==============================] - 1s 892ms/step - loss: 0.0202 - accuracy: 0.9260
# Epoch 35/100
# 1/1 [==============================] - 1s 952ms/step - loss: 0.0200 - accuracy: 0.9260
# TASK 161
# TASK 162
# TASK 163
# TASK 164
# TASK 165
# TASK 166
# TASK 167
# TASK 168
# TASK 169
# TASK 170
# TASK 171
# TASK 172
# TASK 173
# TASK 174
# TASK 175
# TASK 176
# TASK 177
# TASK 178
# TASK 179
# TASK 180
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2142 - accuracy: 0.4038
# Epoch 2/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.2105 - accuracy: 0.5465
# Epoch 3/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.2058 - accuracy: 0.5633
# Epoch 4/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.1993 - accuracy: 0.5716
# Epoch 5/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.1910 - accuracy: 0.5752
# Epoch 6/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1818 - accuracy: 0.5900
# Epoch 7/100
# 1/1 [==============================] - 0s 191ms/step - loss: 0.1735 - accuracy: 0.6046
# Epoch 8/100
# 1/1 [==============================] - 0s 114ms/step - loss: 0.1673 - accuracy: 0.6157
# Epoch 9/100
# 1/1 [==============================] - 0s 109ms/step - loss: 0.1618 - accuracy: 0.6300
# Epoch 10/100
# 1/1 [==============================] - 0s 134ms/step - loss: 0.1557 - accuracy: 0.6533
# Epoch 11/100
# 1/1 [==============================] - 0s 107ms/step - loss: 0.1490 - accuracy: 0.6658
# Epoch 12/100
# 1/1 [==============================] - 0s 123ms/step - loss: 0.1424 - accuracy: 0.6886
# Epoch 13/100
# 1/1 [==============================] - 0s 108ms/step - loss: 0.1364 - accuracy: 0.6966
# Epoch 14/100
# 1/1 [==============================] - 0s 129ms/step - loss: 0.1311 - accuracy: 0.7138
# Epoch 15/100
# 1/1 [==============================] - 0s 128ms/step - loss: 0.1261 - accuracy: 0.7205
# Epoch 16/100
# 1/1 [==============================] - 0s 108ms/step - loss: 0.1211 - accuracy: 0.7278
# Epoch 17/100
# 1/1 [==============================] - 0s 103ms/step - loss: 0.1164 - accuracy: 0.7393
# Epoch 18/100
# 1/1 [==============================] - 0s 219ms/step - loss: 0.1117 - accuracy: 0.7533
# Epoch 19/100
# 1/1 [==============================] - 0s 154ms/step - loss: 0.1068 - accuracy: 0.7574
# Epoch 20/100
# 1/1 [==============================] - 0s 158ms/step - loss: 0.1019 - accuracy: 0.7589
# Epoch 21/100
# 1/1 [==============================] - 0s 195ms/step - loss: 0.0974 - accuracy: 0.7675
# Epoch 22/100
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0934 - accuracy: 0.7750
# Epoch 23/100
# 1/1 [==============================] - 0s 155ms/step - loss: 0.0896 - accuracy: 0.7774
# Epoch 24/100
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0859 - accuracy: 0.7785
# Epoch 25/100
# 1/1 [==============================] - 0s 169ms/step - loss: 0.0824 - accuracy: 0.7774
# Epoch 26/100
# 1/1 [==============================] - 0s 143ms/step - loss: 0.0796 - accuracy: 0.7854
# Epoch 27/100
# 1/1 [==============================] - 0s 164ms/step - loss: 0.0771 - accuracy: 0.7858
# Epoch 28/100
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0747 - accuracy: 0.7909
# Epoch 29/100
# 1/1 [==============================] - 0s 172ms/step - loss: 0.0724 - accuracy: 0.7962
# Epoch 30/100
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0706 - accuracy: 0.7993
# Epoch 31/100
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0693 - accuracy: 0.7996
# Epoch 32/100
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0685 - accuracy: 0.7992
# Epoch 33/100
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0679 - accuracy: 0.7989
# Epoch 34/100
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0674 - accuracy: 0.7989
# Epoch 35/100
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0668 - accuracy: 0.7974
# Epoch 36/100
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0662 - accuracy: 0.7974
# TASK 181
# TASK 182
# TASK 183
# TASK 184
# TASK 185
# TASK 186
# TASK 187
# TASK 188
# TASK 189
# TASK 190
# TASK 191
# TASK 192
# TASK 193
# TASK 194
# TASK 195
# TASK 196
# TASK 197
# TASK 198
# TASK 199
# TASK 200
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2399 - accuracy: 0.4943
# Epoch 2/100
# 1/1 [==============================] - 1s 746ms/step - loss: 0.2395 - accuracy: 0.6834
# Epoch 3/100
# 1/1 [==============================] - 1s 799ms/step - loss: 0.2391 - accuracy: 0.6892
# Epoch 4/100
# 1/1 [==============================] - 1s 810ms/step - loss: 0.2384 - accuracy: 0.6823
# Epoch 5/100
# 1/1 [==============================] - 1s 814ms/step - loss: 0.2374 - accuracy: 0.6701
# Epoch 6/100
# 1/1 [==============================] - 1s 850ms/step - loss: 0.2357 - accuracy: 0.6673
# Epoch 7/100
# 1/1 [==============================] - 1s 942ms/step - loss: 0.2328 - accuracy: 0.6681
# Epoch 8/100
# 1/1 [==============================] - 1s 815ms/step - loss: 0.2278 - accuracy: 0.6719
# TASK 221
# TASK 222
# TASK 223
# TASK 224
# TASK 225
# TASK 226
# TASK 227
# TASK 228
# TASK 229
# TASK 230
# TASK 231
# TASK 232
# TASK 233
# TASK 234
# TASK 235
# TASK 236
# TASK 237
# TASK 238
# TASK 239
# TASK 240
# Epoch 1/100
# 1/1 [==============================] - 1s 897ms/step - loss: 0.2082 - accuracy: 0.3054
# Epoch 2/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2049 - accuracy: 0.5493
# Epoch 3/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2005 - accuracy: 0.5659
# Epoch 4/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1949 - accuracy: 0.6094
# Epoch 5/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1878 - accuracy: 0.6419
# Epoch 6/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1793 - accuracy: 0.6793
# Epoch 7/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1694 - accuracy: 0.6763
# Epoch 8/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1583 - accuracy: 0.7024
# Epoch 9/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1464 - accuracy: 0.7161
# Epoch 10/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1340 - accuracy: 0.7363
# Epoch 11/100
# 1/1 [==============================] - 0s 93ms/step - loss: 0.1215 - accuracy: 0.7528
# Epoch 12/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1094 - accuracy: 0.7589
# Epoch 13/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0983 - accuracy: 0.7556
# Epoch 14/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0887 - accuracy: 0.7556
# Epoch 15/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0810 - accuracy: 0.7556
# Epoch 16/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0748 - accuracy: 0.7556
# Epoch 17/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0693 - accuracy: 0.7556
# TASK 241
# TASK 242
# TASK 243
# TASK 244
# TASK 245
# TASK 246
# TASK 247
# TASK 248
# TASK 249
# TASK 250
# TASK 251
# TASK 252
# TASK 253
# TASK 254
# TASK 255
# TASK 256
# TASK 257
# TASK 258
# TASK 259
# TASK 260
# Epoch 1/100
# 1/1 [==============================] - 1s 946ms/step - loss: 0.2327 - accuracy: 0.5205
# Epoch 2/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2260 - accuracy: 0.7037
# Epoch 3/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2178 - accuracy: 0.7432
# Epoch 4/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.2074 - accuracy: 0.7461
# Epoch 5/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1942 - accuracy: 0.7467
# Epoch 6/100
# 1/1 [==============================] - 0s 118ms/step - loss: 0.1783 - accuracy: 0.7477
# Epoch 7/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1603 - accuracy: 0.7523
# Epoch 8/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1412 - accuracy: 0.7661
# Epoch 9/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1219 - accuracy: 0.7816
# Epoch 10/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1028 - accuracy: 0.8253
# Epoch 11/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0842 - accuracy: 0.8253
# Epoch 12/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0667 - accuracy: 0.8643
# Epoch 13/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0509 - accuracy: 0.8643
# Epoch 14/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0373 - accuracy: 0.8643
# Epoch 15/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0258 - accuracy: 0.8752
# Epoch 16/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0168 - accuracy: 0.8925
# Epoch 17/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0109 - accuracy: 0.8925
# Epoch 18/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0076 - accuracy: 0.8925
# Epoch 19/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0059 - accuracy: 0.8925
# Epoch 20/100
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0050 - accuracy: 0.8925
# Epoch 21/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0046 - accuracy: 0.8925
# TASK 261
# TASK 262
# TASK 263
# TASK 264
# TASK 265
# TASK 266
# TASK 267
# TASK 268
# TASK 269
# TASK 270
# TASK 271
# TASK 272
# TASK 273
# TASK 274
# TASK 275
# TASK 276
# TASK 277
# TASK 278
# TASK 279
# TASK 280
# Epoch 1/100
# 1/1 [==============================] - 1s 691ms/step - loss: 0.2120 - accuracy: 0.3424
# Epoch 2/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.2111 - accuracy: 0.4830
# Epoch 3/100
# 1/1 [==============================] - 0s 268ms/step - loss: 0.2098 - accuracy: 0.5120
# Epoch 4/100
# 1/1 [==============================] - 0s 271ms/step - loss: 0.2077 - accuracy: 0.5230
# Epoch 5/100
# 1/1 [==============================] - 0s 284ms/step - loss: 0.2043 - accuracy: 0.5357
# Epoch 6/100
# 1/1 [==============================] - 0s 239ms/step - loss: 0.1989 - accuracy: 0.5489
# Epoch 7/100
# 1/1 [==============================] - 0s 269ms/step - loss: 0.1912 - accuracy: 0.5603
# Epoch 8/100
# 1/1 [==============================] - 0s 257ms/step - loss: 0.1817 - accuracy: 0.5638
# Epoch 9/100
# 1/1 [==============================] - 0s 325ms/step - loss: 0.1719 - accuracy: 0.5750
# Epoch 10/100
# 1/1 [==============================] - 0s 267ms/step - loss: 0.1638 - accuracy: 0.5903
# Epoch 11/100
# 1/1 [==============================] - 0s 327ms/step - loss: 0.1576 - accuracy: 0.6034
# Epoch 12/100
# 1/1 [==============================] - 0s 291ms/step - loss: 0.1519 - accuracy: 0.6048
# Epoch 13/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.1455 - accuracy: 0.6125
# Epoch 14/100
# 1/1 [==============================] - 0s 270ms/step - loss: 0.1384 - accuracy: 0.6245
# Epoch 15/100
# 1/1 [==============================] - 0s 283ms/step - loss: 0.1313 - accuracy: 0.6389
# Epoch 16/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.1244 - accuracy: 0.6437
# Epoch 17/100
# 1/1 [==============================] - 0s 254ms/step - loss: 0.1177 - accuracy: 0.6486
# Epoch 18/100
# 1/1 [==============================] - 0s 325ms/step - loss: 0.1112 - accuracy: 0.6585
# Epoch 19/100
# 1/1 [==============================] - 0s 262ms/step - loss: 0.1048 - accuracy: 0.6673
# Epoch 20/100
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0987 - accuracy: 0.6754
# Epoch 21/100
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0927 - accuracy: 0.6822
# Epoch 22/100
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0867 - accuracy: 0.6902
# Epoch 23/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0807 - accuracy: 0.6989
# Epoch 24/100
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0748 - accuracy: 0.7051
# Epoch 25/100
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0689 - accuracy: 0.7157
# Epoch 26/100
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0633 - accuracy: 0.7207
# Epoch 27/100
# 1/1 [==============================] - 0s 301ms/step - loss: 0.0578 - accuracy: 0.7309
# Epoch 28/100
# 1/1 [==============================] - 0s 332ms/step - loss: 0.0526 - accuracy: 0.7311
# Epoch 29/100
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0476 - accuracy: 0.7363
# Epoch 30/100
# 1/1 [==============================] - 0s 333ms/step - loss: 0.0429 - accuracy: 0.7464
# Epoch 31/100
# 1/1 [==============================] - 0s 320ms/step - loss: 0.0390 - accuracy: 0.7527
# Epoch 32/100
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0358 - accuracy: 0.7575
# Epoch 33/100
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0334 - accuracy: 0.7575
# Epoch 34/100
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0316 - accuracy: 0.7575
# Epoch 35/100
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0301 - accuracy: 0.7575
# Epoch 36/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0288 - accuracy: 0.7575
# Epoch 37/100
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0276 - accuracy: 0.7611
# Epoch 38/100
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0268 - accuracy: 0.7611
# Epoch 39/100
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0264 - accuracy: 0.7611
# Epoch 40/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0259 - accuracy: 0.7611
# Epoch 41/100
# 1/1 [==============================] - 0s 263ms/step - loss: 0.0251 - accuracy: 0.7611
# Epoch 42/100
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0240 - accuracy: 0.7614
# Epoch 43/100
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0228 - accuracy: 0.7637
# Epoch 44/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.0220 - accuracy: 0.7665
# Epoch 45/100
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0216 - accuracy: 0.7665
# Epoch 46/100
# 1/1 [==============================] - 0s 261ms/step - loss: 0.0214 - accuracy: 0.7665
# Epoch 47/100
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0211 - accuracy: 0.7665
# Epoch 48/100
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0209 - accuracy: 0.7665
# Epoch 49/100
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0207 - accuracy: 0.7665
# TASK 281
# TASK 282
# TASK 283
# TASK 284
# TASK 285
# TASK 286
# TASK 287
# TASK 288
# TASK 289
# TASK 290
# TASK 291
# TASK 292
# TASK 293
# TASK 294
# TASK 295
# TASK 296
# TASK 297
# TASK 298
# TASK 299
# TASK 300
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2275 - accuracy: 0.4221
# Epoch 2/100
# 1/1 [==============================] - 0s 145ms/step - loss: 0.2251 - accuracy: 0.5753
# Epoch 3/100
# 1/1 [==============================] - 0s 139ms/step - loss: 0.2217 - accuracy: 0.5984
# Epoch 4/100
# 1/1 [==============================] - 0s 172ms/step - loss: 0.2166 - accuracy: 0.6069
# Epoch 5/100
# 1/1 [==============================] - 0s 156ms/step - loss: 0.2090 - accuracy: 0.6238
# Epoch 6/100
# 1/1 [==============================] - 0s 153ms/step - loss: 0.1989 - accuracy: 0.6391
# Epoch 7/100
# 1/1 [==============================] - 0s 133ms/step - loss: 0.1870 - accuracy: 0.6386
# Epoch 8/100
# 1/1 [==============================] - 0s 156ms/step - loss: 0.1746 - accuracy: 0.6367
# Epoch 9/100
# 1/1 [==============================] - 0s 171ms/step - loss: 0.1625 - accuracy: 0.6560
# Epoch 10/100
# 1/1 [==============================] - 0s 120ms/step - loss: 0.1508 - accuracy: 0.6900
# Epoch 11/100
# 1/1 [==============================] - 0s 197ms/step - loss: 0.1393 - accuracy: 0.7188
# Epoch 12/100
# 1/1 [==============================] - 0s 161ms/step - loss: 0.1281 - accuracy: 0.7442
# Epoch 13/100
# 1/1 [==============================] - 0s 145ms/step - loss: 0.1172 - accuracy: 0.7668
# Epoch 14/100
# 1/1 [==============================] - 0s 144ms/step - loss: 0.1070 - accuracy: 0.7740
# Epoch 15/100
# 1/1 [==============================] - 0s 171ms/step - loss: 0.0970 - accuracy: 0.7936
# Epoch 16/100
# 1/1 [==============================] - 0s 145ms/step - loss: 0.0869 - accuracy: 0.8050
# Epoch 17/100
# 1/1 [==============================] - 0s 174ms/step - loss: 0.0766 - accuracy: 0.8247
# Epoch 18/100
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0674 - accuracy: 0.8361
# Epoch 19/100
# 1/1 [==============================] - 0s 171ms/step - loss: 0.0598 - accuracy: 0.8472
# Epoch 20/100
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0541 - accuracy: 0.8530
# Epoch 21/100
# 1/1 [==============================] - 0s 154ms/step - loss: 0.0501 - accuracy: 0.8591
# Epoch 22/100
# 1/1 [==============================] - 0s 163ms/step - loss: 0.0467 - accuracy: 0.8688
# Epoch 23/100
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0439 - accuracy: 0.8702
# Epoch 24/100
# 1/1 [==============================] - 0s 174ms/step - loss: 0.0426 - accuracy: 0.8684
# Epoch 25/100
# 1/1 [==============================] - 0s 146ms/step - loss: 0.0421 - accuracy: 0.8684
# Epoch 26/100
# 1/1 [==============================] - 0s 160ms/step - loss: 0.0415 - accuracy: 0.8678
# Epoch 27/100
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0411 - accuracy: 0.8684
# Epoch 28/100
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0407 - accuracy: 0.8700
# TASK 301
# TASK 302
# TASK 303
# TASK 304
# TASK 305
# TASK 306
# TASK 307
# TASK 308
# TASK 309
# TASK 310
# TASK 311
# TASK 312
# TASK 313
# TASK 314
# TASK 315
# TASK 316
# TASK 317
# TASK 318
# TASK 319
# TASK 320
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.
# 1/1 [==============================] - 0s 455ms/step - loss: 0.0147 - accuracy: 0.9268
# Epoch 33/100
# 1/1 [==============================] - 0s 487ms/step - loss: 0.0139 - accuracy: 0.9268
# Epoch 34/100
# 1/1 [==============================] - 1s 506ms/step - loss: 0.0132 - accuracy: 0.9265
# Epoch 35/100
# 1/1 [==============================] - 0s 424ms/step - loss: 0.0128 - accuracy: 0.9261
# Epoch 36/100
# 1/1 [==============================] - 1s 512ms/step - loss: 0.0127 - accuracy: 0.9251
# TASK 321
# TASK 322
# TASK 323
# TASK 324
# TASK 325
# TASK 326
# TASK 327
# TASK 328
# TASK 329
# TASK 330
# TASK 331
# TASK 332
# TASK 333
# TASK 334
# TASK 335
# TASK 336
# TASK 337
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-8b6dc5f2234e> in <module>
#      47     pred_train = (decoded_imgs_train.reshape(outp_shape[0:2]))*10
#      48
# ---> 49     encoded_imgs_test = base_model.encoder(Xs_test_aug[idx][:1]).numpy()
#      50     decoded_imgs_test = base_model.decoder(encoded_imgs_test).numpy()
#      51
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     976     if any(isinstance(x, (
#     977         np_arrays.ndarray, np.ndarray, float, int)) for x in input_list):
# --> 978       inputs = nest.map_structure(_convert_numpy_or_python_types, inputs)
#     979       input_list = nest.flatten(inputs)
#     980
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in _convert_numpy_or_python_types(x)
#    3226 def _convert_numpy_or_python_types(x):
#    3227   if isinstance(x, (np_arrays.ndarray, np.ndarray, float, int)):
# -> 3228     return ops.convert_to_tensor_v2_with_dispatch(x)
#    3229   return x
#    3230
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1429   """
#    1430   return convert_to_tensor_v2(
# -> 1431       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#    1432
#    1433
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1439       name=name,
#    1440       preferred_dtype=dtype_hint,
# -> 1441       as_ref=False)
#    1442
#    1443
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     263   """
#     264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 265                         allow_broadcast=True)
#     266
#     267
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type numpy.ndarray).

# %%
base_model.encoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 15, 15, 160)       1600
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 8, 8, 160)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 320)         461120
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 320)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 5120)              0
# _________________________________________________________________
# dense (Dense)                (None, 50)                256050
# =================================================================
# Total params: 718,770
# Trainable params: 718,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
base_model.decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 225)               11475
# _________________________________________________________________
# reshape (Reshape)            (None, 15, 15, 1)         0
# =================================================================
# Total params: 11,475
# Trainable params: 11,475
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(pred_train_li),len(pred_test_li)
# Out:
# (337, 337)

# %%
type(pred_train_li[5]), pred_train_li[5].shape
# Out:
# (numpy.ndarray, (7, 7))

# %%
type(pred_train_li[33]), pred_train_li[33].shape
# Out:
# (numpy.ndarray, (9, 9))

# %% [markdown]
# ## PLOT PREDICTIONS

# %%
x=40 #### choose which one to display in all below

# %%
cmap = colors.ListedColormap(
            ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
             '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
norm = colors.Normalize(vmin=0, vmax=9)
fig, ax = plt.subplots(1, 5, figsize=(20,20))
for idx in range(x,x+1,20):
 
    
    ax[0].imshow((Xs_train_aug[idx][0])*10, cmap=cmap, norm=norm)
    ax[0].set_title(f'Train Input')
    ax[1].imshow((ys_train_aug[idx][0])*10, cmap=cmap, norm=norm)
    ax[1].set_title(f'Train output')
    ax[2].imshow((pred_train_li[idx]), cmap=cmap, norm=norm)
    ax[2].set_title(f'Train Prediction')   
    
    ax[3].imshow((Xs_test_aug[idx][0])*10, cmap=cmap, norm=norm)
    ax[3].set_title(f'Test Input')
    ax[4].imshow(pred_test_li[idx], cmap=cmap, norm=norm)
    ax[4].set_title(f'Test Prediction')

# %%
cmap = colors.ListedColormap(
            ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
             '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
norm = colors.Normalize(vmin=0, vmax=9)
fig, ax = plt.subplots(15, 10, figsize=(25,25))
for i in range(15):
    for j in range(10):
        idx = i+j+3*i
        
        ax[i,j].imshow((Xs_train_aug[x][idx])*10, cmap=cmap, norm=norm)
        ax[i,j].set_title(f'Train Input {idx}')

# %%
cmap = colors.ListedColormap(
            ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
             '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
norm = colors.Normalize(vmin=0, vmax=9)
fig, ax = plt.subplots(1, 3, figsize=(25,25))
for i in range(1):
    for j in range(3):
        idx = j
        
        ax[j].imshow((Xs_train_aug[x][idx])*10, cmap=cmap, norm=norm)
        ax[j].set_title(f'Train Input {idx}')
