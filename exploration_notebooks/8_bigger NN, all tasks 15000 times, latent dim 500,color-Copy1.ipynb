# %% [markdown]
# NEW NEW NEW
# - new color definition
# - reduced amount of times random method is executed
# - class Autoencoder(Model): included input_shape and output_shape
# - loooooops

# %%
import numpy as np
import pandas as pd
import random 
from random import randint
import time

import os
import json
from pathlib import Path

import tensorflow.keras as keras
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras import layers
#from tensorflow.keras.datasets import mnist
from tensorflow.keras import backend as K
#from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt
from matplotlib import colors

# %%
data_path = Path('./kaggle_input/')
training_path = data_path / 'training'      # 400 X-train ('train'), y-train('test') input-output pairs
evaluation_path = data_path / 'evaluation'  # 400
test_path = data_path / 'test'              # 100 pairs X-train ('train') (input-output),
                                            #           y-train (input only) pairs

training_tasks_files = sorted(os.listdir(training_path))#[1:]
eval_tasks_files = sorted(os.listdir(evaluation_path))
test_task_files = sorted(os.listdir(test_path))

# %%
def load_files(path):
    path_files = sorted(os.listdir(path))
    tasks = []
    for task_file in path_files:
        with open(str(path / task_file), 'r') as f:
            task = json.load(f)
            tasks.append(task)
    return tasks

# %%
training_tasks = load_files(training_path)          ### this is for building / training the algorithm
test_tasks = load_files(test_path)                  ### this is the input for the actual prediction!!!
evaluation_tasks = load_files(evaluation_path)      ### testing the algorithm

# %%
len(training_tasks), training_tasks[0]['test']
# Out:
# (400,
#  [{'input': [[7, 0, 7], [7, 0, 7], [7, 7, 0]],
#    'output': [[7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 7, 0, 0, 0, 0, 7, 7, 0],
#     [7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 7, 0, 0, 0, 0, 7, 7, 0],
#     [7, 0, 7, 7, 0, 7, 0, 0, 0],
#     [7, 0, 7, 7, 0, 7, 0, 0, 0],
#     [7, 7, 0, 7, 7, 0, 0, 0, 0]]}])

# %%
len(evaluation_tasks), evaluation_tasks[0]['test']
# Out:
# (400,
#  [{'input': [[3, 2], [7, 8]],
#    'output': [[3, 2, 3, 2, 3, 2],
#     [7, 8, 7, 8, 7, 8],
#     [2, 3, 2, 3, 2, 3],
#     [8, 7, 8, 7, 8, 7],
#     [3, 2, 3, 2, 3, 2],
#     [7, 8, 7, 8, 7, 8]]}])

# %%
len(test_tasks),test_tasks[0]['test']
# Out:
# (100, [{'input': [[3, 2], [7, 8]]}])

# %% [markdown]
#
#  ---
#  ---

# %% [markdown]
# ### 1. Create Train - Test - Split

# %%
def tts(input_list):
    Xs_test, ys_test, Xs_train, ys_train = [], [], [], []

    for task in input_list:
        X_test, y_test, X_train, y_train = [], [], [], []

        for pair in task["test"]:
            X_test.append(pair["input"])
            y_test.append(pair["output"])      ### to be predicted !!!

        for pair in task["train"]:
            X_train.append(pair["input"])
            y_train.append(pair["output"])

        Xs_test.append(X_test)
        ys_test.append(y_test)
        Xs_train.append(X_train)
        ys_train.append(y_train)
    return Xs_test, ys_test, Xs_train, ys_train

# %% [markdown]
#
# #### Create origanl sized Train-Test-Split for reference

# %%
Xs_test_orig, ys_test_orig, Xs_train_orig, ys_train_orig = tts(training_tasks)

# %%
len(Xs_train_orig), len(ys_train_orig), len(Xs_test_orig), len(ys_test_orig)
# Out:
# (400, 400, 400, 400)

# %%
len(Xs_train_orig[1]), len(ys_train_orig[1]), len(Xs_test_orig[1]), len(ys_test_orig[1])
# Out:
# (5, 5, 1, 1)

# %% [markdown]
#
# #### Create actual Train-Test-Split

# %%
Xs_test, ys_test, Xs_train, ys_train = tts(training_tasks)

# %%
len(Xs_train), len(ys_train), len(Xs_test), len(ys_test)
# Out:
# (400, 400, 400, 400)

# %%
len(Xs_train[1]), len(ys_train[1]), len(Xs_test[1]), len(ys_test[1])
# Out:
# (5, 5, 1, 1)

# %% [markdown]
# ## Data Augmentation of the training data

# %%
# #### color
# def color_change(arr):
#     x = arr*3
# #     x = x/(x.max()+0.1)
#     x = np.interp(x, (0.3, 2.7), (0, 0.9))
#     x = np.ndarray.round(x,1)
#     return x

# %%
def augm(X_list, y_list):
    idx = 1
    X_list_new = []
    y_list_new = []
    
    for task_X, task_y in zip(X_list, y_list):
        task_li_x = []
        task_li_y = []
        print("TASK",idx)
        length = len(Xs_train_orig[idx-1])
#         print(length)
        max_li=[]
        for i in range(length):
            max_a = max(len(task_X[i]),len(task_X[i][0]))
            max_b = max(len(task_y[i]),len(task_y[i][0]))
            max_c = max(len(Xs_test[idx-1][0]),len(Xs_test[idx-1][0][0]))
            max_d = max(len(ys_test[idx-1][0]),len(ys_test[idx-1][0][0]))
            max_abcd = max(max_a,max_b, max_c, max_d)
            max_li.append(max_abcd)
#             print(f"max_a = max({len(task_X[i])},{len(task_X[i][0])})")
#             print(f"max_b = max({len(task_y[i])},{len(task_y[i][0])})")
#             print(max_int)
        max_int = max(max_li)
            
        for e_x,e_y in zip(task_X, task_y):
            e_x = (np.array(e_x))/10.     
            e_y = (np.array(e_y))/10.
#             print(e_x.shape,e_y.shape, max_int)
            e_x = np.pad(e_x, [(0, max_int-e_x.shape[0]), (0, max_int-e_x.shape[1])], mode='constant')
            e_y = np.pad(e_y, [(0, max_int-e_y.shape[0]), (0, max_int-e_y.shape[1])], mode='constant')
#             print(e_x.shape,e_y.shape, max_int, "\n")
            task_li_x.append(e_x.reshape(e_x.shape + (1,) ))
            task_li_y.append(e_y.reshape(e_y.shape + (1,) ))
        # ========================
         
        while len(task_li_x) < 5000*length:    ###################
#             print(len(task_li_x))
            """
            choose a random method and append new array
            """
            i = randint(0,length-1) 
            new_x = (np.array(task_X[i]))/10.
#             print((new_x))
            new_y = (np.array(task_y[i]))/10.
            
            
            times = randint(1,5)
#             print(f"LENGTH: {len(task_X)} // INDEX: {i} // TIMES: {times}" )
            for j in range(times):
                
                method = random.choice([np.fliplr, np.flipud, np.rot90])#,color_change])
                new_x = method(new_x)
                new_y = method(new_y)

            new_x = np.pad(new_x, [(0, max_int-new_x.shape[0]), (0, max_int-new_x.shape[1])], mode='constant')

            new_y = np.pad(new_y, [(0, max_int-new_y.shape[0]), (0, max_int-new_y.shape[1])], mode='constant')

            
            task_li_x.append(new_x.reshape(new_x.shape + (1,) ))
            task_li_y.append(new_y.reshape(new_y.shape + (1,) ))
 
        X_list_new.append(np.array(task_li_x))
        y_list_new.append(np.array(task_li_y))

        idx +=1
    return     X_list_new, y_list_new

# %%
Xs_train_aug, ys_train_aug = augm(Xs_train, ys_train)
# Out:
# TASK 1
# TASK 2
# TASK 3
# TASK 4
# TASK 5
# TASK 6
# TASK 7
# TASK 8
# TASK 9
# TASK 10
# TASK 11
# TASK 12
# TASK 13
# TASK 14
# TASK 15
# TASK 16
# TASK 17
# TASK 18
# TASK 19
# TASK 20
# TASK 21
# TASK 22
# TASK 23
# TASK 24
# TASK 25
# TASK 26
# TASK 27
# TASK 28
# TASK 29
# TASK 30
# TASK 31
# TASK 32
# TASK 33
# TASK 34
# TASK 35
# TASK 36
# TASK 37
# TASK 38
# TASK 39
# TASK 40
# TASK 41
# TASK 42
# TASK 43
# TASK 44
# TASK 45
# TASK 46
# TASK 47
# TASK 48
# TASK 49
# TASK 50
# TASK 51
# TASK 52
# TASK 53
# TASK 54
# TASK 55
# TASK 56
# TASK 57
# TASK 58
# TASK 59
# TASK 60
# TASK 61
# TASK 62
# TASK 63
# TASK 64
# TASK 65
# TASK 66
# TASK 67
# TASK 68
# TASK 69
# TASK 70
# TASK 71
# TASK 72
# TASK 73
# TASK 74
# TASK 75
# TASK 76
# TASK 77
# TASK 78
# TASK 79
# TASK 80
# TASK 81
# TASK 82
# TASK 83
# TASK 84
# TASK 85
# TASK 86
# TASK 87
# TASK 88
# TASK 89
# TASK 90
# TASK 91
# TASK 92
# TASK 93
# TASK 94
# TASK 95
# TASK 96
# TASK 97
# TASK 98
# TASK 99
# TASK 100
# TASK 101
# TASK 102
# TASK 103
# TASK 104
# TASK 105
# TASK 106
# TASK 107
# TASK 108
# TASK 109
# TASK 110
# TASK 111
# TASK 112
# TASK 113
# TASK 114
# TASK 115
# TASK 116
# TASK 117
# TASK 118
# TASK 119
# TASK 120
# TASK 121
# TASK 122
# TASK 123
# TASK 124
# TASK 125
# TASK 126
# TASK 127
# TASK 128
# TASK 129
# TASK 130
# TASK 131
# TASK 132
# TASK 133
# TASK 134
# TASK 135
# TASK 136
# TASK 137
# TASK 138
# TASK 139
# TASK 140
# TASK 141
# TASK 142
# TASK 143
# TASK 144
# TASK 145
# TASK 146
# TASK 147
# TASK 148
# TASK 149
# TASK 150
# TASK 151
# TASK 152
# TASK 153
# TASK 154
# TASK 155
# TASK 156
# TASK 157
# TASK 158
# TASK 159
# TASK 160
# TASK 161
# TASK 162
# TASK 163
# TASK 164
# TASK 165
# TASK 166
# TASK 167
# TASK 168
# TASK 169
# TASK 170
# TASK 171
# TASK 172
# TASK 173
# TASK 174
# TASK 175
# TASK 176
# TASK 177
# TASK 178
# TASK 179
# TASK 180
# TASK 181
# TASK 182
# TASK 183
# TASK 184
# TASK 185
# TASK 186
# TASK 187
# TASK 188
# TASK 189
# TASK 190
# TASK 191
# TASK 192
# TASK 193
# TASK 194
# TASK 195
# TASK 196
# TASK 197
# TASK 198
# TASK 199
# TASK 200
# TASK 201
# TASK 202
# TASK 203
# TASK 204
# TASK 205
# TASK 206
# TASK 207
# TASK 208
# TASK 209
# TASK 210
# TASK 211
# TASK 212
# TASK 213
# TASK 214
# TASK 215
# TASK 216
# TASK 217
# TASK 218
# TASK 219
# TASK 220
# TASK 221
# TASK 222
# TASK 223
# TASK 224
# TASK 225
# TASK 226
# TASK 227
# TASK 228
# TASK 229
# TASK 230
# TASK 231
# TASK 232
# TASK 233
# TASK 234
# TASK 235
# TASK 236
# TASK 237
# TASK 238
# TASK 239
# TASK 240
# TASK 241
# TASK 242
# TASK 243
# TASK 244
# TASK 245
# TASK 246
# TASK 247
# TASK 248
# TASK 249
# TASK 250
# TASK 251
# TASK 252
# TASK 253
# TASK 254
# TASK 255
# TASK 256
# TASK 257
# TASK 258
# TASK 259
# TASK 260
# TASK 261
# TASK 262
# TASK 263
# TASK 264
# TASK 265
# TASK 266
# TASK 267
# TASK 268
# TASK 269
# TASK 270
# TASK 271
# TASK 272
# TASK 273
# TASK 274
# TASK 275
# TASK 276
# TASK 277
# TASK 278
# TASK 279
# TASK 280
# TASK 281
# TASK 282
# TASK 283
# TASK 284
# TASK 285
# TASK 286
# TASK 287
# TASK 288
# TASK 289
# TASK 290
# TASK 291
# TASK 292
# TASK 293
# TASK 294
# TASK 295
# TASK 296
# TASK 297
# TASK 298
# TASK 299
# TASK 300
# TASK 301
# TASK 302
# TASK 303
# TASK 304
# TASK 305
# TASK 306
# TASK 307
# TASK 308
# TASK 309
# TASK 310
# TASK 311
# TASK 312
# TASK 313
# TASK 314
# TASK 315
# TASK 316
# TASK 317
# TASK 318
# TASK 319
# TASK 320
# TASK 321
# TASK 322
# TASK 323
# TASK 324
# TASK 325
# TASK 326
# TASK 327
# TASK 328
# TASK 329
# TASK 330
# TASK 331
# TASK 332
# TASK 333
# TASK 334
# TASK 335
# TASK 336
# TASK 337
# TASK 338
# TASK 339
# TASK 340
# TASK 341
# TASK 342
# TASK 343
# TASK 344
# TASK 345
# TASK 346
# TASK 347
# TASK 348
# TASK 349
# TASK 350
# TASK 351
# TASK 352
# TASK 353
# TASK 354
# TASK 355
# TASK 356
# TASK 357
# TASK 358
# TASK 359
# TASK 360
# TASK 361
# TASK 362
# TASK 363
# TASK 364
# TASK 365
# TASK 366
# TASK 367
# TASK 368
# TASK 369
# TASK 370
# TASK 371
# TASK 372
# TASK 373
# TASK 374
# TASK 375
# TASK 376
# TASK 377
# TASK 378
# TASK 379
# TASK 380
# TASK 381
# TASK 382
# TASK 383
# TASK 384
# TASK 385
# TASK 386
# TASK 387
# TASK 388
# TASK 389
# TASK 390
# TASK 391
# TASK 392
# TASK 393
# TASK 394
# TASK 395
# TASK 396
# TASK 397
# TASK 398
# TASK 399
# TASK 400

# %%
type(Xs_train_aug),len(Xs_train_aug)   ### number of Tasks
# Out:
# (list, 400)

# %%
type(Xs_train_aug[0]),len(Xs_train_aug[0]) ### number of sets
# Out:
# (numpy.ndarray, 25000)

# %%
type(Xs_train_aug[0][0]),Xs_train_aug[0][0].shape ### number of inputs (pairs)
# Out:
# (numpy.ndarray, (9, 9, 1))

# %% [markdown]
# #### format test data

# %%
def t2l(X_list, y_list):
    li_x =[]
    li_y =[]
    idx = 0
    for task_x, task_y in zip(X_list, y_list):
#         print("TASK", idx)
        task_x_arr = np.array(task_x)
        task_y_arr = np.array(task_y)
        li2_x = []
        li2_y = []
        for e_x, e_y in zip(task_x_arr, task_y_arr):
            e_x = np.array(e_x)
            e_y = np.array(e_y)
            max_train = Xs_train_aug[idx].shape[1]
            max_int = max(max(e_x.shape),max(e_y.shape),max_train)
            
            
            e_x = np.pad(e_x, [(0, max_int-e_x.shape[0]), (0, max_int-e_x.shape[1])], mode='constant')
            e_x = e_x / 10.
            e_x = e_x.reshape(e_x.shape + (1,) )
#             print(e_x.shape, e_y.shape, max_int)
            e_y = np.pad(e_y, [(0, max_int-e_y.shape[0]), (0, max_int-e_y.shape[1])], mode='constant')
            e_y = e_y / 10.
            e_y = e_y.reshape(e_y.shape + (1,) )
#             print(e_x.shape, e_y.shape, "\n")
            li2_x.append(e_x)
            li2_y.append(e_y)

#         lenght = len(Xs_train_aug[idx])
        
#         li_x.append([np.array(li2_x)])
#         li_y.append([np.array(li2_y)])
        
        li_x.append(np.array(li2_x))
        li_y.append(np.array(li2_y))
        idx += 1
    return li_x, li_y

# %%
Xs_test_aug, ys_test_aug = t2l(Xs_test, ys_test)
# Out:
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   import sys
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:34: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:35: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
type(Xs_train_aug), type(ys_train_aug),type(Xs_test_aug), type(ys_test_aug)
# Out:
# (list, list, list, list)

# %%
len(Xs_train_aug), len(ys_train_aug),len(Xs_test_aug), len(ys_test_aug)
# Out:
# (400, 400, 400, 400)

# %%
type(Xs_train_aug[0]), type(ys_train_aug[0]),type(Xs_test_aug[0]), type(ys_test_aug[0])
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
len(Xs_train_aug[0]), len(ys_train_aug[0]),len(Xs_test_aug[0]), len(ys_test_aug[0])
# Out:
# (25000, 25000, 1, 1)

# %%
Xs_train_aug[0].shape, ys_train_aug[0].shape,Xs_test_aug[0].shape, ys_test_aug[0].shape
# Out:
# ((25000, 9, 9, 1), (25000, 9, 9, 1), (1, 9, 9, 1), (1, 9, 9, 1))

# %%
type(Xs_train_aug[0][0]), type(ys_train_aug[0][0]),type(Xs_test_aug[0][0]), type(ys_test_aug[0][0])
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
Xs_train_aug[2][2].shape, ys_train_aug[2][2].shape, Xs_test_aug[2][0].shape, ys_test_aug[2][0].shape
# Out:
# ((9, 9, 1), (9, 9, 1), (9, 9, 1), (9, 9, 1))

# %% [markdown]
# ## Model comp

# %%
class Autoencoder(Model):
    def __init__(self, latent_dim, inp_shape, outp_shape, flat_shape):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.inp_shape = inp_shape
        self.outp_shape = outp_shape
        self.flat_shape = flat_shape
        
        
        self.encoder = Sequential([
            layers.Conv2D(160, (3, 3), activation='relu', padding='same', input_shape = inp_shape), #### 
            layers.MaxPooling2D((2, 2), padding='same'),
            layers.Conv2D(320, (3, 3), activation='relu', padding='same'),
            layers.MaxPooling2D((2, 2), padding='same'),
            layers.Flatten(),
            layers.Dense(latent_dim, activation='relu'),
        ])
        self.decoder = Sequential([
            layers.Dense(flat_shape, activation='sigmoid'),
            layers.Reshape(outp_shape),
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
K.clear_session()  
latent_dim = 500 
idx = 0
start = time.time()
pred_train_li = []
pred_test_li = []

for X_train, y_train, X_test, y_test in zip(Xs_train_aug, ys_train_aug, Xs_test_aug, ys_test_aug):
    K.clear_session()  
    print(f"TASK {idx}")
    set_no = 0


    ### get input and output shapes to pass to the model
    inp_shape = X_train[0].shape
#         print('in', inp_shape)
    outp_shape = y_train[0].shape#[0]*y_set_train[0].shape[1]
#         print('out',outp_shape)
    flat_shape = outp_shape[0]*outp_shape[1]
#         print('flat',flat_shape)   
        
        
    verb = 0
    if idx%10 == 0: verb=1    
    
    K.clear_session() 
    base_model = Autoencoder(latent_dim, inp_shape, outp_shape, flat_shape)

    base_model.compile(optimizer='adam', 
                              loss='mean_squared_error',
                              metrics=['accuracy'])

    callback = keras.callbacks.EarlyStopping(monitor='accuracy',
                                                 patience=5)

    base_model.fit(X_train, y_train,
                          epochs=100,
                          batch_size=5000,
                          #shuffle=True,
                          verbose=verb,
                          callbacks=[callback])#,
#                           validation_data=(X_set_test, y_set_test))        
        
    encoded_imgs_train = base_model.encoder(X_train[:1]).numpy()
    decoded_imgs_train = base_model.decoder(encoded_imgs_train).numpy()

    pred_train = (decoded_imgs_train.reshape(outp_shape[0:2]))*10
    
    encoded_imgs_test = base_model.encoder(Xs_test_aug[idx][:1]).numpy()
    decoded_imgs_test = base_model.decoder(encoded_imgs_test).numpy()

    pred_test = (decoded_imgs_test.reshape(outp_shape[0:2]))*10
    
    pred_train_li.append(pred_train)
    pred_test_li.append(pred_test) 
        
    idx += 1
    
end = time.time()
 
print("Total time: " + str(np.round(end - start, 1)) + " s" + "\n")
# Out:
# TASK 0
# Epoch 1/100
# 5/5 [==============================] - 13s 3s/step - loss: 0.1832 - accuracy: 0.6150
# Epoch 2/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.1175 - accuracy: 0.7103
# Epoch 3/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.0834 - accuracy: 0.7131
# Epoch 4/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.0830 - accuracy: 0.7127
# Epoch 5/100
# 5/5 [==============================] - 10s 2s/step - loss: 0.0809 - accuracy: 0.7125
# Epoch 6/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.0787 - accuracy: 0.7127
# Epoch 7/100
# 5/5 [==============================] - 10s 2s/step - loss: 0.0764 - accuracy: 0.7123
# Epoch 8/100
# 5/5 [==============================] - 10s 2s/step - loss: 0.0748 - accuracy: 0.7118
# TASK 1
# TASK 2
# TASK 3
# TASK 4
# TASK 5
# TASK 6
# TASK 7
# TASK 8
# TASK 9
# TASK 10
# Epoch 1/100
# 4/4 [==============================] - 11s 3s/step - loss: 0.0853 - accuracy: 0.3014
# Epoch 2/100
# 4/4 [==============================] - 11s 3s/step - loss: 0.0369 - accuracy: 0.3705
# Epoch 3/100
# 4/4 [==============================] - 11s 3s/step - loss: 0.0372 - accuracy: 0.3719
# Epoch 4/100
# 4/4 [==============================] - 11s 3s/step - loss: 0.0337 - accuracy: 0.3719
# Epoch 5/100
# 4/4 [==============================] - 11s 3s/step - loss: 0.0298 - accuracy: 0.3719
# Epoch 6/100
# 4/4 [==============================] - 11s 3s/step - loss: 0.0283 - accuracy: 0.3719
# Epoch 7/100
# 4/4 [==============================] - 11s 3s/step - loss: 0.0268 - accuracy: 0.3719
# Epoch 8/100
# 4/4 [==============================] - 11s 3s/step - loss: 0.0268 - accuracy: 0.3719
# TASK 11
# TASK 12
# TASK 13
# TASK 14
# TASK 15
# TASK 16
# TASK 17
# TASK 18
# TASK 19
# TASK 20
# Epoch 1/100
# 3/3 [==============================] - 50s 16s/step - loss: 0.2363 - accuracy: 0.6535
# Epoch 2/100
# 3/3 [==============================] - 47s 16s/step - loss: 0.1099 - accuracy: 0.8925
# Epoch 3/100
# 3/3 [==============================] - 47s 16s/step - loss: 0.0114 - accuracy: 0.9657
# Epoch 4/100
# 3/3 [==============================] - 47s 16s/step - loss: 0.0016 - accuracy: 0.9799
# Epoch 5/100
# 3/3 [==============================] - 47s 16s/step - loss: 0.0016 - accuracy: 0.9799
# Epoch 6/100
# 3/3 [==============================] - 47s 15s/step - loss: 0.0016 - accuracy: 0.9799
# Epoch 7/100
# 3/3 [==============================] - 47s 16s/step - loss: 0.0016 - accuracy: 0.9799
# Epoch 8/100
# 3/3 [==============================] - 47s 16s/step - loss: 0.0016 - accuracy: 0.9799
# Epoch 9/100
# 3/3 [==============================] - 46s 15s/step - loss: 0.0016 - accuracy: 0.9799
# TASK 21
# TASK 22
# TASK 23
# TASK 24
# TASK 25
# TASK 26
# TASK 27
# TASK 28
# TASK 29
# TASK 30
# Epoch 1/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.2357 - accuracy: 0.7135
# Epoch 2/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.1761 - accuracy: 0.8841
# Epoch 3/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0576 - accuracy: 0.9286
# Epoch 4/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0128 - accuracy: 0.9421
# Epoch 5/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0113 - accuracy: 0.9410
# Epoch 6/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0108 - accuracy: 0.9418
# Epoch 7/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0101 - accuracy: 0.9418
# Epoch 8/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0097 - accuracy: 0.9421
# Epoch 9/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0092 - accuracy: 0.9421
# Epoch 10/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0090 - accuracy: 0.9420
# Epoch 11/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0089 - accuracy: 0.9419
# Epoch 12/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0089 - accuracy: 0.9420
# Epoch 13/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0089 - accuracy: 0.9420
# TASK 31
# TASK 32
# TASK 33
# TASK 34
# TASK 35
# TASK 36
# TASK 37
# TASK 38
# TASK 39
# TASK 40
# Epoch 1/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.1878 - accuracy: 0.5616
# Epoch 2/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.1284 - accuracy: 0.6996
# Epoch 3/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0768 - accuracy: 0.7134
# Epoch 4/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0739 - accuracy: 0.7111
# Epoch 5/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0729 - accuracy: 0.7106
# Epoch 6/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0717 - accuracy: 0.7122
# Epoch 7/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0703 - accuracy: 0.7120
# Epoch 8/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0677 - accuracy: 0.7112
# TASK 41
# TASK 42
# TASK 43
# TASK 44
# TASK 45
# TASK 46
# TASK 47
# TASK 48
# TASK 49
# TASK 50
# Epoch 1/100
# 3/3 [==============================] - 17s 6s/step - loss: 0.2323 - accuracy: 0.6611
# Epoch 2/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.1690 - accuracy: 0.8688
# Epoch 3/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.0460 - accuracy: 0.9174
# Epoch 4/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.0152 - accuracy: 0.9245
# Epoch 5/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.0149 - accuracy: 0.9241
# Epoch 6/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.0147 - accuracy: 0.9244
# Epoch 7/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.0146 - accuracy: 0.9244
# Epoch 8/100
# 3/3 [==============================] - 18s 6s/step - loss: 0.0145 - accuracy: 0.9244
# Epoch 9/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.0145 - accuracy: 0.9245
# TASK 51
# TASK 52
# TASK 53
# TASK 54
# TASK 55
# TASK 56
# TASK 57
# TASK 58
# TASK 59
# TASK 60
# Epoch 1/100
# 4/4 [==============================] - 30s 8s/step - loss: 0.0679 - accuracy: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 30s 7s/step - loss: 0.0473 - accuracy: 0.0000e+00
# Epoch 3/100
# 4/4 [==============================] - 30s 8s/step - loss: 0.0425 - accuracy: 0.0000e+00
# Epoch 4/100
# 4/4 [==============================] - 30s 8s/step - loss: 0.0416 - accuracy: 0.0000e+00
# Epoch 5/100
# 4/4 [==============================] - 30s 8s/step - loss: 0.0407 - accuracy: 0.0000e+00
# Epoch 6/100
# 4/4 [==============================] - 30s 8s/step - loss: 0.0397 - accuracy: 0.0000e+00
# TASK 61
# TASK 62
# TASK 63
# TASK 64
# TASK 65
# TASK 66
# TASK 67
# TASK 68
# TASK 69
# TASK 70
# Epoch 1/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.2217 - accuracy: 0.5804
# Epoch 2/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.1857 - accuracy: 0.7902
# Epoch 3/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.0905 - accuracy: 0.8448
# Epoch 4/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.0297 - accuracy: 0.8626
# Epoch 5/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.0221 - accuracy: 0.8709
# Epoch 6/100
# 2/2 [==============================] - 13s 6s/step - loss: 0.0224 - accuracy: 0.8709
# Epoch 7/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.0224 - accuracy: 0.8707
# Epoch 8/100
# 2/2 [==============================] - 12s 6s/step - loss: 0.0223 - accuracy: 0.8709
# Epoch 9/100
# 2/2 [==============================] - 13s 6s/step - loss: 0.0222 - accuracy: 0.8709
# Epoch 10/100
# 2/2 [==============================] - 13s 7s/step - loss: 0.0221 - accuracy: 0.8709
# TASK 71
# TASK 72
# TASK 73
# TASK 74
# TASK 75
# TASK 76
# TASK 77
# TASK 78
# TASK 79
# TASK 80
# Epoch 1/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.2135 - accuracy: 0.5808
# Epoch 2/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1706 - accuracy: 0.7925
# Epoch 3/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1043 - accuracy: 0.7957
# Epoch 4/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0820 - accuracy: 0.7957
# Epoch 5/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0880 - accuracy: 0.7906
# Epoch 6/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0894 - accuracy: 0.7904
# Epoch 7/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0879 - accuracy: 0.7957
# Epoch 8/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0860 - accuracy: 0.7957
# TASK 81
# TASK 82
# TASK 83
# TASK 84
# TASK 85
# TASK 86
# TASK 87
# TASK 88
# TASK 89
# TASK 90
# Epoch 1/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.2124 - accuracy: 0.7093
# Epoch 2/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0732 - accuracy: 0.9051
# Epoch 3/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0177 - accuracy: 0.9305
# Epoch 4/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0168 - accuracy: 0.9304
# Epoch 5/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0161 - accuracy: 0.9323
# Epoch 6/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0162 - accuracy: 0.9334
# Epoch 7/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0160 - accuracy: 0.9323
# Epoch 8/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0157 - accuracy: 0.9336
# Epoch 9/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0156 - accuracy: 0.9329
# Epoch 10/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0154 - accuracy: 0.9335
# Epoch 11/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0155 - accuracy: 0.9339
# Epoch 12/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0151 - accuracy: 0.9340
# Epoch 13/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0150 - accuracy: 0.9334
# Epoch 14/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0146 - accuracy: 0.9348
# Epoch 15/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0145 - accuracy: 0.9345
# Epoch 16/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0143 - accuracy: 0.9346
# Epoch 17/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0141 - accuracy: 0.9348
# Epoch 18/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0140 - accuracy: 0.9351
# Epoch 19/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0139 - accuracy: 0.9351
# Epoch 20/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0137 - accuracy: 0.9352
# Epoch 21/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0136 - accuracy: 0.9352
# Epoch 22/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0135 - accuracy: 0.9353
# Epoch 23/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0134 - accuracy: 0.9353
# Epoch 24/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0134 - accuracy: 0.9353
# Epoch 25/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0133 - accuracy: 0.9353
# Epoch 26/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0132 - accuracy: 0.9353
# Epoch 27/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0131 - accuracy: 0.9353
# Epoch 28/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0130 - accuracy: 0.9353
# TASK 91
# TASK 92
# TASK 93
# TASK 94
# TASK 95
# TASK 96
# TASK 97
# TASK 98
# TASK 99
# TASK 100
# Epoch 1/100
# 3/3 [==============================] - 31s 10s/step - loss: 0.2405 - accuracy: 0.6645
# Epoch 2/100
# 3/3 [==============================] - 31s 10s/step - loss: 0.2034 - accuracy: 0.8478
# Epoch 3/100
# 3/3 [==============================] - 30s 10s/step - loss: 0.0587 - accuracy: 0.9117
# Epoch 4/100
# 3/3 [==============================] - 30s 10s/step - loss: 0.0030 - accuracy: 0.9292
# Epoch 5/100
# 3/3 [==============================] - 31s 10s/step - loss: 0.0013 - accuracy: 0.9303
# Epoch 6/100
# 3/3 [==============================] - 30s 10s/step - loss: 0.0013 - accuracy: 0.9303
# Epoch 7/100
# 3/3 [==============================] - 30s 10s/step - loss: 0.0013 - accuracy: 0.9303
# Epoch 8/100
# 3/3 [==============================] - 30s 10s/step - loss: 0.0013 - accuracy: 0.9303
# Epoch 9/100
# 3/3 [==============================] - 30s 10s/step - loss: 0.0013 - accuracy: 0.9303
# Epoch 10/100
# 3/3 [==============================] - 31s 10s/step - loss: 0.0013 - accuracy: 0.9303
# TASK 101
# TASK 102
# TASK 103
# TASK 104
# TASK 105
# TASK 106
# TASK 107
# TASK 108
# TASK 109
# TASK 110
# Epoch 1/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.2338 - accuracy: 0.7561
# Epoch 2/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.1581 - accuracy: 0.9274
# Epoch 3/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0310 - accuracy: 0.9500
# Epoch 4/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0032 - accuracy: 0.9500
# Epoch 5/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - accuracy: 0.9500
# Epoch 6/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - accuracy: 0.9500
# Epoch 7/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - accuracy: 0.9500
# Epoch 8/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0030 - accuracy: 0.9500
# TASK 111
# TASK 112
# TASK 113
# TASK 114
# TASK 115
# TASK 116
# TASK 117
# TASK 118
# TASK 119
# TASK 120
# Epoch 1/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.2317 - accuracy: 0.7518
# Epoch 2/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.1207 - accuracy: 0.9314
# Epoch 3/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0110 - accuracy: 0.9645
# Epoch 4/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0026 - accuracy: 0.9665
# Epoch 5/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0026 - accuracy: 0.9660
# Epoch 6/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0026 - accuracy: 0.9665
# Epoch 7/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0026 - accuracy: 0.9665
# Epoch 8/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0029 - accuracy: 0.9660
# Epoch 9/100
# 3/3 [==============================] - 14s 5s/step - loss: 0.0029 - accuracy: 0.9665
# TASK 121
# TASK 122
# TASK 123
# TASK 124
# TASK 125
# TASK 126
# TASK 127
# TASK 128
# TASK 129
# TASK 130
# Epoch 1/100
# 3/3 [==============================] - 23s 7s/step - loss: 0.2365 - accuracy: 0.6802
# Epoch 2/100
# 3/3 [==============================] - 22s 7s/step - loss: 0.1907 - accuracy: 0.8858
# Epoch 3/100
# 3/3 [==============================] - 22s 7s/step - loss: 0.0526 - accuracy: 0.9331
# Epoch 4/100
# 3/3 [==============================] - 22s 7s/step - loss: 0.0126 - accuracy: 0.9424
# Epoch 5/100
# 3/3 [==============================] - 22s 7s/step - loss: 0.0124 - accuracy: 0.9424
# Epoch 6/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.0124 - accuracy: 0.9424
# Epoch 7/100
# 3/3 [==============================] - 22s 7s/step - loss: 0.0124 - accuracy: 0.9424
# Epoch 8/100
# 3/3 [==============================] - 22s 7s/step - loss: 0.0124 - accuracy: 0.9424
# Epoch 9/100
# 3/3 [==============================] - 22s 7s/step - loss: 0.0124 - accuracy: 0.9424
# TASK 131
# TASK 132
# TASK 133
# TASK 134
# TASK 135
# TASK 136
# TASK 137
# TASK 138
# TASK 139
# TASK 140
# Epoch 1/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.2379 - accuracy: 0.6573
# Epoch 2/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.2214 - accuracy: 0.8622
# Epoch 3/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.1224 - accuracy: 0.9153
# Epoch 4/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.0276 - accuracy: 0.9350
# Epoch 5/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.0209 - accuracy: 0.9389
# Epoch 6/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.0209 - accuracy: 0.9389
# Epoch 7/100
# 3/3 [==============================] - 22s 7s/step - loss: 0.0209 - accuracy: 0.9389
# Epoch 8/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.0209 - accuracy: 0.9389
# Epoch 9/100
# 3/3 [==============================] - 21s 7s/step - loss: 0.0209 - accuracy: 0.9389
# Epoch 10/100
# 3/3 [==============================] - 22s 7s/step - loss: 0.0209 - accuracy: 0.9389
# TASK 141
# TASK 142
# TASK 143
# TASK 144
# TASK 145
# TASK 146
# TASK 147
# TASK 148
# TASK 149
# TASK 150
# Epoch 1/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.2174 - accuracy: 0.6810
# Epoch 2/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.1354 - accuracy: 0.8719
# Epoch 3/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0432 - accuracy: 0.8910
# Epoch 4/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0259 - accuracy: 0.8957
# Epoch 5/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0253 - accuracy: 0.8946
# Epoch 6/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0244 - accuracy: 0.8945
# Epoch 7/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0236 - accuracy: 0.8942
# Epoch 8/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0233 - accuracy: 0.8952
# Epoch 9/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0230 - accuracy: 0.8952
# TASK 151
# TASK 152
# TASK 153
# TASK 154
# TASK 155
# TASK 156
# TASK 157
# TASK 158
# TASK 159
# TASK 160
# Epoch 1/100
# 3/3 [==============================] - 32s 11s/step - loss: 0.2278 - accuracy: 0.6388
# Epoch 2/100
# 3/3 [==============================] - 31s 10s/step - loss: 0.1119 - accuracy: 0.8670
# Epoch 3/100
# 3/3 [==============================] - 32s 11s/step - loss: 0.0205 - accuracy: 0.9260
# Epoch 4/100
# 3/3 [==============================] - 32s 11s/step - loss: 0.0167 - accuracy: 0.9291
# Epoch 5/100
# 3/3 [==============================] - 31s 10s/step - loss: 0.0167 - accuracy: 0.9291
# Epoch 6/100
# 3/3 [==============================] - 31s 10s/step - loss: 0.0167 - accuracy: 0.9291
# Epoch 7/100
# 3/3 [==============================] - 31s 10s/step - loss: 0.0167 - accuracy: 0.9291
# Epoch 8/100
# 3/3 [==============================] - 31s 11s/step - loss: 0.0167 - accuracy: 0.9291
# Epoch 9/100
# 3/3 [==============================] - 31s 10s/step - loss: 0.0167 - accuracy: 0.9291
# TASK 161
# TASK 162
# TASK 163
# TASK 164
# TASK 165
# TASK 166
# TASK 167
# TASK 168
# TASK 169
# TASK 170
# Epoch 1/100
# 4/4 [==============================] - 6s 1s/step - loss: 0.2089 - accuracy: 0.7392
# Epoch 2/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.2082 - accuracy: 0.7374
# Epoch 3/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.2075 - accuracy: 0.7374
# Epoch 4/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.2068 - accuracy: 0.7374
# Epoch 5/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.2061 - accuracy: 0.7374
# Epoch 6/100
# 4/4 [==============================] - 5s 1s/step - loss: 0.2054 - accuracy: 0.7374
# TASK 171
# TASK 172
# TASK 173
# TASK 174
# TASK 175
# TASK 176
# TASK 177
# TASK 178
# TASK 179
# TASK 180
# Epoch 1/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.1995 - accuracy: 0.6365
# Epoch 2/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.1155 - accuracy: 0.7837
# Epoch 3/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0716 - accuracy: 0.8066
# Epoch 4/100
# 3/3 [==============================] - 6s 2s/step - loss: 0.0714 - accuracy: 0.8048
# Epoch 5/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0678 - accuracy: 0.7993
# Epoch 6/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0645 - accuracy: 0.8045
# Epoch 7/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0615 - accuracy: 0.8021
# Epoch 8/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0588 - accuracy: 0.8019
# TASK 181
# TASK 182
# TASK 183
# TASK 184
# TASK 185
# TASK 186
# TASK 187
# TASK 188
# TASK 189
# TASK 190
# Epoch 1/100
# 4/4 [==============================] - 48s 12s/step - loss: 0.2075 - accuracy: 0.6273
# Epoch 2/100
# 4/4 [==============================] - 51s 13s/step - loss: 0.0564 - accuracy: 0.8134
# Epoch 3/100
# 4/4 [==============================] - 49s 12s/step - loss: 0.0126 - accuracy: 0.8529
# Epoch 4/100
# 4/4 [==============================] - 50s 12s/step - loss: 0.0123 - accuracy: 0.8530
# Epoch 5/100
# 4/4 [==============================] - 48s 12s/step - loss: 0.0108 - accuracy: 0.8542
# Epoch 6/100
# 4/4 [==============================] - 49s 12s/step - loss: 0.0107 - accuracy: 0.8546
# Epoch 7/100
# 4/4 [==============================] - 48s 12s/step - loss: 0.0107 - accuracy: 0.8546
# Epoch 8/100
# 4/4 [==============================] - 48s 12s/step - loss: 0.0107 - accuracy: 0.8546
# Epoch 9/100
# 4/4 [==============================] - 48s 12s/step - loss: 0.0107 - accuracy: 0.8546
# Epoch 10/100
# 4/4 [==============================] - 49s 12s/step - loss: 0.0107 - accuracy: 0.8546
# Epoch 11/100
# 4/4 [==============================] - 49s 12s/step - loss: 0.0107 - accuracy: 0.8546
# TASK 191
# TASK 192
# TASK 193
# TASK 194
# TASK 195
# TASK 196
# TASK 197
# TASK 198
# TASK 199
# TASK 200
# Epoch 1/100
# 4/4 [==============================] - 22s 5s/step - loss: 0.2020 - accuracy: 0.7104
# Epoch 2/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0631 - accuracy: 0.8581
# Epoch 3/100
# 4/4 [==============================] - 23s 6s/step - loss: 0.0274 - accuracy: 0.8688
# Epoch 4/100
# 4/4 [==============================] - 23s 6s/step - loss: 0.0278 - accuracy: 0.8688
# Epoch 5/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0280 - accuracy: 0.8683
# Epoch 6/100
# 4/4 [==============================] - 21s 5s/step - loss: 0.0283 - accuracy: 0.8681
# Epoch 7/100
# 4/4 [==============================] - 21s 5s/step - loss: 0.0282 - accuracy: 0.8680
# Epoch 8/100
# 4/4 [==============================] - 23s 5s/step - loss: 0.0280 - accuracy: 0.8682
# Epoch 9/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0277 - accuracy: 0.8688
# TASK 201
# TASK 202
# TASK 203
# TASK 204
# TASK 205
# TASK 206
# TASK 207
# TASK 208
# TASK 209
# TASK 210
# Epoch 1/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.2102 - accuracy: 0.6497
# Epoch 2/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.1808 - accuracy: 0.7833
# Epoch 3/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0963 - accuracy: 0.7997
# Epoch 4/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0450 - accuracy: 0.8031
# Epoch 5/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0463 - accuracy: 0.8031
# Epoch 6/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0461 - accuracy: 0.8031
# Epoch 7/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0451 - accuracy: 0.8031
# Epoch 8/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0448 - accuracy: 0.8031
# Epoch 9/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0441 - accuracy: 0.8031
# TASK 211
# TASK 212
# TASK 213
# TASK 214
# TASK 215
# TASK 216
# TASK 217
# TASK 218
# TASK 219
# TASK 220
# Epoch 1/100
# 4/4 [==============================] - 46s 11s/step - loss: 0.2365 - accuracy: 0.7196
# Epoch 2/100
# 4/4 [==============================] - 46s 11s/step - loss: 0.1770 - accuracy: 0.8928
# Epoch 3/100
# 4/4 [==============================] - 46s 11s/step - loss: 0.0274 - accuracy: 0.9463
# Epoch 4/100
# 4/4 [==============================] - 51s 13s/step - loss: 0.0086 - accuracy: 0.9513
# Epoch 5/100
# 4/4 [==============================] - 46s 12s/step - loss: 0.0086 - accuracy: 0.9513
# Epoch 6/100
# 4/4 [==============================] - 46s 12s/step - loss: 0.0086 - accuracy: 0.9513
# Epoch 7/100
# 4/4 [==============================] - 46s 12s/step - loss: 0.0086 - accuracy: 0.9513
# Epoch 8/100
# 4/4 [==============================] - 46s 12s/step - loss: 0.0086 - accuracy: 0.9513
# Epoch 9/100
# 4/4 [==============================] - 45s 11s/step - loss: 0.0086 - accuracy: 0.9513
# TASK 221
# TASK 222
# TASK 223
# TASK 224
# TASK 225
# TASK 226
# TASK 227
# TASK 228
# TASK 229
# TASK 230
# Epoch 1/100
# 3/3 [==============================] - 26s 9s/step - loss: 0.2366 - accuracy: 0.6367
# Epoch 2/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.2061 - accuracy: 0.8433
# Epoch 3/100
# 3/3 [==============================] - 26s 9s/step - loss: 0.0873 - accuracy: 0.9123
# Epoch 4/100
# 3/3 [==============================] - 26s 8s/step - loss: 0.0132 - accuracy: 0.9276
# Epoch 5/100
# 3/3 [==============================] - 25s 8s/step - loss: 0.0101 - accuracy: 0.9279
# Epoch 6/100
# 3/3 [==============================] - 26s 9s/step - loss: 0.0102 - accuracy: 0.9279
# Epoch 7/100
# 3/3 [==============================] - 25s 8s/step - loss: 0.0101 - accuracy: 0.9279
# Epoch 8/100
# 3/3 [==============================] - 26s 9s/step - loss: 0.0101 - accuracy: 0.9279
# Epoch 9/100
# 3/3 [==============================] - 25s 8s/step - loss: 0.0101 - accuracy: 0.9279
# Epoch 10/100
# 3/3 [==============================] - 26s 9s/step - loss: 0.0101 - accuracy: 0.9279
# TASK 231
# TASK 232
# TASK 233
# TASK 234
# TASK 235
# TASK 236
# TASK 237
# TASK 238
# TASK 239
# TASK 240
# Epoch 1/100
# 3/3 [==============================] - 3s 964ms/step - loss: 0.1975 - accuracy: 0.6198
# Epoch 2/100
# 3/3 [==============================] - 3s 961ms/step - loss: 0.1409 - accuracy: 0.7721
# Epoch 3/100
# 3/3 [==============================] - 3s 963ms/step - loss: 0.0630 - accuracy: 0.8054
# Epoch 4/100
# 3/3 [==============================] - 3s 957ms/step - loss: 0.0427 - accuracy: 0.8054
# Epoch 5/100
# 3/3 [==============================] - 3s 969ms/step - loss: 0.0421 - accuracy: 0.8054
# Epoch 6/100
# 3/3 [==============================] - 3s 934ms/step - loss: 0.0422 - accuracy: 0.8043
# Epoch 7/100
# 3/3 [==============================] - 3s 949ms/step - loss: 0.0416 - accuracy: 0.8054
# Epoch 8/100
# 3/3 [==============================] - 3s 949ms/step - loss: 0.0399 - accuracy: 0.8043
# TASK 241
# TASK 242
# TASK 243
# TASK 244
# TASK 245
# TASK 246
# TASK 247
# TASK 248
# TASK 249
# TASK 250
# Epoch 1/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.2039 - accuracy: 0.5475
# Epoch 2/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.1427 - accuracy: 0.6888
# Epoch 3/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0286 - accuracy: 0.7073
# Epoch 4/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0086 - accuracy: 0.7093
# Epoch 5/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0090 - accuracy: 0.7093
# Epoch 6/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0090 - accuracy: 0.7093
# Epoch 7/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0090 - accuracy: 0.7093
# Epoch 8/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0090 - accuracy: 0.7093
# Epoch 9/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0090 - accuracy: 0.7093
# TASK 251
# TASK 252
# TASK 253
# TASK 254
# TASK 255
# TASK 256
# TASK 257
# TASK 258
# TASK 259
# TASK 260
# Epoch 1/100
# 3/3 [==============================] - 3s 913ms/step - loss: 0.2185 - accuracy: 0.7042
# Epoch 2/100
# 3/3 [==============================] - 3s 925ms/step - loss: 0.1340 - accuracy: 0.8938
# Epoch 3/100
# 3/3 [==============================] - 3s 914ms/step - loss: 0.0297 - accuracy: 0.8938
# Epoch 4/100
# 3/3 [==============================] - 3s 927ms/step - loss: 0.0052 - accuracy: 0.8938
# Epoch 5/100
# 3/3 [==============================] - 3s 919ms/step - loss: 0.0042 - accuracy: 0.8938
# Epoch 6/100
# 3/3 [==============================] - 3s 937ms/step - loss: 0.0042 - accuracy: 0.8938
# Epoch 7/100
# 3/3 [==============================] - 3s 978ms/step - loss: 0.0042 - accuracy: 0.8938
# TASK 261
# TASK 262
# TASK 263
# TASK 264
# TASK 265
# TASK 266
# TASK 267
# TASK 268
# TASK 269
# TASK 270
# Epoch 1/100
# 4/4 [==============================] - 10s 2s/step - loss: 0.1822 - accuracy: 0.7640
# Epoch 2/100
# 4/4 [==============================] - 9s 2s/step - loss: 0.0283 - accuracy: 0.8889
# Epoch 3/100
# 4/4 [==============================] - 9s 2s/step - loss: 0.0147 - accuracy: 0.8889
# Epoch 4/100
# 4/4 [==============================] - 9s 2s/step - loss: 0.0143 - accuracy: 0.8889
# Epoch 5/100
# 4/4 [==============================] - 9s 2s/step - loss: 0.0117 - accuracy: 0.8889
# Epoch 6/100
# 4/4 [==============================] - 9s 2s/step - loss: 0.0102 - accuracy: 0.8889
# Epoch 7/100
# 4/4 [==============================] - 9s 2s/step - loss: 0.0089 - accuracy: 0.8889
# TASK 271
# TASK 272
# TASK 273
# TASK 274
# TASK 275
# TASK 276
# TASK 277
# TASK 278
# TASK 279
# TASK 280
# Epoch 1/100
# 3/3 [==============================] - 18s 7s/step - loss: 0.2052 - accuracy: 0.5979
# Epoch 2/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.1271 - accuracy: 0.7572
# Epoch 3/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0279 - accuracy: 0.7670
# Epoch 4/100
# 3/3 [==============================] - 17s 6s/step - loss: 0.0226 - accuracy: 0.7688
# Epoch 5/100
# 3/3 [==============================] - 15s 5s/step - loss: 0.0230 - accuracy: 0.7688
# Epoch 6/100
# 3/3 [==============================] - 17s 6s/step - loss: 0.0230 - accuracy: 0.7688
# Epoch 7/100
# 3/3 [==============================] - 18s 5s/step - loss: 0.0230 - accuracy: 0.7688
# Epoch 8/100
# 3/3 [==============================] - 19s 6s/step - loss: 0.0230 - accuracy: 0.7688
# Epoch 9/100
# 3/3 [==============================] - 16s 5s/step - loss: 0.0230 - accuracy: 0.7688
# TASK 281
# TASK 282
# TASK 283
# TASK 284
# TASK 285
# TASK 286
# TASK 287
# TASK 288
# TASK 289
# TASK 290
# Epoch 1/100
# 3/3 [==============================] - 27s 9s/step - loss: 0.2300 - accuracy: 0.7273
# Epoch 2/100
# 3/3 [==============================] - 25s 8s/step - loss: 0.0870 - accuracy: 0.9281
# Epoch 3/100
# 3/3 [==============================] - 25s 8s/step - loss: 0.0058 - accuracy: 0.9903
# Epoch 4/100
# 3/3 [==============================] - 25s 8s/step - loss: 1.2132e-04 - accuracy: 0.9965
# Epoch 5/100
# 3/3 [==============================] - 25s 8s/step - loss: 1.7642e-04 - accuracy: 0.9965
# Epoch 6/100
# 3/3 [==============================] - 25s 8s/step - loss: 2.5566e-04 - accuracy: 0.9965
# Epoch 7/100
# 3/3 [==============================] - 26s 9s/step - loss: 2.6217e-04 - accuracy: 0.9965
# Epoch 8/100
# 3/3 [==============================] - 26s 9s/step - loss: 1.9346e-04 - accuracy: 0.9965
# Epoch 9/100
# 3/3 [==============================] - 25s 9s/step - loss: 2.0936e-04 - accuracy: 0.9965
# TASK 291
# TASK 292
# TASK 293
# TASK 294
# TASK 295
# TASK 296
# TASK 297
# TASK 298
# TASK 299
# TASK 300
# Epoch 1/100
# 3/3 [==============================] - 12s 4s/step - loss: 0.2189 - accuracy: 0.6548
# Epoch 2/100
# 3/3 [==============================] - 11s 4s/step - loss: 0.1507 - accuracy: 0.8444
# Epoch 3/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0568 - accuracy: 0.8743
# Epoch 4/100
# 3/3 [==============================] - 11s 4s/step - loss: 0.0360 - accuracy: 0.8760
# Epoch 5/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0355 - accuracy: 0.8771
# Epoch 6/100
# 3/3 [==============================] - 11s 4s/step - loss: 0.0348 - accuracy: 0.8751
# Epoch 7/100
# 3/3 [==============================] - 12s 4s/step - loss: 0.0344 - accuracy: 0.8751
# Epoch 8/100
# 3/3 [==============================] - 11s 4s/step - loss: 0.0347 - accuracy: 0.8752
# Epoch 9/100
# 3/3 [==============================] - 10s 4s/step - loss: 0.0339 - accuracy: 0.8759
# Epoch 10/100
# 3/3 [==============================] - 11s 3s/step - loss: 0.0331 - accuracy: 0.8746
# TASK 301
# TASK 302
# TASK 303
# TASK 304
# TASK 305
# TASK 306
# TASK 307
# TASK 308
# TASK 309
# TASK 310
# Epoch 1/100
# 3/3 [==============================] - 4s 933ms/step - loss: 0.2123 - accuracy: 0.7619
# Epoch 2/100
# 3/3 [==============================] - 3s 972ms/step - loss: 0.1567 - accuracy: 0.8709
# Epoch 3/100
# 3/3 [==============================] - 3s 887ms/step - loss: 0.0743 - accuracy: 0.8709
# Epoch 4/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0547 - accuracy: 0.8709
# Epoch 5/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0555 - accuracy: 0.8587
# Epoch 6/100
# 3/3 [==============================] - 3s 935ms/step - loss: 0.0541 - accuracy: 0.8709
# Epoch 7/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0526 - accuracy: 0.8709
# TASK 311
# TASK 312
# TASK 313
# TASK 314
# TASK 315
# TASK 316
# TASK 317
# TASK 318
# TASK 319
# TASK 320
# Epoch 1/100
# 5/5 [==============================] - 62s 12s/step - loss: 0.1892 - accuracy: 0.7777
# Epoch 2/100
# 5/5 [==============================] - 58s 12s/step - loss: 0.0244 - accuracy: 0.9199
# Epoch 3/100
# 5/5 [==============================] - 57s 11s/step - loss: 0.0087 - accuracy: 0.9292
# Epoch 4/100
# 5/5 [==============================] - 51s 10s/step - loss: 0.0079 - accuracy: 0.9302
# Epoch 5/100
# 5/5 [==============================] - 42s 8s/step - loss: 0.0074 - accuracy: 0.9300
# Epoch 6/100
# 5/5 [==============================] - 44s 9s/step - loss: 0.0068 - accuracy: 0.9299
# Epoch 7/100
# 5/5 [==============================] - 45s 9s/step - loss: 0.0063 - accuracy: 0.9304
# Epoch 8/100
# 5/5 [==============================] - 46s 9s/step - loss: 0.0059 - accuracy: 0.9307
# Epoch 9/100
# 5/5 [==============================] - 45s 9s/step - loss: 0.0056 - accuracy: 0.9310
# Epoch 10/100
# 5/5 [==============================] - 43s 9s/step - loss: 0.0054 - accuracy: 0.9311
# Epoch 11/100
# 5/5 [==============================] - 43s 9s/step - loss: 0.0052 - accuracy: 0.9312
# Epoch 12/100
# 5/5 [==============================] - 44s 9s/step - loss: 0.0050 - accuracy: 0.9313
# Epoch 13/100
# 5/5 [==============================] - 43s 9s/step - loss: 0.0049 - accuracy: 0.9314
# Epoch 14/100
# 5/5 [==============================] - 41s 8s/step - loss: 0.0047 - accuracy: 0.9315
# Epoch 15/100
# 5/5 [==============================] - 45s 9s/step - loss: 0.0046 - accuracy: 0.9314
# Epoch 16/100
# 5/5 [==============================] - 44s 9s/step - loss: 0.0046 - accuracy: 0.9313
# Epoch 17/100
# 5/5 [==============================] - 43s 8s/step - loss: 0.0044 - accuracy: 0.9314
# Epoch 18/100
# 5/5 [==============================] - 46s 9s/step - loss: 0.0042 - accuracy: 0.9315
# Epoch 19/100
# 5/5 [==============================] - 44s 9s/step - loss: 0.0040 - accuracy: 0.9315
# TASK 321
# TASK 322
# TASK 323
# TASK 324
# TASK 325
# TASK 326
# TASK 327
# TASK 328
# TASK 329
# TASK 330
# Epoch 1/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.2091 - accuracy: 0.5381
# Epoch 2/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.2040 - accuracy: 0.7246
# Epoch 3/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.1848 - accuracy: 0.7505
# Epoch 4/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.1357 - accuracy: 0.7521
# Epoch 5/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0759 - accuracy: 0.7600
# Epoch 6/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0632 - accuracy: 0.7600
# Epoch 7/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0681 - accuracy: 0.7600
# Epoch 8/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0698 - accuracy: 0.7600
# Epoch 9/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0700 - accuracy: 0.7600
# Epoch 10/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0699 - accuracy: 0.7600
# TASK 331
# TASK 332
# TASK 333
# TASK 334
# TASK 335
# TASK 336
# TASK 337
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-df379bad02ca> in <module>
#      47     pred_train = (decoded_imgs_train.reshape(outp_shape[0:2]))*10
#      48
# ---> 49     encoded_imgs_test = base_model.encoder(Xs_test_aug[idx][:1]).numpy()
#      50     decoded_imgs_test = base_model.decoder(encoded_imgs_test).numpy()
#      51
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     976     if any(isinstance(x, (
#     977         np_arrays.ndarray, np.ndarray, float, int)) for x in input_list):
# --> 978       inputs = nest.map_structure(_convert_numpy_or_python_types, inputs)
#     979       input_list = nest.flatten(inputs)
#     980
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in _convert_numpy_or_python_types(x)
#    3226 def _convert_numpy_or_python_types(x):
#    3227   if isinstance(x, (np_arrays.ndarray, np.ndarray, float, int)):
# -> 3228     return ops.convert_to_tensor_v2_with_dispatch(x)
#    3229   return x
#    3230
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1429   """
#    1430   return convert_to_tensor_v2(
# -> 1431       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#    1432
#    1433
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1439       name=name,
#    1440       preferred_dtype=dtype_hint,
# -> 1441       as_ref=False)
#    1442
#    1443
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     263   """
#     264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 265                         allow_broadcast=True)
#     266
#     267
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type numpy.ndarray).

# %%
base_model.encoder.summary()

# %%
base_model.decoder.summary()

# %% [markdown]
# ## PLOT PREDICTIONS

# %%
x = 40

# %%
cmap = colors.ListedColormap(
            ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
             '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
norm = colors.Normalize(vmin=0, vmax=9)
fig, ax = plt.subplots(1, 5, figsize=(20,20))
for idx in range(x,x+1,20):
  
    ax[0].imshow((Xs_train_aug[idx][0])*10, cmap=cmap, norm=norm)
    ax[0].set_title(f'Train Input {idx}')
    ax[1].imshow((ys_train_aug[idx][0])*10, cmap=cmap, norm=norm)
    ax[1].set_title(f'Train output {idx}')
    ax[2].imshow((pred_train_li[idx]), cmap=cmap, norm=norm)
    ax[2].set_title(f'Train Prediction {idx}')       
    ax[3].imshow((Xs_test_aug[idx][0])*10, cmap=cmap, norm=norm)
    ax[3].set_title(f'Test Input {idx}')
    ax[4].imshow(pred_test_li[idx], cmap=cmap, norm=norm)
    ax[4].set_title(f'Test Prediction {idx}')
