# %% [markdown]
# NEW NEW NEW
# - new color definition
# - reduced amount of times random method is executed
# - class Autoencoder(Model): included input_shape and output_shape
# - loooooops

# %%
import numpy as np
import pandas as pd
import random 
from random import randint
import time

import os
import json
from pathlib import Path

import tensorflow.keras as keras
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras import layers
#from tensorflow.keras.datasets import mnist
from tensorflow.keras import backend as K
#from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt
from matplotlib import colors

# %%
data_path = Path('./kaggle_input/')
training_path = data_path / 'training'      # 400 X-train ('train'), y-train('test') input-output pairs
evaluation_path = data_path / 'evaluation'  # 400
test_path = data_path / 'test'              # 100 pairs X-train ('train') (input-output),
                                            #           y-train (input only) pairs

training_tasks_files = sorted(os.listdir(training_path))#[1:]
eval_tasks_files = sorted(os.listdir(evaluation_path))
test_task_files = sorted(os.listdir(test_path))

# %%
def load_files(path):
    path_files = sorted(os.listdir(path))
    tasks = []
    for task_file in path_files:
        with open(str(path / task_file), 'r') as f:
            task = json.load(f)
            tasks.append(task)
    return tasks

# %%
training_tasks = load_files(training_path)          ### this is for building / training the algorithm
test_tasks = load_files(test_path)                  ### this is the input for the actual prediction!!!
evaluation_tasks = load_files(evaluation_path)      ### testing the algorithm

# %%
len(training_tasks), training_tasks[0]['test']
# Out:
# (400,
#  [{'input': [[7, 0, 7], [7, 0, 7], [7, 7, 0]],
#    'output': [[7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 7, 0, 0, 0, 0, 7, 7, 0],
#     [7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 7, 0, 0, 0, 0, 7, 7, 0],
#     [7, 0, 7, 7, 0, 7, 0, 0, 0],
#     [7, 0, 7, 7, 0, 7, 0, 0, 0],
#     [7, 7, 0, 7, 7, 0, 0, 0, 0]]}])

# %%
len(evaluation_tasks), evaluation_tasks[0]['test']
# Out:
# (400,
#  [{'input': [[3, 2], [7, 8]],
#    'output': [[3, 2, 3, 2, 3, 2],
#     [7, 8, 7, 8, 7, 8],
#     [2, 3, 2, 3, 2, 3],
#     [8, 7, 8, 7, 8, 7],
#     [3, 2, 3, 2, 3, 2],
#     [7, 8, 7, 8, 7, 8]]}])

# %%
len(test_tasks),test_tasks[0]['test']
# Out:
# (100, [{'input': [[3, 2], [7, 8]]}])

# %% [markdown]
#
#  ---
#  ---

# %% [markdown]
# ### 1. Create Train - Test - Split

# %%
def tts(input_list):
    Xs_test, ys_test, Xs_train, ys_train = [], [], [], []

    for task in input_list:
        X_test, y_test, X_train, y_train = [], [], [], []

        for pair in task["test"]:
            X_test.append(pair["input"])
            y_test.append(pair["output"])      ### to be predicted !!!

        for pair in task["train"]:
            X_train.append(pair["input"])
            y_train.append(pair["output"])

        Xs_test.append(X_test)
        ys_test.append(y_test)
        Xs_train.append(X_train)
        ys_train.append(y_train)
    return Xs_test, ys_test, Xs_train, ys_train

# %% [markdown]
#
# #### Create origanl sized Train-Test-Split for reference

# %%
Xs_test_orig, ys_test_orig, Xs_train_orig, ys_train_orig = tts(training_tasks)

# %%
len(Xs_train_orig), len(ys_train_orig), len(Xs_test_orig), len(ys_test_orig)
# Out:
# (400, 400, 400, 400)

# %%
len(Xs_train_orig[1]), len(ys_train_orig[1]), len(Xs_test_orig[1]), len(ys_test_orig[1])
# Out:
# (5, 5, 1, 1)

# %% [markdown]
#
# #### Create actual Train-Test-Split

# %%
Xs_test, ys_test, Xs_train, ys_train = tts(training_tasks)

# %%
len(Xs_train), len(ys_train), len(Xs_test), len(ys_test)
# Out:
# (400, 400, 400, 400)

# %%
len(Xs_train[1]), len(ys_train[1]), len(Xs_test[1]), len(ys_test[1])
# Out:
# (5, 5, 1, 1)

# %% [markdown]
# ## Data Augmentation of the training data

# %%
#### color
def color_change(arr):
    x = arr*3
#     x = x/(x.max()+0.1)
    x = np.interp(x, (0.3, 2.7), (0, 0.9))
    x = np.ndarray.round(x,1)
    return x

# %%
def augm(X_list, y_list):
    idx = 1
    X_list_new = []
    y_list_new = []
    
    for task_X, task_y in zip(X_list, y_list):
        task_li_x = []
        task_li_y = []
        print("TASK",idx)
        length = len(Xs_train_orig[idx-1])
#         print(length)
        max_li=[]
        for i in range(length):
            max_a = max(len(task_X[i]),len(task_X[i][0]))
            max_b = max(len(task_y[i]),len(task_y[i][0]))
            max_c = max(len(Xs_test[idx-1][0]),len(Xs_test[idx-1][0][0]))
            max_d = max(len(ys_test[idx-1][0]),len(ys_test[idx-1][0][0]))
            max_abcd = max(max_a,max_b, max_c, max_d)
            max_li.append(max_abcd)
#             print(f"max_a = max({len(task_X[i])},{len(task_X[i][0])})")
#             print(f"max_b = max({len(task_y[i])},{len(task_y[i][0])})")
#             print(max_int)
        max_int = max(max_li)
            
        for e_x,e_y in zip(task_X, task_y):
            e_x = (np.array(e_x))/10.     
            e_y = (np.array(e_y))/10.
#             print(e_x.shape,e_y.shape, max_int)
            e_x = np.pad(e_x, [(0, max_int-e_x.shape[0]), (0, max_int-e_x.shape[1])], mode='constant')
            e_y = np.pad(e_y, [(0, max_int-e_y.shape[0]), (0, max_int-e_y.shape[1])], mode='constant')
#             print(e_x.shape,e_y.shape, max_int, "\n")
            task_li_x.append(e_x.reshape(e_x.shape + (1,) ))
            task_li_y.append(e_y.reshape(e_y.shape + (1,) ))
        # ========================
         
        while len(task_li_x) < 50*length:    ###################
#             print(len(task_li_x))
            """
            choose a random method and append new array
            """
            i = randint(0,length-1) 
            new_x = (np.array(task_X[i]))/10.
#             print((new_x))
            new_y = (np.array(task_y[i]))/10.
            
            
            times = randint(1,5)
#             print(f"LENGTH: {len(task_X)} // INDEX: {i} // TIMES: {times}" )
            for j in range(times):
                
                method = random.choice([np.fliplr, np.flipud, np.rot90,color_change])
                new_x = method(new_x)
                new_y = method(new_y)

            new_x = np.pad(new_x, [(0, max_int-new_x.shape[0]), (0, max_int-new_x.shape[1])], mode='constant')

            new_y = np.pad(new_y, [(0, max_int-new_y.shape[0]), (0, max_int-new_y.shape[1])], mode='constant')

            
            task_li_x.append(new_x.reshape(new_x.shape + (1,) ))
            task_li_y.append(new_y.reshape(new_y.shape + (1,) ))
 
        X_list_new.append(np.array(task_li_x))
        y_list_new.append(np.array(task_li_y))

        idx +=1
    return     X_list_new, y_list_new

# %%
# TASK 214
# TASK 215
# TASK 216
# TASK 217
# TASK 218
# TASK 219
# TASK 220
# TASK 221
# TASK 222
# TASK 223
# TASK 224
# TASK 225
# TASK 226
# TASK 227
# TASK 228
# TASK 229
# TASK 230
# TASK 231
# TASK 232
# TASK 233
# TASK 234
# TASK 235
# TASK 236
# TASK 237
# TASK 238
# TASK 239
# TASK 240
# TASK 241
# TASK 242
# TASK 243
# TASK 244
# TASK 245
# TASK 246
# TASK 247
# TASK 248
# TASK 249
# TASK 250
# TASK 251
# TASK 252
# TASK 253
# TASK 254
# TASK 255
# TASK 256
# TASK 257
# TASK 258
# TASK 259
# TASK 260
# TASK 261
# TASK 262
# TASK 263
# TASK 264
# TASK 265
# TASK 266
# TASK 267
# TASK 268
# TASK 269
# TASK 270
# TASK 271
# TASK 272
# TASK 273
# TASK 274
# TASK 275
# TASK 276
# TASK 277
# TASK 278
# TASK 279
# TASK 280
# TASK 281
# TASK 282
# TASK 283
# TASK 284
# TASK 285
# TASK 286
# TASK 287
# TASK 288
# TASK 289
# TASK 290
# TASK 291
# TASK 292
# TASK 293
# TASK 294
# TASK 295
# TASK 296
# TASK 297
# TASK 298
# TASK 299
# TASK 300
# TASK 301
# TASK 302
# TASK 303
# TASK 304
# TASK 305
# TASK 306
# TASK 307
# TASK 308
# TASK 309
# TASK 310
# TASK 311
# TASK 312
# TASK 313
# TASK 314
# TASK 315
# TASK 316
# TASK 317
# TASK 318
# TASK 319
# TASK 320
# TASK 321
# TASK 322
# TASK 323
# TASK 324
# TASK 325
# TASK 326
# TASK 327
# TASK 328
# TASK 329
# TASK 330
# TASK 331
# TASK 332
# TASK 333
# TASK 334
# TASK 335
# TASK 336
# TASK 337
# TASK 338
# TASK 339
# TASK 340
# TASK 341
# TASK 342
# TASK 343
# TASK 344
# TASK 345
# TASK 346
# TASK 347
# TASK 348
# TASK 349
# TASK 350
# TASK 351
# TASK 352
# TASK 353
# TASK 354
# TASK 355
# TASK 356
# TASK 357
# TASK 358
# TASK 359
# TASK 360
# TASK 361
# TASK 362
# TASK 363
# TASK 364
# TASK 365
# TASK 366
# TASK 367
# TASK 368
# TASK 369
# TASK 370
# TASK 371
# TASK 372
# TASK 373
# TASK 374
# TASK 375
# TASK 376
# TASK 377
# TASK 378
# TASK 379
# TASK 380
# TASK 381
# TASK 382
# TASK 383
# TASK 384
# TASK 385
# TASK 386
# TASK 387
# TASK 388
# TASK 389
# TASK 390
# TASK 391
# TASK 392
# TASK 393
# TASK 394
# TASK 395
# TASK 396
# TASK 397
# TASK 398
# TASK 399
# TASK 400

# %%
# def augm(X_list, y_list):
#     start = time.time()
# #     idx = 1
#     X_list_new = []
#     y_list_new = []
    
#     for task_X, task_y in zip(X_list, y_list):
# #         print(f"TASK {idx}")
#         task_x_li = []
#         task_y_li = []
        
#         for e_x, e_y in zip(task_X, task_y):
            
#             new_x = (np.array(e_x))/10.     
#             e_x_li = []
# #             e_x_li.append(new_x.reshape(new_x.shape + (1,) ))
            
#             new_y = (np.array(e_y))/10.
#             e_y_li = []
# #             e_y_li.append(new_y.reshape(new_y.shape + (1,) ))

#             max_int = max(max(new_x.shape),max(new_y.shape)) 
            
#             while len(e_x_li) < 500:                                      ###############
#                 """
#                 choose a random method and append new array
#                 """
#                 if len(e_x_li) > 0:
                    
#                     times = randint(1,4)
#                     for j in range(times):

#                         method = random.choice([np.fliplr, np.flipud, np.rot90])#,color_change])
#                         new_x = method(new_x)
#                         new_y = method(new_y)
                
#                 new_x = np.pad(new_x, [(0, max_int-new_x.shape[0]), (0, max_int-new_x.shape[1])], mode='constant')
# #                 new_x = new_x/10.
#                 new_y = np.pad(new_y, [(0, max_int-new_y.shape[0]), (0, max_int-new_y.shape[1])], mode='constant')
# #                 new_y = new_y/10.
                
#                 e_x_li.append(new_x.reshape(new_x.shape + (1,) ))
#                 e_y_li.append(new_y.reshape(new_y.shape + (1,) ))
                
#             task_x_li.append(np.array(e_x_li))
#             task_y_li.append(np.array(e_y_li))
            
#         X_list_new.append(task_x_li)
#         y_list_new.append(task_y_li)
            
# #         idx +=1
#     end = time.time()
 
#     print("Total time: " + str(np.round(end - start, 1)) + " s" + "\n")
#     return X_list_new, y_list_new

# %%
type(Xs_train_aug),len(Xs_train_aug)   ### number of Tasks
# Out:
# (list, 400)

# %%
type(Xs_train_aug[0]),len(Xs_train_aug[0]) ### number of sets
# Out:
# (numpy.ndarray, 250)

# %%
type(Xs_train_aug[0][0]),Xs_train_aug[0][0].shape ### number of inputs (pairs)
# Out:
# (numpy.ndarray, (9, 9, 1))

# %% [markdown]
# #### format test data

# %%
def t2l(X_list, y_list):
    li_x =[]
    li_y =[]
    idx = 0
    for task_x, task_y in zip(X_list, y_list):
#         print("TASK", idx)
        task_x_arr = np.array(task_x)
        task_y_arr = np.array(task_y)
        li2_x = []
        li2_y = []
        for e_x, e_y in zip(task_x_arr, task_y_arr):
            e_x = np.array(e_x)
            e_y = np.array(e_y)
            max_train = Xs_train_aug[idx].shape[1]
            max_int = max(max(e_x.shape),max(e_y.shape),max_train)
            
            
            e_x = np.pad(e_x, [(0, max_int-e_x.shape[0]), (0, max_int-e_x.shape[1])], mode='constant')
            e_x = e_x / 10.
            e_x = e_x.reshape(e_x.shape + (1,) )
#             print(e_x.shape, e_y.shape, max_int)
            e_y = np.pad(e_y, [(0, max_int-e_y.shape[0]), (0, max_int-e_y.shape[1])], mode='constant')
            e_y = e_y / 10.
            e_y = e_y.reshape(e_y.shape + (1,) )
#             print(e_x.shape, e_y.shape, "\n")
            li2_x.append(e_x)
            li2_y.append(e_y)

#         lenght = len(Xs_train_aug[idx])
        
#         li_x.append([np.array(li2_x)])
#         li_y.append([np.array(li2_y)])
        
        li_x.append(np.array(li2_x))
        li_y.append(np.array(li2_y))
        idx += 1
    return li_x, li_y

# %%
Xs_test_aug, ys_test_aug = t2l(Xs_test, ys_test)
# Out:
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   import sys
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:34: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:35: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
type(Xs_train_aug), type(ys_train_aug),type(Xs_test_aug), type(ys_test_aug)
# Out:
# (list, list, list, list)

# %%
len(Xs_train_aug), len(ys_train_aug),len(Xs_test_aug), len(ys_test_aug)
# Out:
# (400, 400, 400, 400)

# %%
type(Xs_train_aug[0]), type(ys_train_aug[0]),type(Xs_test_aug[0]), type(ys_test_aug[0])
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
len(Xs_train_aug[0]), len(ys_train_aug[0]),len(Xs_test_aug[0]), len(ys_test_aug[0])
# Out:
# (250, 250, 1, 1)

# %%
Xs_train_aug[0].shape, ys_train_aug[0].shape,Xs_test_aug[0].shape, ys_test_aug[0].shape
# Out:
# ((250, 9, 9, 1), (250, 9, 9, 1), (1, 9, 9, 1), (1, 9, 9, 1))

# %%
type(Xs_train_aug[0][0]), type(ys_train_aug[0][0]),type(Xs_test_aug[0][0]), type(ys_test_aug[0][0])
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
Xs_train_aug[2][2].shape, ys_train_aug[2][2].shape, Xs_test_aug[2][0].shape, ys_test_aug[2][0].shape
# Out:
# ((9, 9, 1), (9, 9, 1), (9, 9, 1), (9, 9, 1))

# %% [markdown]
# ## Model comp

# %%
class Autoencoder(Model):
    def __init__(self, latent_dim, inp_shape, outp_shape, flat_shape):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.inp_shape = inp_shape
        self.outp_shape = outp_shape
        self.flat_shape = flat_shape
        
        
        self.encoder = Sequential([
            layers.Conv2D(160, (3, 3), activation='relu', padding='same', input_shape = inp_shape), #### 
            layers.MaxPooling2D((2, 2), padding='same'),
            layers.Conv2D(320, (3, 3), activation='relu', padding='same'),
            layers.MaxPooling2D((2, 2), padding='same'),
            layers.Flatten(),
            layers.Dense(latent_dim, activation='relu'),
        ])
        self.decoder = Sequential([
            layers.Dense(flat_shape, activation='sigmoid'),
            layers.Reshape(outp_shape),
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
K.clear_session()  
latent_dim = 50 
idx = 0
start = time.time()
pred_train_li = []
pred_test_li = []

for X_train, y_train, X_test, y_test in zip(Xs_train_aug, ys_train_aug, Xs_test_aug, ys_test_aug):
    K.clear_session()  
    print(f"TASK {idx}")
    set_no = 0


    ### get input and output shapes to pass to the model
    inp_shape = X_train[0].shape
#         print('in', inp_shape)
    outp_shape = y_train[0].shape#[0]*y_set_train[0].shape[1]
#         print('out',outp_shape)
    flat_shape = outp_shape[0]*outp_shape[1]
#         print('flat',flat_shape)   
        
    verb = 0
    if idx%20 == 0: verb=1  
        
    K.clear_session() 
    base_model = Autoencoder(latent_dim, inp_shape, outp_shape, flat_shape)

    base_model.compile(optimizer='adam', 
                              loss='mean_squared_error',
                              metrics=['accuracy'])

    callback = keras.callbacks.EarlyStopping(monitor='accuracy',
                                                 patience=5)

    base_model.fit(X_train, y_train,
                          epochs=100,
                          batch_size=5000,
                          #shuffle=True,
                          verbose=verb,
                          callbacks=[callback])#,
#                           validation_data=(X_set_test, y_set_test))        
    
    
    encoded_imgs_train = base_model.encoder(X_train[:1]).numpy()
    decoded_imgs_train = base_model.decoder(encoded_imgs_train).numpy()

    pred_train = (decoded_imgs_train.reshape(outp_shape[0:2]))*10
    
    encoded_imgs_test = base_model.encoder(Xs_test_aug[idx][:1]).numpy()
    decoded_imgs_test = base_model.decoder(encoded_imgs_test).numpy()

    pred_test = (decoded_imgs_test.reshape(outp_shape[0:2]))*10
    
    pred_train_li.append(pred_train)
    pred_test_li.append(pred_test)
        
    idx += 1
    
end = time.time()
 
print("Total time: " + str(np.round(end - start, 1)) + " s" + "\n")
# Out:
# TASK 0
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1931 - accuracy: 0.3228
# Epoch 2/100
# 1/1 [==============================] - 0s 224ms/step - loss: 0.1925 - accuracy: 0.5128
# Epoch 3/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.1918 - accuracy: 0.5112
# Epoch 4/100
# 1/1 [==============================] - 0s 241ms/step - loss: 0.1910 - accuracy: 0.5084
# Epoch 5/100
# 1/1 [==============================] - 0s 296ms/step - loss: 0.1899 - accuracy: 0.4959
# Epoch 6/100
# 1/1 [==============================] - 0s 262ms/step - loss: 0.1884 - accuracy: 0.4936
# Epoch 7/100
# 1/1 [==============================] - 0s 284ms/step - loss: 0.1865 - accuracy: 0.4956
# TASK 1
# TASK 2
# TASK 3
# TASK 4
# TASK 5
# TASK 6
# TASK 7
# TASK 8
# TASK 9
# TASK 10
# TASK 11
# TASK 12
# TASK 13
# TASK 14
# TASK 15
# TASK 16
# TASK 17
# TASK 18
# TASK 19
# TASK 20
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2471 - accuracy: 0.4892
# Epoch 2/100
# 1/1 [==============================] - 1s 901ms/step - loss: 0.2459 - accuracy: 0.5887
# Epoch 3/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2431 - accuracy: 0.6070
# Epoch 4/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2369 - accuracy: 0.6276
# Epoch 5/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2253 - accuracy: 0.6475
# Epoch 6/100
# 1/1 [==============================] - 1s 964ms/step - loss: 0.2081 - accuracy: 0.6717
# Epoch 7/100
# 1/1 [==============================] - 1s 851ms/step - loss: 0.1891 - accuracy: 0.6913
# Epoch 8/100
# 1/1 [==============================] - 1s 940ms/step - loss: 0.1737 - accuracy: 0.7119
# Epoch 9/100
# 1/1 [==============================] - 1s 969ms/step - loss: 0.1610 - accuracy: 0.7372
# Epoch 10/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1472 - accuracy: 0.7700
# Epoch 11/100
# 1/1 [==============================] - 1s 903ms/step - loss: 0.1322 - accuracy: 0.7917
# Epoch 12/100
# 1/1 [==============================] - 1s 908ms/step - loss: 0.1171 - accuracy: 0.8214
# Epoch 13/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1025 - accuracy: 0.8504
# Epoch 14/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0887 - accuracy: 0.8694
# Epoch 15/100
# 1/1 [==============================] - 1s 633ms/step - loss: 0.0758 - accuracy: 0.8873
# Epoch 16/100
# 1/1 [==============================] - 1s 867ms/step - loss: 0.0641 - accuracy: 0.9071
# Epoch 17/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0536 - accuracy: 0.9187
# Epoch 18/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0443 - accuracy: 0.9287
# Epoch 19/100
# 1/1 [==============================] - 1s 944ms/step - loss: 0.0360 - accuracy: 0.9382
# Epoch 20/100
# 1/1 [==============================] - 1s 883ms/step - loss: 0.0284 - accuracy: 0.9475
# Epoch 21/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.0219 - accuracy: 0.9570
# Epoch 22/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0166 - accuracy: 0.9671
# Epoch 23/100
# 1/1 [==============================] - 1s 832ms/step - loss: 0.0126 - accuracy: 0.9698
# Epoch 24/100
# 1/1 [==============================] - 1s 723ms/step - loss: 0.0096 - accuracy: 0.9719
# Epoch 25/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0072 - accuracy: 0.9767
# Epoch 26/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0056 - accuracy: 0.9780
# Epoch 27/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0046 - accuracy: 0.9781
# Epoch 28/100
# 1/1 [==============================] - 1s 931ms/step - loss: 0.0038 - accuracy: 0.9781
# Epoch 29/100
# 1/1 [==============================] - 1s 996ms/step - loss: 0.0031 - accuracy: 0.9794
# Epoch 30/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0025 - accuracy: 0.9800
# Epoch 31/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0020 - accuracy: 0.9808
# Epoch 32/100
# 1/1 [==============================] - 1s 961ms/step - loss: 0.0017 - accuracy: 0.9808
# Epoch 33/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0013 - accuracy: 0.9808
# Epoch 34/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0010 - accuracy: 0.9822
# Epoch 35/100
# 1/1 [==============================] - 1s 1s/step - loss: 9.1779e-04 - accuracy: 0.9822
# Epoch 36/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.8558e-04 - accuracy: 0.9822
# Epoch 37/100
# 1/1 [==============================] - 1s 922ms/step - loss: 8.7594e-04 - accuracy: 0.9822
# Epoch 38/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.7317e-04 - accuracy: 0.9822
# Epoch 39/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.7211e-04 - accuracy: 0.9822
# TASK 21
# TASK 22
# TASK 23
# TASK 24
# TASK 25
# TASK 26
# TASK 27
# TASK 28
# TASK 29
# TASK 30
# TASK 31
# TASK 32
# TASK 33
# TASK 34
# TASK 35
# TASK 36
# TASK 37
# TASK 38
# TASK 39
# TASK 40
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2046 - accuracy: 0.4047
# Epoch 2/100
# 1/1 [==============================] - 0s 89ms/step - loss: 0.2016 - accuracy: 0.5415
# Epoch 3/100
# 1/1 [==============================] - 0s 119ms/step - loss: 0.1976 - accuracy: 0.5364
# Epoch 4/100
# 1/1 [==============================] - 0s 125ms/step - loss: 0.1918 - accuracy: 0.5360
# Epoch 5/100
# 1/1 [==============================] - 0s 179ms/step - loss: 0.1842 - accuracy: 0.5425
# Epoch 6/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.1758 - accuracy: 0.5447
# Epoch 7/100
# 1/1 [==============================] - 0s 169ms/step - loss: 0.1674 - accuracy: 0.5543
# Epoch 8/100
# 1/1 [==============================] - 0s 165ms/step - loss: 0.1594 - accuracy: 0.5697
# Epoch 9/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.1518 - accuracy: 0.5901
# Epoch 10/100
# 1/1 [==============================] - 0s 130ms/step - loss: 0.1445 - accuracy: 0.6111
# Epoch 11/100
# 1/1 [==============================] - 0s 147ms/step - loss: 0.1380 - accuracy: 0.6186
# Epoch 12/100
# 1/1 [==============================] - 0s 196ms/step - loss: 0.1323 - accuracy: 0.6338
# Epoch 13/100
# 1/1 [==============================] - 0s 215ms/step - loss: 0.1268 - accuracy: 0.6441
# Epoch 14/100
# 1/1 [==============================] - 0s 165ms/step - loss: 0.1210 - accuracy: 0.6477
# Epoch 15/100
# 1/1 [==============================] - 0s 126ms/step - loss: 0.1149 - accuracy: 0.6664
# Epoch 16/100
# 1/1 [==============================] - 0s 180ms/step - loss: 0.1090 - accuracy: 0.6801
# Epoch 17/100
# 1/1 [==============================] - 0s 195ms/step - loss: 0.1036 - accuracy: 0.6839
# Epoch 18/100
# 1/1 [==============================] - 0s 156ms/step - loss: 0.0985 - accuracy: 0.6996
# Epoch 19/100
# 1/1 [==============================] - 0s 191ms/step - loss: 0.0934 - accuracy: 0.7040
# Epoch 20/100
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0881 - accuracy: 0.7109
# Epoch 21/100
# 1/1 [==============================] - 0s 199ms/step - loss: 0.0831 - accuracy: 0.7270
# Epoch 22/100
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0795 - accuracy: 0.7298
# Epoch 23/100
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0770 - accuracy: 0.7345
# Epoch 24/100
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0753 - accuracy: 0.7357
# Epoch 25/100
# 1/1 [==============================] - 0s 233ms/step - loss: 0.0741 - accuracy: 0.7357
# Epoch 26/100
# 1/1 [==============================] - 0s 194ms/step - loss: 0.0734 - accuracy: 0.7357
# Epoch 27/100
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0730 - accuracy: 0.7357
# Epoch 28/100
# 1/1 [==============================] - 0s 175ms/step - loss: 0.
# Epoch 26/100
# 1/1 [==============================] - 1s 805ms/step - loss: 0.0478 - accuracy: 0.2159
# Epoch 27/100
# 1/1 [==============================] - 1s 771ms/step - loss: 0.0464 - accuracy: 0.2174
# Epoch 28/100
# 1/1 [==============================] - 1s 596ms/step - loss: 0.0451 - accuracy: 0.2180
# Epoch 29/100
# 1/1 [==============================] - 1s 602ms/step - loss: 0.0440 - accuracy: 0.2183
# Epoch 30/100
# 1/1 [==============================] - 1s 548ms/step - loss: 0.0431 - accuracy: 0.2185
# Epoch 31/100
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0422 - accuracy: 0.2191
# Epoch 32/100
# 1/1 [==============================] - 1s 802ms/step - loss: 0.0416 - accuracy: 0.2197
# Epoch 33/100
# 1/1 [==============================] - 1s 858ms/step - loss: 0.0410 - accuracy: 0.2202
# Epoch 34/100
# 1/1 [==============================] - 1s 742ms/step - loss: 0.0404 - accuracy: 0.2202
# Epoch 35/100
# 1/1 [==============================] - 1s 894ms/step - loss: 0.0400 - accuracy: 0.2210
# Epoch 36/100
# 1/1 [==============================] - 1s 750ms/step - loss: 0.0395 - accuracy: 0.2216
# Epoch 37/100
# 1/1 [==============================] - 1s 769ms/step - loss: 0.0391 - accuracy: 0.2216
# Epoch 38/100
# 1/1 [==============================] - 1s 827ms/step - loss: 0.0387 - accuracy: 0.2216
# Epoch 39/100
# 1/1 [==============================] - 1s 719ms/step - loss: 0.0384 - accuracy: 0.2216
# Epoch 40/100
# 1/1 [==============================] - 1s 558ms/step - loss: 0.0381 - accuracy: 0.2216
# Epoch 41/100
# 1/1 [==============================] - 1s 532ms/step - loss: 0.0377 - accuracy: 0.2216
# TASK 61
# TASK 62
# TASK 63
# TASK 64
# TASK 65
# TASK 66
# TASK 67
# TASK 68
# TASK 69
# TASK 70
# TASK 71
# TASK 72
# TASK 73
# TASK 74
# TASK 75
# TASK 76
# TASK 77
# TASK 78
# TASK 79
# TASK 80
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2231 - accuracy: 0.4090
# Epoch 2/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2154 - accuracy: 0.5916
# Epoch 3/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2068 - accuracy: 0.6120
# Epoch 4/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1970 - accuracy: 0.6267
# Epoch 5/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1862 - accuracy: 0.6147
# Epoch 6/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1754 - accuracy: 0.6302
# Epoch 7/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1659 - accuracy: 0.6396
# Epoch 8/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1581 - accuracy: 0.6447
# Epoch 9/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1520 - accuracy: 0.6788
# Epoch 10/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1470 - accuracy: 0.6671
# Epoch 11/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1430 - accuracy: 0.6755
# Epoch 12/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1390 - accuracy: 0.6918
# Epoch 13/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1351 - accuracy: 0.7147
# Epoch 14/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1311 - accuracy: 0.7382
# Epoch 15/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1269 - accuracy: 0.7429
# Epoch 16/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1224 - accuracy: 0.7455
# Epoch 17/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1177 - accuracy: 0.7604
# Epoch 18/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1132 - accuracy: 0.7716
# Epoch 19/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1089 - accuracy: 0.7922
# Epoch 20/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1051 - accuracy: 0.7935
# Epoch 21/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1014 - accuracy: 0.7953
# Epoch 22/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0978 - accuracy: 0.7953
# Epoch 23/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0940 - accuracy: 0.7943
# Epoch 24/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0899 - accuracy: 0.7943
# Epoch 25/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0859 - accuracy: 0.7992
# Epoch 26/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0829 - accuracy: 0.8133
# Epoch 27/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0809 - accuracy: 0.8147
# Epoch 28/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0793 - accuracy: 0.8190
# Epoch 29/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0780 - accuracy: 0.8202
# Epoch 30/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0769 - accuracy: 0.8231
# Epoch 31/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0760 - accuracy: 0.8231
# Epoch 32/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0750 - accuracy: 0.8235
# Epoch 33/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0739 - accuracy: 0.8235
# Epoch 34/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0729 - accuracy: 0.8235
# Epoch 35/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0721 - accuracy: 0.8235
# Epoch 36/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0713 - accuracy: 0.8235
# Epoch 37/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0703 - accuracy: 0.8235
# TASK 81
# TASK 82
# TASK 83
# TASK 84
# TASK 85
# TASK 86
# TASK 87
# TASK 88
# TASK 89
# TASK 90
# TASK 91
# TASK 92
# TASK 93
# TASK 94
# TASK 95
# TASK 96
# TASK 97
# TASK 98
# TASK 99
# TASK 100
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.2457 - accuracy: 0.5803
# Epoch 2/100
# 1/1 [==============================] - 1s 867ms/step - loss: 0.2453 - accuracy: 0.7221
# Epoch 3/100
# 1/1 [==============================] - 1s 822ms/step - loss: 0.2449 - accuracy: 0.7108
# Epoch 4/100
# 1/1 [==============================] - 1s 808ms/step - loss: 0.2442 - accuracy: 0.6892
# Epoch 5/100
# 1/1 [==============================] - 1s 770ms/step - loss: 0.2429 - accuracy: 0.6747
# Epoch 6/100
# 1/1 [==============================] - 1s 911ms/step - loss: 0.2406 - accuracy: 0.6673
# Epoch 7/100
# 1/1 [==============================] - 1s 816ms/step - loss: 0.2364 - accuracy: 0.6624
# TASK 101
# TASK 102
# TASK 103
# TASK 104
# TASK 105
# TASK 106
# TASK 107
# TASK 108
# TASK 109
# TASK 110
# TASK 111
# TASK 112
# TASK 113
# TASK 114
# TASK 115
# TASK 116
# TASK 117
# TASK 118
# TASK 119
# TASK 120
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2446 - accuracy: 0.5008
# Epoch 2/100
# 1/1 [==============================] - 0s 345ms/step - loss: 0.2425 - accuracy: 0.6314
# Epoch 3/100
# 1/1 [==============================] - 0s 417ms/step - loss: 0.2393 - accuracy: 0.6579
# Epoch 4/100
# 1/1 [==============================] - 0s 336ms/step - loss: 0.2340 - accuracy: 0.6723
# Epoch 5/100
# 1/1 [==============================] - 0s 373ms/step - loss: 0.2254 - accuracy: 0.6836
# Epoch 6/100
# 1/1 [==============================] - 0s 403ms/step - loss: 0.2128 - accuracy: 0.6900
# Epoch 7/100
# 1/1 [==============================] - 0s 330ms/step - loss: 0.1967 - accuracy: 0.6933
# Epoch 8/100
# 1/1 [==============================] - 0s 359ms/step - loss: 0.1790 - accuracy: 0.7010
# Epoch 9/100
# 1/1 [==============================] - 0s 429ms/step - loss: 0.1620 - accuracy: 0.7161
# Epoch 10/100
# 1/1 [==============================] - 0s 401ms/step - loss: 0.1468 - accuracy: 0.7370
# Epoch 11/100
# 1/1 [==============================] - 0s 392ms/step - loss: 0.1332 - accuracy: 0.7644
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2401 - accuracy: 0.5017
# Epoch 2/100
# 1/1 [==============================] - 1s 584ms/step - loss: 0.2391 - accuracy: 0.5508
# Epoch 3/100
# 1/1 [==============================] - 1s 695ms/step - loss: 0.2368 - accuracy: 0.5647
# Epoch 4/100
# 1/1 [==============================] - 1s 739ms/step - loss: 0.2319 - accuracy: 0.5768
# Epoch 5/100
# 1/1 [==============================] - 1s 852ms/step - loss: 0.2227 - accuracy: 0.5988
# Epoch 6/100
# 1/1 [==============================] - 1s 781ms/step - loss: 0.2090 - accuracy: 0.6268
# Epoch 7/100
# 1/1 [==============================] - 1s 787ms/step - loss: 0.1935 - accuracy: 0.6467
# Epoch 8/100
# 1/1 [==============================] - 1s 999ms/step - loss: 0.1805 - accuracy: 0.6659
# Epoch 9/100
# 1/1 [==============================] - 1s 844ms/step - loss: 0.1690 - accuracy: 0.6834
# Epoch 10/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1558 - accuracy: 0.7197
# Epoch 11/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1414 - accuracy: 0.7485
# Epoch 12/100
# 1/1 [==============================] - 1s 900ms/step - loss: 0.1269 - accuracy: 0.7658
# Epoch 13/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1131 - accuracy: 0.7911
# Epoch 14/100
# 1/1 [==============================] - 1s 963ms/step - loss: 0.1000 - accuracy: 0.8113
# Epoch 15/100
# 1/1 [==============================] - 1s 967ms/step - loss: 0.0879 - accuracy: 0.8363
# Epoch 16/100
# 1/1 [==============================] - 1s 928ms/step - loss: 0.0765 - accuracy: 0.8467
# Epoch 17/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0658 - accuracy: 0.8575
# Epoch 18/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0558 - accuracy: 0.8798
# Epoch 19/100
# 1/1 [==============================] - 1s 968ms/step - loss: 0.0467 - accuracy: 0.8958
# Epoch 20/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0389 - accuracy: 0.9072
# Epoch 21/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0324 - accuracy: 0.9146
# Epoch 22/100
# 1/1 [==============================] - 1s 985ms/step - loss: 0.0274 - accuracy: 0.9206
# Epoch 23/100
# 1/1 [==============================] - 1s 954ms/step - loss: 0.0238 - accuracy: 0.9250
# Epoch 24/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0212 - accuracy: 0.9250
# Epoch 25/100
# 1/1 [==============================] - 1s 933ms/step - loss: 0.0193 - accuracy: 0.9297
# Epoch 26/100
# 1/1 [==============================] - 1s 949ms/step - loss: 0.0181 - accuracy: 0.9304
# Epoch 27/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0175 - accuracy: 0.9324
# Epoch 28/100
# 1/1 [==============================] - 1s 853ms/step - loss: 0.0173 - accuracy: 0.9324
# Epoch 29/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0173 - accuracy: 0.9324
# Epoch 30/100
# 1/1 [==============================] - 1s 914ms/step - loss: 0.0174 - accuracy: 0.9324
# Epoch 31/100
# 1/1 [==============================] - 1s 678ms/step - loss: 0.0173 - accuracy: 0.9324
# Epoch 32/100
# 1/1 [==============================] - 1s 589ms/step - loss: 0.0173 - accuracy: 0.9324
# TASK 161
# TASK 162
# TASK 163
# TASK 164
# TASK 165
# TASK 166
# TASK 167
# TASK 168
# TASK 169
# TASK 170
# TASK 171
# TASK 172
# TASK 173
# TASK 174
# TASK 175
# TASK 176
# TASK 177
# TASK 178
# TASK 179
# TASK 180
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2160 - accuracy: 0.3933
# Epoch 2/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.2128 - accuracy: 0.5274
# Epoch 3/100
# 1/1 [==============================] - 0s 108ms/step - loss: 0.2088 - accuracy: 0.5736
# Epoch 4/100
# 1/1 [==============================] - 0s 160ms/step - loss: 0.2033 - accuracy: 0.6158
# Epoch 5/100
# 1/1 [==============================] - 0s 96ms/step - loss: 0.1960 - accuracy: 0.6215
# Epoch 6/100
# 1/1 [==============================] - 0s 131ms/step - loss: 0.1875 - accuracy: 0.6259
# Epoch 7/100
# 1/1 [==============================] - 0s 119ms/step - loss: 0.1787 - accuracy: 0.6289
# Epoch 8/100
# 1/1 [==============================] - 0s 106ms/step - loss: 0.1710 - accuracy: 0.6371
# Epoch 9/100
# 1/1 [==============================] - 0s 84ms/step - loss: 0.1649 - accuracy: 0.6456
# Epoch 10/100
# 1/1 [==============================] - 0s 129ms/step - loss: 0.1596 - accuracy: 0.6647
# Epoch 11/100
# 1/1 [==============================] - 0s 150ms/step - loss: 0.1544 - accuracy: 0.6775
# Epoch 12/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.1493 - accuracy: 0.6798
# Epoch 13/100
# 1/1 [==============================] - 0s 115ms/step - loss: 0.1441 - accuracy: 0.6781
# Epoch 14/100
# 1/1 [==============================] - 0s 140ms/step - loss: 0.1390 - accuracy: 0.6910
# Epoch 15/100
# 1/1 [==============================] - 0s 88ms/step - loss: 0.1341 - accuracy: 0.6971
# Epoch 16/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1295 - accuracy: 0.7128
# Epoch 17/100
# 1/1 [==============================] - 0s 129ms/step - loss: 0.1253 - accuracy: 0.7350
# Epoch 18/100
# 1/1 [==============================] - 0s 129ms/step - loss: 0.1214 - accuracy: 0.7458
# Epoch 19/100
# 1/1 [==============================] - 0s 106ms/step - loss: 0.1178 - accuracy: 0.7495
# Epoch 20/100
# 1/1 [==============================] - 0s 117ms/step - loss: 0.1145 - accuracy: 0.7534
# Epoch 21/100
# 1/1 [==============================] - 0s 101ms/step - loss: 0.1112 - accuracy: 0.7548
# Epoch 22/100
# 1/1 [==============================] - 0s 135ms/step - loss: 0.1081 - accuracy: 0.7544
# Epoch 23/100
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1052 - accuracy: 0.7539
# Epoch 24/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1023 - accuracy: 0.7534
# Epoch 25/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0993 - accuracy: 0.7583
# Epoch 26/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0963 - accuracy: 0.7604
# Epoch 27/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0934 - accuracy: 0.7615
# Epoch 28/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0906 - accuracy: 0.7635
# Epoch 29/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0881 - accuracy: 0.7723
# Epoch 30/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0859 - accuracy: 0.7734
# Epoch 31/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0840 - accuracy: 0.7780
# Epoch 32/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0822 - accuracy: 0.7805
# Epoch 33/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0805 - accuracy: 0.7779
# Epoch 34/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0788 - accuracy: 0.7770
# Epoch 35/100
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0769 - accuracy: 0.7785
# Epoch 36/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0748 - accuracy: 0.7775
# Epoch 37/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0726 - accuracy: 0.7765
# TASK 181
# TASK 182
# TASK 183
# TASK 184
# TASK 185
# TASK 186
# TASK 187
# TASK 188
# TASK 189
# TASK 190
# TASK 191
# TASK 192
# TASK 193
# TASK 194
# TASK 195
# TASK 196
# TASK 197
# TASK 198
# TASK 199
# TASK 200
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2293 - accuracy: 0.4511
# Epoch 2/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.2273 - accuracy: 0.5504
# Epoch 3/100
# 1/1 [==============================] - 0s 360ms/step - loss: 0.2238 - accuracy: 0.5696
# Epoch 4/100
# 1/1 [==============================] - 0s 373ms/step - loss: 0.2180 - accuracy: 0.5832
# Epoch 5/100
# 1/1 [==============================] - 0s 427ms/step - loss: 0.2095 - accuracy: 0.5968
# Epoch 6/100
# 1/1 [==============================] - 0s 338ms/step - loss: 0.1989 - accuracy: 0.6039
# Epoch 7/100
# 1/1 [==============================] - 0s 347ms/step - loss: 0.1882 - accuracy: 0.6194
# Epoch 8/100
# 1/1 [==============================] - 0s 391ms/step - loss: 0.1786 - accuracy: 0.6332
# Epoch 9/100
# 1/1 [==============================] - 0s 403ms/step - loss: 0.1696 - accuracy: 0.6499
# Epoch 10/100
# 1/1 [==============================] - 0s 380ms/step - loss: 0.1605 - accuracy: 0.6806
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2408 - accuracy: 0.4848
# Epoch 2/100
# 1/1 [==============================] - 1s 715ms/step - loss: 0.2404 - accuracy: 0.7087
# Epoch 3/100
# 1/1 [==============================] - 1s 740ms/step - loss: 0.2400 - accuracy: 0.7090
# Epoch 4/100
# 1/1 [==============================] - 1s 762ms/step - loss: 0.2395 - accuracy: 0.6894
# Epoch 5/100
# 1/1 [==============================] - 1s 721ms/step - loss: 0.2387 - accuracy: 0.6759
# Epoch 6/100
# 1/1 [==============================] - 1s 771ms/step - loss: 0.2373 - accuracy: 0.6675
# Epoch 7/100
# 1/1 [==============================] - 1s 721ms/step - loss: 0.2350 - accuracy: 0.6651
# Epoch 8/100
# 1/1 [==============================] - 1s 724ms/step - loss: 0.2312 - accuracy: 0.6652
# TASK 221
# TASK 222
# TASK 223
# TASK 224
# TASK 225
# TASK 226
# TASK 227
# TASK 228
# TASK 229
# TASK 230
# TASK 231
# TASK 232
# TASK 233
# TASK 234
# TASK 235
# TASK 236
# TASK 237
# TASK 238
# TASK 239
# TASK 240
# Epoch 1/100
# 1/1 [==============================] - 1s 501ms/step - loss: 0.2084 - accuracy: 0.4113
# Epoch 2/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.2043 - accuracy: 0.5615
# Epoch 3/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1990 - accuracy: 0.5813
# Epoch 4/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1924 - accuracy: 0.5856
# Epoch 5/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1842 - accuracy: 0.5887
# Epoch 6/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1747 - accuracy: 0.5887
# Epoch 7/100
# 1/1 [==============================] - 0s 101ms/step - loss: 0.1645 - accuracy: 0.5930
# Epoch 8/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1547 - accuracy: 0.6024
# Epoch 9/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1461 - accuracy: 0.6311
# Epoch 10/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1389 - accuracy: 0.6333
# Epoch 11/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1323 - accuracy: 0.6333
# Epoch 12/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1257 - accuracy: 0.6533
# Epoch 13/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.1188 - accuracy: 0.6787
# Epoch 14/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.1119 - accuracy: 0.6887
# Epoch 15/100
# 1/1 [==============================] - 0s 99ms/step - loss: 0.1051 - accuracy: 0.7309
# Epoch 16/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0982 - accuracy: 0.7578
# Epoch 17/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0909 - accuracy: 0.7578
# Epoch 18/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0836 - accuracy: 0.7578
# Epoch 19/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0776 - accuracy: 0.7802
# Epoch 20/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0735 - accuracy: 0.7802
# Epoch 21/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0710 - accuracy: 0.7802
# Epoch 22/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0694 - accuracy: 0.7802
# Epoch 23/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0684 - accuracy: 0.7802
# Epoch 24/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0677 - accuracy: 0.7802
# TASK 241
# TASK 242
# TASK 243
# TASK 244
# TASK 245
# TASK 246
# TASK 247
# TASK 248
# TASK 249
# TASK 250
# TASK 251
# TASK 252
# TASK 253
# TASK 254
# TASK 255
# TASK 256
# TASK 257
# TASK 258
# TASK 259
# TASK 260
# Epoch 1/100
# 1/1 [==============================] - 1s 825ms/step - loss: 0.2367 - accuracy: 0.4893
# Epoch 2/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2286 - accuracy: 0.7355
# Epoch 3/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2191 - accuracy: 0.7829
# Epoch 4/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.2072 - accuracy: 0.7949
# Epoch 5/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1922 - accuracy: 0.8000
# Epoch 6/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1741 - accuracy: 0.8139
# Epoch 7/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1534 - accuracy: 0.8160
# Epoch 8/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1313 - accuracy: 0.8352
# Epoch 9/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1089 - accuracy: 0.8648
# Epoch 10/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0877 - accuracy: 0.8648
# Epoch 11/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0687 - accuracy: 0.8648
# Epoch 12/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0526 - accuracy: 0.8648
# Epoch 13/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0388 - accuracy: 0.8648
# Epoch 14/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0270 - accuracy: 0.9024
# Epoch 15/100
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0174 - accuracy: 0.9024
# Epoch 16/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0108 - accuracy: 0.9024
# Epoch 17/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0071 - accuracy: 0.9024
# Epoch 18/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0052 - accuracy: 0.9024
# Epoch 19/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0041 - accuracy: 0.9024
# TASK 261
# TASK 262
# TASK 263
# TASK 264
# TASK 265
# TASK 266
# TASK 267
# TASK 268
# TASK 269
# TASK 270
# TASK 271
# TASK 272
# TASK 273
# TASK 274
# TASK 275
# TASK 276
# TASK 277
# TASK 278
# TASK 279
# TASK 280
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2208 - accuracy: 0.3804
# Epoch 2/100
# 1/1 [==============================] - 0s 244ms/step - loss: 0.2195 - accuracy: 0.5331
# Epoch 3/100
# 1/1 [==============================] - 0s 249ms/step - loss: 0.2177 - accuracy: 0.5449
# Epoch 4/100
# 1/1 [==============================] - 0s 323ms/step - loss: 0.2144 - accuracy: 0.5448
# Epoch 5/100
# 1/1 [==============================] - 0s 271ms/step - loss: 0.2090 - accuracy: 0.5526
# Epoch 6/100
# 1/1 [==============================] - 0s 254ms/step - loss: 0.2006 - accuracy: 0.5645
# Epoch 7/100
# 1/1 [==============================] - 0s 226ms/step - loss: 0.1890 - accuracy: 0.5751
# Epoch 8/100
# 1/1 [==============================] - 0s 321ms/step - loss: 0.1754 - accuracy: 0.5873
# Epoch 9/100
# 1/1 [==============================] - 0s 238ms/step - loss: 0.1624 - accuracy: 0.6009
# Epoch 10/100
# 1/1 [==============================] - 0s 284ms/step - loss: 0.1522 - accuracy: 0.6318
# Epoch 11/100
# 1/1 [==============================] - 0s 234ms/step - loss: 0.1441 - accuracy: 0.6478
# Epoch 12/100
# 1/1 [==============================] - 0s 301ms/step - loss: 0.1363 - accuracy: 0.6643
# Epoch 13/100
# 1/1 [==============================] - 0s 260ms/step - loss: 0.1279 - accuracy: 0.6694
# Epoch 14/100
# 1/1 [==============================] - 0s 225ms/step - loss: 0.1190 - accuracy: 0.6841
# Epoch 15/100
# 1/1 [==============================] - 0s 169ms/step - loss: 0.1101 - accuracy: 0.6905
# Epoch 16/100
# 1/1 [==============================] - 0s 154ms/step - loss: 0.1015 - accuracy: 0.6998
# Epoch 17/100
# 1/1 [==============================] - 0s 154ms/step - loss: 0.0936 - accuracy: 0.7120
# Epoch 18/100
# 1/1 [==============================] - 0s 159ms/step - loss: 0.0859 - accuracy: 0.7224
# Epoch 19/100
# 1/1 [==============================] - 0s 176ms/step - loss: 0.0782 - accuracy: 0.7334
# Epoch 20/100
# 1/1 [==============================] - 0s 173ms/step - loss: 0.0706 - accuracy: 0.7415
# Epoch 21/100
# 1/1 [==============================] - 0s 221ms/step - loss: 0.0633 - accuracy: 0.7607
# Epoch 22/100
# 1/1 [==============================] - 0s 175ms/step - loss: 0.0568 - accuracy: 0.7759
# Epoch 23/100
# 1/1 [==============================] - 0s 194ms/step - loss: 0.0513 - accuracy: 0.7826
# Epoch 24/100
# 1/1 [==============================] - 0s 368ms/step - loss: 0.0466 - accuracy: 0.7876
# Epoch 25/100
# 1/1 [==============================] - 0s 320ms/step - loss: 0.0425 - accuracy: 0.7906
# Epoch 26/100
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0389 - accuracy: 0.7929
# Epoch 27/100
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0355 - accuracy: 0.7964
# Epoch 28/100
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0326 - accuracy: 0.7993
# Epoch 29/100
# 1/1 [==============================] - 0s 246ms/step - loss: 0.0303 - accuracy: 0.8049
# Epoch 30/100
# 1/1 [==============================] - 0s 325ms/step - loss: 0.0288 - accuracy: 0.8049
# Epoch 31/100
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0276 - accuracy: 0.8049
# Epoch 32/100
# 1/1 [==============================] - 0s 258ms/step - loss: 0.0262 - accuracy: 0.8049
# Epoch 33/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0248 - accuracy: 0.8108
# Epoch 34/100
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0241 - accuracy: 0.8108
# Epoch 35/100
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0239 - accuracy: 0.8108
# Epoch 36/100
# 1/1 [==============================] - 0s 314ms/step - loss: 0.0238 - accuracy: 0.8108
# Epoch 37/100
# 1/1 [==============================] - 0s 197ms/step - loss: 0.0237 - accuracy: 0.8108
# Epoch 38/100
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0237 - accuracy: 0.8108
# TASK 281
# TASK 282
# TASK 283
# TASK 284
# TASK 285
# TASK 286
# TASK 287
# TASK 288
# TASK 289
# TASK 290
# TASK 291
# TASK 292
# TASK 293
# TASK 294
# TASK 295
# TASK 296
# TASK 297
# TASK 298
# TASK 299
# TASK 300
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2310 - accuracy: 0.4170
# Epoch 2/100
# 1/1 [==============================] - 0s 119ms/step - loss: 0.2297 - accuracy: 0.5409
# Epoch 3/100
# 1/1 [==============================] - 0s 167ms/step - loss: 0.2281 - accuracy: 0.5683
# Epoch 4/100
# 1/1 [==============================] - 0s 163ms/step - loss: 0.2255 - accuracy: 0.5641
# Epoch 5/100
# 1/1 [==============================] - 0s 150ms/step - loss: 0.2216 - accuracy: 0.5696
# Epoch 6/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.2160 - accuracy: 0.5695
# Epoch 7/100
# 1/1 [==============================] - 0s 172ms/step - loss: 0.2087 - accuracy: 0.5753
# Epoch 8/100
# 1/1 [==============================] - 0s 140ms/step - loss: 0.2000 - accuracy: 0.5819
# Epoch 9/100
# 1/1 [==============================] - 0s 164ms/step - loss: 0.1904 - accuracy: 0.6291
# Epoch 10/100
# 1/1 [==============================] - 0s 176ms/step - loss: 0.1804 - accuracy: 0.6515
# Epoch 11/100
# 1/1 [==============================] - 0s 139ms/step - loss: 0.1702 - accuracy: 0.6671
# Epoch 12/100
# 1/1 [==============================] - 0s 164ms/step - loss: 0.1598 - accuracy: 0.6941
# Epoch 13/100
# 1/1 [==============================] - 0s 166ms/step - loss: 0.1491 - accuracy: 0.7095
# Epoch 14/100
# 1/1 [==============================] - 0s 149ms/step - loss: 0.1384 - accuracy: 0.7326
# Epoch 15/100
# 1/1 [==============================] - 0s 169ms/step - loss: 0.1280 - accuracy: 0.7512
# Epoch 16/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.1180 - accuracy: 0.7832
# Epoch 17/100
# 1/1 [==============================] - 0s 131ms/step - loss: 0.1082 - accuracy: 0.7991
# Epoch 18/100
# 1/1 [==============================] - 0s 167ms/step - loss: 0.0983 - accuracy: 0.8028
# Epoch 19/100
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0886 - accuracy: 0.8274
# Epoch 20/100
# 1/1 [==============================] - 0s 146ms/step - loss: 0.0800 - accuracy: 0.8458
# Epoch 21/100
# 1/1 [==============================] - 0s 141ms/step - loss: 0.0730 - accuracy: 0.8490
# Epoch 22/100
# 1/1 [==============================] - 0s 168ms/step - loss: 0.0670 - accuracy: 0.8555
# Epoch 23/100
# 1/1 [==============================] - 0s 161ms/step - loss: 0.0615 - accuracy: 0.8616
# Epoch 24/100
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0568 - accuracy: 0.8637
# Epoch 25/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0536 - accuracy: 0.8711
# Epoch 26/100
# 1/1 [==============================] - 0s 182ms/step - loss: 0.0523 - accuracy: 0.8707
# Epoch 27/100
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0520 - accuracy: 0.8705
# Epoch 28/100
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0518 - accuracy: 0.8705
# Epoch 29/100
# 1/1 [==============================] - 0s 194ms/step - loss: 0.0512 - accuracy: 0.8704
# Epoch 30/100
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0499 - accuracy: 0.8698
# TASK 301
# TASK 302
# TASK 303
# TASK 304
# TASK 305
# TASK 306
# TASK 307
# TASK 308
# TASK 309
# TASK 310
# TASK 311
# TASK 312
# TASK 313
# TASK 314
# TASK 315
# TASK 316
# TASK 317
# TASK 318
# TASK 319
# TASK 320
# Epoch 1/100
# 1/1 [==============================] - 1s 947ms/step - loss: 0.2383 - accuracy: 0.4775
# Epoch 2/100
# 1/1 [==============================] - 0s 257ms/step - loss: 0.2360 - accuracy: 0.6424
# Epoch 3/100
# 1/1 [==============================] - 0s 257ms/step - loss: 0.2323 - accuracy: 0.6775
# Epoch 4/100
# 1/1 [==============================] - 0s 279ms/step - loss: 0.2263 - accuracy: 0.7006
# Epoch 5/100
# 1/1 [==============================] - 0s 253ms/step - loss: 0.2171 - accuracy: 0.7157
# Epoch 6/100
# 1/1 [==============================] - 0s 241ms/step - loss: 0.2043 - accuracy: 0.7184
# Epoch 7/100
# 1/1 [==============================] - 0s 268ms/step - loss: 0.1890 - accuracy: 0.7204
# Epoch 8/100
# 1/1 [==============================] - 0s 260ms/step - loss: 0.1733 - accuracy: 0.7371
# Epoch 9/100
# 1/1 [==============================] - 0s 259ms/step - loss: 0.1593 - accuracy: 0.7431
# Epoch 10/100
# 1/1 [==============================] - 0s 230ms/step - loss: 0.1481 - accuracy: 0.7583
# Epoch 11/100
# 1/1 [==============================] - 0s 268ms/step - loss: 0.1387 - accuracy: 0.7694
# Epoch 12/100
# 1/1 [==============================] - 0s 256ms/step - loss: 0.1298 - accuracy: 0.7828
# Epoch 13/100
# 1/1 [==============================] - 0s 253ms/step - loss: 0.1207 - accuracy: 0.7904
# Epoch 14/100
# 1/1 [==============================] - 0s 254ms/step - loss: 0.1113 - accuracy: 0.8003
# Epoch 15/100
# 1/1 [==============================] - 0s 259ms/step - loss: 0.1023 - accuracy: 0.8186
# Epoch 16/100
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0946 - accuracy: 0.8358
# Epoch 17/100
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0878 - accuracy: 0.8450
# Epoch 18/100
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0811 - accuracy: 0.8505
# Epoch 19/100
# 1/1 [==============================] - 0s 235ms/step - loss: 0.0746 - accuracy: 0.8607
# Epoch 20/100
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0683 - accuracy: 0.8677
# Epoch 21/100
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0628 - accuracy: 0.8753
# Epoch 22/100
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0581 - accuracy: 0.8833
# Epoch 23/100
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0540 - accuracy: 0.8894
# Epoch 24/100
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0504 - accuracy: 0.8934
# Epoch 25/100
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0474 - accuracy: 0.8992
# Epoch 26/100
# 1/1 [==============================] - 0s 324ms/step - loss: 0.0449 - accuracy: 0.8991
# Epoch 27/100
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0425 - accuracy: 0.9003
# Epoch 28/100
# 1/1 [==============================] - 0s 358ms/step - loss: 0.0403 - accuracy: 0.8999
# Epoch 29/100
# 1/1 [==============================] - 0s 326ms/step - loss: 0.0384 - accuracy: 0.9051
# Epoch 30/100
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0366 - accuracy: 0.9044
# Epoch 31/100
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0345 - accuracy: 0.9096
# Epoch 32/100
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0327 - accuracy: 0.9096
# Epoch 33/100
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0313 - accuracy: 0.9109
# Epoch 34/100
# 1/1 [==============================] - 0s 328ms/step - loss: 0.0302 - accuracy: 0.9142
# Epoch 35/100
# 1/1 [==============================] - 0s 359ms/step - loss: 0.0295 - accuracy: 0.9149
# Epoch 36/100
# 1/1 [==============================] - 0s 347ms/step - loss: 0.0290 - accuracy: 0.9157
# Epoch 37/100
# 1/1 [==============================] - 0s 351ms/step - loss: 0.0286 - accuracy: 0.9164
# Epoch 38/100
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0284 - accuracy: 0.9166
# Epoch 39/100
# 1/1 [==============================] - 0s 327ms/step - loss: 0.0283 - accuracy: 0.9168
# Epoch 40/100
# 1/1 [==============================] - 0s 317ms/step - loss: 0.0283 - accuracy: 0.9168
# Epoch 41/100
# 1/1 [==============================] - 0s 354ms/step - loss: 0.0283 - accuracy: 0.9168
# Epoch 42/100
# 1/1 [==============================] - 0s 376ms/step - loss: 0.0282 - accuracy: 0.9168
# Epoch 43/100
# 1/1 [==============================] - 0s 369ms/step - loss: 0.0280 - accuracy: 0.9168
# Epoch 44/100
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0277 - accuracy: 0.9168
# TASK 321
# TASK 322
# TASK 323
# TASK 324
# TASK 325
# TASK 326
# TASK 327
# TASK 328
# TASK 329
# TASK 330
# TASK 331
# TASK 332
# TASK 333
# TASK 334
# TASK 335
# TASK 336
# TASK 337
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-05a912162d1b> in <module>
#      47     pred_train = (decoded_imgs_train.reshape(outp_shape[0:2]))*10
#      48
# ---> 49     encoded_imgs_test = base_model.encoder(Xs_test_aug[idx][:1]).numpy()
#      50     decoded_imgs_test = base_model.decoder(encoded_imgs_test).numpy()
#      51
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     976     if any(isinstance(x, (
#     977         np_arrays.ndarray, np.ndarray, float, int)) for x in input_list):
# --> 978       inputs = nest.map_structure(_convert_numpy_or_python_types, inputs)
#     979       input_list = nest.flatten(inputs)
#     980
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in _convert_numpy_or_python_types(x)
#    3226 def _convert_numpy_or_python_types(x):
#    3227   if isinstance(x, (np_arrays.ndarray, np.ndarray, float, int)):
# -> 3228     return ops.convert_to_tensor_v2_with_dispatch(x)
#    3229   return x
#    3230
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1429   """
#    1430   return convert_to_tensor_v2(
# -> 1431       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#    1432
#    1433
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1439       name=name,
#    1440       preferred_dtype=dtype_hint,
# -> 1441       as_ref=False)
#    1442
#    1443
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     263   """
#     264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 265                         allow_broadcast=True)
#     266
#     267
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type numpy.ndarray).

# %%
base_model.encoder.summary()

# %%
base_model.decoder.summary()

# %% [markdown]
# ## PLOT PREDICTIONS

# %%
x=40 #### choose which one to display in all below

# %%
cmap = colors.ListedColormap(
            ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
             '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
norm = colors.Normalize(vmin=0, vmax=9)
fig, ax = plt.subplots(1, 5, figsize=(20,20))
for idx in range(x,x+1,20):
  
    ax[0].imshow((Xs_train_aug[idx][0])*10, cmap=cmap, norm=norm)
    ax[0].set_title(f'Train Input {idx}')
    ax[1].imshow((ys_train_aug[idx][0])*10, cmap=cmap, norm=norm)
    ax[1].set_title(f'Train output {idx}')
    ax[2].imshow((pred_train_li[idx]), cmap=cmap, norm=norm)
    ax[2].set_title(f'Train Prediction {idx}')       
    ax[3].imshow((Xs_test_aug[idx][0])*10, cmap=cmap, norm=norm)
    ax[3].set_title(f'Test Input {idx}')
    ax[4].imshow(pred_test_li[idx], cmap=cmap, norm=norm)
    ax[4].set_title(f'Test Prediction {idx}')

# %%
cmap = colors.ListedColormap(
            ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
             '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
norm = colors.Normalize(vmin=0, vmax=9)
fig, ax = plt.subplots(15, 15, figsize=(25,25))
for i in range(15):
    for j in range(15):
        idx = i+j+6*i
        
        ax[i,j].imshow((Xs_train_aug[x][idx])*10, cmap=cmap, norm=norm)
#         ax[i,j].set_title(f'Train Input {idx}')

# %%
cmap = colors.ListedColormap(
            ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
             '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
norm = colors.Normalize(vmin=0, vmax=9)
fig, ax = plt.subplots(1, 3, figsize=(15,15))
for i in range(1):
    for j in range(3):
        idx = j
        
        ax[j].imshow((Xs_train_aug[x][idx])*10, cmap=cmap, norm=norm)
#         ax[j].set_title(f'Train Input {idx}')
