# %% [markdown]
# NEW NEW NEW
# - new color definition
# - reduced amount of times random method is executed
# - class Autoencoder(Model): included input_shape and output_shape
# - loooooops

# %%
import numpy as np
import pandas as pd
import random 
from random import randint
import time

import os
import json
from pathlib import Path

import tensorflow.keras as keras
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras import layers
#from tensorflow.keras.datasets import mnist
from tensorflow.keras import backend as K
#from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt
from matplotlib import colors

# %%
data_path = Path('./kaggle_input/')
training_path = data_path / 'training'      # 400 X-train ('train'), y-train('test') input-output pairs
evaluation_path = data_path / 'evaluation'  # 400
test_path = data_path / 'test'              # 100 pairs X-train ('train') (input-output),
                                            #           y-train (input only) pairs

training_tasks_files = sorted(os.listdir(training_path))#[1:]
eval_tasks_files = sorted(os.listdir(evaluation_path))
test_task_files = sorted(os.listdir(test_path))

# %%
def load_files(path):
    path_files = sorted(os.listdir(path))
    tasks = []
    for task_file in path_files:
        with open(str(path / task_file), 'r') as f:
            task = json.load(f)
            tasks.append(task)
    return tasks

# %%
training_tasks = load_files(training_path)          ### this is for building / training the algorithm
test_tasks = load_files(test_path)                  ### this is the input for the actual prediction!!!
evaluation_tasks = load_files(evaluation_path)      ### testing the algorithm

# %%
len(training_tasks), training_tasks[0]['test']
# Out:
# (400,
#  [{'input': [[7, 0, 7], [7, 0, 7], [7, 7, 0]],
#    'output': [[7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 7, 0, 0, 0, 0, 7, 7, 0],
#     [7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 0, 7, 0, 0, 0, 7, 0, 7],
#     [7, 7, 0, 0, 0, 0, 7, 7, 0],
#     [7, 0, 7, 7, 0, 7, 0, 0, 0],
#     [7, 0, 7, 7, 0, 7, 0, 0, 0],
#     [7, 7, 0, 7, 7, 0, 0, 0, 0]]}])

# %%
len(evaluation_tasks), evaluation_tasks[0]['test']
# Out:
# (400,
#  [{'input': [[3, 2], [7, 8]],
#    'output': [[3, 2, 3, 2, 3, 2],
#     [7, 8, 7, 8, 7, 8],
#     [2, 3, 2, 3, 2, 3],
#     [8, 7, 8, 7, 8, 7],
#     [3, 2, 3, 2, 3, 2],
#     [7, 8, 7, 8, 7, 8]]}])

# %%
len(test_tasks),test_tasks[0]['test']
# Out:
# (100, [{'input': [[3, 2], [7, 8]]}])

# %% [markdown]
#
#  ---
#  ---

# %% [markdown]
# ### 1. Create Train - Test - Split

# %%
def tts(input_list):
    Xs_test, ys_test, Xs_train, ys_train = [], [], [], []

    for task in input_list:
        X_test, y_test, X_train, y_train = [], [], [], []

        for pair in task["test"]:
            X_test.append(pair["input"])
            y_test.append(pair["output"])      ### to be predicted !!!

        for pair in task["train"]:
            X_train.append(pair["input"])
            y_train.append(pair["output"])

        Xs_test.append(X_test)
        ys_test.append(y_test)
        Xs_train.append(X_train)
        ys_train.append(y_train)
    return Xs_test, ys_test, Xs_train, ys_train

# %% [markdown]
#
# #### Create origanl sized Train-Test-Split for reference

# %%
Xs_test_orig, ys_test_orig, Xs_train_orig, ys_train_orig = tts(training_tasks)

# %%
len(Xs_train_orig), len(ys_train_orig), len(Xs_test_orig), len(ys_test_orig)
# Out:
# (400, 400, 400, 400)

# %%
len(Xs_train_orig[1]), len(ys_train_orig[1]), len(Xs_test_orig[1]), len(ys_test_orig[1])
# Out:
# (5, 5, 1, 1)

# %% [markdown]
#
# #### Create actual Train-Test-Split

# %%
Xs_test, ys_test, Xs_train, ys_train = tts(training_tasks)

# %%
len(Xs_train), len(ys_train), len(Xs_test), len(ys_test)
# Out:
# (400, 400, 400, 400)

# %%
len(Xs_train[1]), len(ys_train[1]), len(Xs_test[1]), len(ys_test[1])
# Out:
# (5, 5, 1, 1)

# %% [markdown]
# ## Data Augmentation of the training data

# %%
# #### color
# def color_change(arr):
#     x = arr*3
# #     x = x/(x.max()+0.1)
#     x = np.interp(x, (0.3, 2.7), (0, 0.9))
#     x = np.ndarray.round(x,1)
#     return x

# %%
def augm(X_list, y_list):
    idx = 1
    X_list_new = []
    y_list_new = []
    
    for task_X, task_y in zip(X_list, y_list):
        task_li_x = []
        task_li_y = []
        print("TASK",idx)
        length = len(Xs_train_orig[idx-1])
#         print(length)
        max_li=[]
        for i in range(length):
            max_a = max(len(task_X[i]),len(task_X[i][0]))
            max_b = max(len(task_y[i]),len(task_y[i][0]))
            max_c = max(len(Xs_test[idx-1][0]),len(Xs_test[idx-1][0][0]))
            max_d = max(len(ys_test[idx-1][0]),len(ys_test[idx-1][0][0]))
            max_abcd = max(max_a,max_b, max_c, max_d)
            max_li.append(max_abcd)
#             print(f"max_a = max({len(task_X[i])},{len(task_X[i][0])})")
#             print(f"max_b = max({len(task_y[i])},{len(task_y[i][0])})")
#             print(max_int)
        max_int = max(max_li)
            
        for e_x,e_y in zip(task_X, task_y):
            e_x = (np.array(e_x))/10.     
            e_y = (np.array(e_y))/10.
#             print(e_x.shape,e_y.shape, max_int)
            e_x = np.pad(e_x, [(0, max_int-e_x.shape[0]), (0, max_int-e_x.shape[1])], mode='constant')
            e_y = np.pad(e_y, [(0, max_int-e_y.shape[0]), (0, max_int-e_y.shape[1])], mode='constant')
#             print(e_x.shape,e_y.shape, max_int, "\n")
            task_li_x.append(e_x.reshape(e_x.shape + (1,) ))
            task_li_y.append(e_y.reshape(e_y.shape + (1,) ))
        # ========================
         
        while len(task_li_x) < 50*length:    ###################
#             print(len(task_li_x))
            """
            choose a random method and append new array
            """
            i = randint(0,length-1) 
            new_x = (np.array(task_X[i]))/10.
#             print((new_x))
            new_y = (np.array(task_y[i]))/10.
            
            
            times = randint(1,5)
#             print(f"LENGTH: {len(task_X)} // INDEX: {i} // TIMES: {times}" )
            for j in range(times):
                
                method = random.choice([np.fliplr, np.flipud, np.rot90])#,color_change])
                new_x = method(new_x)
                new_y = method(new_y)

            new_x = np.pad(new_x, [(0, max_int-new_x.shape[0]), (0, max_int-new_x.shape[1])], mode='constant')

            new_y = np.pad(new_y, [(0, max_int-new_y.shape[0]), (0, max_int-new_y.shape[1])], mode='constant')

            
            task_li_x.append(new_x.reshape(new_x.shape + (1,) ))
            task_li_y.append(new_y.reshape(new_y.shape + (1,) ))
 
        X_list_new.append(np.array(task_li_x))
        y_list_new.append(np.array(task_li_y))

        idx +=1
    return     X_list_new, y_list_new

# %%
Xs_train_aug, ys_train_aug = augm(Xs_train, ys_train)
# Out:
# TASK 1
# TASK 2
# TASK 3
# TASK 4
# TASK 5
# TASK 6
# TASK 7
# TASK 8
# TASK 9
# TASK 10
# TASK 11
# TASK 12
# TASK 13
# TASK 14
# TASK 15
# TASK 16
# TASK 17
# TASK 18
# TASK 19
# TASK 20
# TASK 21
# TASK 22
# TASK 23
# TASK 24
# TASK 25
# TASK 26
# TASK 27
# TASK 28
# TASK 29
# TASK 30
# TASK 31
# TASK 32
# TASK 33
# TASK 34
# TASK 35
# TASK 36
# TASK 37
# TASK 38
# TASK 39
# TASK 40
# TASK 41
# TASK 42
# TASK 43
# TASK 44
# TASK 45
# TASK 46
# TASK 47
# TASK 48
# TASK 49
# TASK 50
# TASK 51
# TASK 52
# TASK 53
# TASK 54
# TASK 55
# TASK 56
# TASK 57
# TASK 58
# TASK 59
# TASK 60
# TASK 61
# TASK 62
# TASK 63
# TASK 64
# TASK 65
# TASK 66
# TASK 67
# TASK 68
# TASK 69
# TASK 70
# TASK 71
# TASK 72
# TASK 73
# TASK 74
# TASK 75
# TASK 76
# TASK 77
# TASK 78
# TASK 79
# TASK 80
# TASK 81
# TASK 82
# TASK 83
# TASK 84
# TASK 85
# TASK 86
# TASK 87
# TASK 88
# TASK 89
# TASK 90
# TASK 91
# TASK 92
# TASK 93
# TASK 94
# TASK 95
# TASK 96
# TASK 97
# TASK 98
# TASK 99
# TASK 100
# TASK 101
# TASK 102
# TASK 103
# TASK 104
# TASK 105
# TASK 106
# TASK 107
# TASK 108
# TASK 109
# TASK 110
# TASK 111
# TASK 112
# TASK 113
# TASK 114
# TASK 115
# TASK 116
# TASK 117
# TASK 118
# TASK 119
# TASK 120
# TASK 121
# TASK 122
# TASK 123
# TASK 124
# TASK 125
# TASK 126
# TASK 127
# TASK 128
# TASK 129
# TASK 130
# TASK 131
# TASK 132
# TASK 133
# TASK 134
# TASK 135
# TASK 136
# TASK 137
# TASK 138
# TASK 139
# TASK 140
# TASK 141
# TASK 142
# TASK 143
# TASK 144
# TASK 145
# TASK 146
# TASK 147
# TASK 148
# TASK 149
# TASK 150
# TASK 151
# TASK 152
# TASK 153
# TASK 154
# TASK 155
# TASK 156
# TASK 157
# TASK 158
# TASK 159
# TASK 160
# TASK 161
# TASK 162
# TASK 163
# TASK 164
# TASK 165
# TASK 166
# TASK 167
# TASK 168
# TASK 169
# TASK 170
# TASK 171
# TASK 172
# TASK 173
# TASK 174
# TASK 175
# TASK 176
# TASK 177
# TASK 178
# TASK 179
# TASK 180
# TASK 181
# TASK 182
# TASK 183
# TASK 184
# TASK 185
# TASK 186
# TASK 187
# TASK 188
# TASK 189
# TASK 190
# TASK 191
# TASK 192
# TASK 193
# TASK 194
# TASK 195
# TASK 196
# TASK 197
# TASK 198
# TASK 199
# TASK 200
# TASK 201
# TASK 202
# TASK 203
# TASK 204
# TASK 205
# TASK 206
# TASK 207
# TASK 208
# TASK 209
# TASK 210
# TASK 211
# TASK 212
# TASK 213
# TASK 214
# TASK 215
# TASK 216
# TASK 217
# TASK 218
# TASK 219
# TASK 220
# TASK 221
# TASK 222
# TASK 223
# TASK 224
# TASK 225
# TASK 226
# TASK 227
# TASK 228
# TASK 229
# TASK 230
# TASK 231
# TASK 232
# TASK 233
# TASK 234
# TASK 235
# TASK 236
# TASK 237
# TASK 238
# TASK 239
# TASK 240
# TASK 241
# TASK 242
# TASK 243
# TASK 244
# TASK 245
# TASK 246
# TASK 247
# TASK 248
# TASK 249
# TASK 250
# TASK 251
# TASK 252
# TASK 253
# TASK 254
# TASK 255
# TASK 256
# TASK 257
# TASK 258
# TASK 259
# TASK 260
# TASK 261
# TASK 262
# TASK 263
# TASK 264
# TASK 265
# TASK 266
# TASK 267
# TASK 268
# TASK 269
# TASK 270
# TASK 271
# TASK 272
# TASK 273
# TASK 274
# TASK 275
# TASK 276
# TASK 277
# TASK 278
# TASK 279
# TASK 280
# TASK 281
# TASK 282
# TASK 283
# TASK 284
# TASK 285
# TASK 286
# TASK 287
# TASK 288
# TASK 289
# TASK 290
# TASK 291
# TASK 292
# TASK 293
# TASK 294
# TASK 295
# TASK 296
# TASK 297
# TASK 298
# TASK 299
# TASK 300
# TASK 301
# TASK 302
# TASK 303
# TASK 304
# TASK 305
# TASK 306
# TASK 307
# TASK 308
# TASK 309
# TASK 310
# TASK 311
# TASK 312
# TASK 313
# TASK 314
# TASK 315
# TASK 316
# TASK 317
# TASK 318
# TASK 319
# TASK 320
# TASK 321
# TASK 322
# TASK 323
# TASK 324
# TASK 325
# TASK 326
# TASK 327
# TASK 328
# TASK 329
# TASK 330
# TASK 331
# TASK 332
# TASK 333
# TASK 334
# TASK 335
# TASK 336
# TASK 337
# TASK 338
# TASK 339
# TASK 340
# TASK 341
# TASK 342
# TASK 343
# TASK 344
# TASK 345
# TASK 346
# TASK 347
# TASK 348
# TASK 349
# TASK 350
# TASK 351
# TASK 352
# TASK 353
# TASK 354
# TASK 355
# TASK 356
# TASK 357
# TASK 358
# TASK 359
# TASK 360
# TASK 361
# TASK 362
# TASK 363
# TASK 364
# TASK 365
# TASK 366
# TASK 367
# TASK 368
# TASK 369
# TASK 370
# TASK 371
# TASK 372
# TASK 373
# TASK 374
# TASK 375
# TASK 376
# TASK 377
# TASK 378
# TASK 379
# TASK 380
# TASK 381
# TASK 382
# TASK 383
# TASK 384
# TASK 385
# TASK 386
# TASK 387
# TASK 388
# TASK 389
# TASK 390
# TASK 391
# TASK 392
# TASK 393
# TASK 394
# TASK 395
# TASK 396
# TASK 397
# TASK 398
# TASK 399
# TASK 400

# %%
# def augm(X_list, y_list):
#     start = time.time()
# #     idx = 1
#     X_list_new = []
#     y_list_new = []
    
#     for task_X, task_y in zip(X_list, y_list):
# #         print(f"TASK {idx}")
#         task_x_li = []
#         task_y_li = []
        
#         for e_x, e_y in zip(task_X, task_y):
            
#             new_x = (np.array(e_x))/10.     
#             e_x_li = []
# #             e_x_li.append(new_x.reshape(new_x.shape + (1,) ))
            
#             new_y = (np.array(e_y))/10.
#             e_y_li = []
# #             e_y_li.append(new_y.reshape(new_y.shape + (1,) ))

#             max_int = max(max(new_x.shape),max(new_y.shape)) 
            
#             while len(e_x_li) < 500:                                      ###############
#                 """
#                 choose a random method and append new array
#                 """
#                 if len(e_x_li) > 0:
                    
#                     times = randint(1,4)
#                     for j in range(times):

#                         method = random.choice([np.fliplr, np.flipud, np.rot90])#,color_change])
#                         new_x = method(new_x)
#                         new_y = method(new_y)
                
#                 new_x = np.pad(new_x, [(0, max_int-new_x.shape[0]), (0, max_int-new_x.shape[1])], mode='constant')
# #                 new_x = new_x/10.
#                 new_y = np.pad(new_y, [(0, max_int-new_y.shape[0]), (0, max_int-new_y.shape[1])], mode='constant')
# #                 new_y = new_y/10.
                
#                 e_x_li.append(new_x.reshape(new_x.shape + (1,) ))
#                 e_y_li.append(new_y.reshape(new_y.shape + (1,) ))
                
#             task_x_li.append(np.array(e_x_li))
#             task_y_li.append(np.array(e_y_li))
            
#         X_list_new.append(task_x_li)
#         y_list_new.append(task_y_li)
            
# #         idx +=1
#     end = time.time()
 
#     print("Total time: " + str(np.round(end - start, 1)) + " s" + "\n")
#     return X_list_new, y_list_new

# %%
type(Xs_train_aug),len(Xs_train_aug)   ### number of Tasks
# Out:
# (list, 400)

# %%
type(Xs_train_aug[0]),len(Xs_train_aug[0]) ### number of sets
# Out:
# (numpy.ndarray, 250)

# %%
type(Xs_train_aug[0][0]),Xs_train_aug[0][0].shape ### number of inputs (pairs)
# Out:
# (numpy.ndarray, (9, 9, 1))

# %% [markdown]
# #### format test data

# %%
def t2l(X_list, y_list):
    li_x =[]
    li_y =[]
    idx = 0
    for task_x, task_y in zip(X_list, y_list):
#         print("TASK", idx)
        task_x_arr = np.array(task_x)
        task_y_arr = np.array(task_y)
        li2_x = []
        li2_y = []
        for e_x, e_y in zip(task_x_arr, task_y_arr):
            e_x = np.array(e_x)
            e_y = np.array(e_y)
            max_train = Xs_train_aug[idx].shape[1]
            max_int = max(max(e_x.shape),max(e_y.shape),max_train)
            
            
            e_x = np.pad(e_x, [(0, max_int-e_x.shape[0]), (0, max_int-e_x.shape[1])], mode='constant')
            e_x = e_x / 10.
            e_x = e_x.reshape(e_x.shape + (1,) )
#             print(e_x.shape, e_y.shape, max_int)
            e_y = np.pad(e_y, [(0, max_int-e_y.shape[0]), (0, max_int-e_y.shape[1])], mode='constant')
            e_y = e_y / 10.
            e_y = e_y.reshape(e_y.shape + (1,) )
#             print(e_x.shape, e_y.shape, "\n")
            li2_x.append(e_x)
            li2_y.append(e_y)

#         lenght = len(Xs_train_aug[idx])
        
#         li_x.append([np.array(li2_x)])
#         li_y.append([np.array(li2_y)])
        
        li_x.append(np.array(li2_x))
        li_y.append(np.array(li2_y))
        idx += 1
    return li_x, li_y

# %%
Xs_test_aug, ys_test_aug = t2l(Xs_test, ys_test)
# Out:
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   import sys
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:34: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:35: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
type(Xs_train_aug), type(ys_train_aug),type(Xs_test_aug), type(ys_test_aug)
# Out:
# (list, list, list, list)

# %%
len(Xs_train_aug), len(ys_train_aug),len(Xs_test_aug), len(ys_test_aug)
# Out:
# (400, 400, 400, 400)

# %%
type(Xs_train_aug[0]), type(ys_train_aug[0]),type(Xs_test_aug[0]), type(ys_test_aug[0])
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
len(Xs_train_aug[40]), len(ys_train_aug[40]),len(Xs_test_aug[40]), len(ys_test_aug[40])
# Out:
# (150, 150, 1, 1)

# %%
Xs_train_aug[0].shape, ys_train_aug[0].shape,Xs_test_aug[0].shape, ys_test_aug[0].shape
# Out:
# ((250, 9, 9, 1), (250, 9, 9, 1), (1, 9, 9, 1), (1, 9, 9, 1))

# %%
type(Xs_train_aug[0][0]), type(ys_train_aug[0][0]),type(Xs_test_aug[0][0]), type(ys_test_aug[0][0])
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
Xs_train_aug[2][2].shape, ys_train_aug[2][2].shape, Xs_test_aug[2][0].shape, ys_test_aug[2][0].shape
# Out:
# ((9, 9, 1), (9, 9, 1), (9, 9, 1), (9, 9, 1))

# %% [markdown]
# ## Model comp

# %%
class Autoencoder(Model):
    def __init__(self, latent_dim, inp_shape, outp_shape, flat_shape):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.inp_shape = inp_shape
        self.outp_shape = outp_shape
        self.flat_shape = flat_shape
        
        
        self.encoder = Sequential([
            layers.Conv2D(160, (3, 3), activation='relu', padding='same', input_shape = inp_shape), #### 
            layers.MaxPooling2D((2, 2), padding='same'),
            layers.Conv2D(320, (3, 3), activation='relu', padding='same'),
            layers.MaxPooling2D((2, 2), padding='same'),
            layers.Flatten(),
            layers.Dense(latent_dim, activation='relu'),
        ])
        self.decoder = Sequential([
            layers.Dense(flat_shape, activation='sigmoid'),
            layers.Reshape(outp_shape),
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
K.clear_session()  
latent_dim = 500
idx = 0
start = time.time()
pred_train_li = []
pred_test_li = []

for X_train, y_train, X_test, y_test in zip(Xs_train_aug, ys_train_aug, Xs_test_aug, ys_test_aug):
    K.clear_session()  
    print(f"TASK {idx}")
    set_no = 0


    ### get input and output shapes to pass to the model
    inp_shape = X_train[0].shape
#         print('in', inp_shape)
    outp_shape = y_train[0].shape#[0]*y_set_train[0].shape[1]
#         print('out',outp_shape)
    flat_shape = outp_shape[0]*outp_shape[1]
#         print('flat',flat_shape)   
        
    verb = 0
    if idx%20 == 0: verb=1   
    
    K.clear_session() 
    base_model = Autoencoder(latent_dim, inp_shape, outp_shape, flat_shape)

    base_model.compile(optimizer='adam', 
                              loss='mean_squared_error',
                              metrics=['accuracy'])

    callback = keras.callbacks.EarlyStopping(monitor='accuracy',
                                                 patience=5)

    base_model.fit(X_train, y_train,
                          epochs=100,
                          batch_size=5000,
                          #shuffle=True,
                          verbose=verb,
                          callbacks=[callback])#,
#                           validation_data=(X_set_test, y_set_test))  


    encoded_imgs_train = base_model.encoder(X_train[:1]).numpy()
    decoded_imgs_train = base_model.decoder(encoded_imgs_train).numpy()

    pred_train = (decoded_imgs_train.reshape(outp_shape[0:2]))*10
    
    encoded_imgs_test = base_model.encoder(Xs_test_aug[idx][:1]).numpy()
    decoded_imgs_test = base_model.decoder(encoded_imgs_test).numpy()

    pred_test = (decoded_imgs_test.reshape(outp_shape[0:2]))*10
    
    pred_train_li.append(pred_train)
    pred_test_li.append(pred_test)
        
    idx += 1

end = time.time()
 
print("Total time: " + str(np.round(end - start, 1)) + " s" + "\n")
# Out:
# TASK 0
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.1907 - accuracy: 0.3598
# Epoch 2/100
# 1/1 [==============================] - 0s 334ms/step - loss: 0.1883 - accuracy: 0.6073
# Epoch 3/100
# 1/1 [==============================] - 0s 283ms/step - loss: 0.1848 - accuracy: 0.6518
# Epoch 4/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.1789 - accuracy: 0.6741
# Epoch 5/100
# 1/1 [==============================] - 0s 449ms/step - loss: 0.1690 - accuracy: 0.6817
# Epoch 6/100
# 1/1 [==============================] - 0s 465ms/step - loss: 0.1540 - accuracy: 0.6955
# Epoch 7/100
# 1/1 [==============================] - 0s 330ms/step - loss: 0.1339 - accuracy: 0.7017
# Epoch 8/100
# 1/1 [==============================] - 0s 438ms/step - loss: 0.1117 - accuracy: 0.7099
# Epoch 9/100
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0933 - accuracy: 0.7099
# Epoch 10/100
# 1/1 [==============================] - 0s 383ms/step - loss: 0.0834 - accuracy: 0.7099
# Epoch 11/100
# 1/1 [==============================] - 0s 314ms/step - loss: 0.0811 - accuracy: 0.7099
# Epoch 12/100
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0822 - accuracy: 0.7099
# Epoch 13/100
# 1/1 [==============================] - 0s 466ms/step - loss: 0.0835 - accuracy: 0.7099
# TASK 1
# TASK 2
# TASK 3
# TASK 4
# TASK 5
# TASK 6
# TASK 7
# TASK 8
# TASK 9
# TASK 10
# TASK 11
# TASK 12
# TASK 13
# TASK 14
# TASK 15
# TASK 16
# TASK 17
# TASK 18
# TASK 19
# TASK 20
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.2458 - accuracy: 0.4938
# Epoch 2/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2386 - accuracy: 0.7222
# Epoch 3/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2145 - accuracy: 0.7986
# Epoch 4/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1601 - accuracy: 0.8556
# Epoch 5/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0898 - accuracy: 0.9084
# Epoch 6/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0401 - accuracy: 0.9384
# Epoch 7/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0158 - accuracy: 0.9642
# Epoch 8/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0053 - accuracy: 0.9745
# Epoch 9/100
# 1/1 [==============================] - 1s 996ms/step - loss: 0.0022 - accuracy: 0.9786
# Epoch 10/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0017 - accuracy: 0.9786
# Epoch 11/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0017 - accuracy: 0.9786
# Epoch 12/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0017 - accuracy: 0.9786
# Epoch 13/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0017 - accuracy: 0.9786
# Epoch 14/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0017 - accuracy: 0.9786
# TASK 21
# TASK 22
# TASK 23
# TASK 24
# TASK 25
# TASK 26
# TASK 27
# TASK 28
# TASK 29
# TASK 30
# TASK 31
# TASK 32
# TASK 33
# TASK 34
# TASK 35
# TASK 36
# TASK 37
# TASK 38
# TASK 39
# TASK 40
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1962 - accuracy: 0.3620
# Epoch 2/100
# 1/1 [==============================] - 0s 134ms/step - loss: 0.1899 - accuracy: 0.6535
# Epoch 3/100
# 1/1 [==============================] - 0s 216ms/step - loss: 0.1783 - accuracy: 0.6709
# Epoch 4/100
# 1/1 [==============================] - 0s 253ms/step - loss: 0.1578 - accuracy: 0.6935
# Epoch 5/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.1299 - accuracy: 0.7010
# Epoch 6/100
# 1/1 [==============================] - 0s 242ms/step - loss: 0.1025 - accuracy: 0.7055
# Epoch 7/100
# 1/1 [==============================] - 0s 212ms/step - loss: 0.0832 - accuracy: 0.7071
# Epoch 8/100
# 1/1 [==============================] - 0s 234ms/step - loss: 0.0746 - accuracy: 0.7121
# Epoch 9/100
# 1/1 [==============================] - 0s 215ms/step - loss: 0.0733 - accuracy: 0.7121
# Epoch 10/100
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0742 - accuracy: 0.7121
# Epoch 11/100
# 1/1 [==============================] - 0s 226ms/step - loss: 0.0746 - accuracy: 0.7121
# Epoch 12/100
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0747 - accuracy: 0.7109
# Epoch 13/100
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0740 - accuracy: 0.7084
# TASK 41
# TASK 42
# TASK 43
# TASK 44
# TASK 45
# TASK 46
# TASK 47
# TASK 48
# TASK 49
# TASK 50
# TASK 51
# TASK 52
# TASK 53
# TASK 54
# TASK 55
# TASK 56
# TASK 57
# TASK 58
# TASK 59
# TASK 60
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.0788 - accuracy: 0.0000e+00
# Epoch 2/100
# 1/1 [==============================] - 1s 829ms/step - loss: 0.0739 - accuracy: 0.0000e+00
# Epoch 3/100
# 1/1 [==============================] - 1s 826ms/step - loss: 0.0640 - accuracy: 0.0000e+00
# Epoch 4/100
# 1/1 [==============================] - 1s 652ms/step - loss: 0.0539 - accuracy: 0.0000e+00
# Epoch 5/100
# 1/1 [==============================] - 1s 764ms/step - loss: 0.0531 - accuracy: 0.0000e+00
# Epoch 6/100
# 1/1 [==============================] - 1s 750ms/step - loss: 0.0485 - accuracy: 0.0000e+00
# TASK 61
# TASK 62
# TASK 63
# TASK 64
# TASK 65
# TASK 66
# TASK 67
# TASK 68
# TASK 69
# TASK 70
# TASK 71
# TASK 72
# TASK 73
# TASK 74
# TASK 75
# TASK 76
# TASK 77
# TASK 78
# TASK 79
# TASK 80
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2210 - accuracy: 0.3837
# Epoch 2/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2059 - accuracy: 0.7402
# Epoch 3/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1851 - accuracy: 0.7616
# Epoch 4/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1544 - accuracy: 0.7686
# Epoch 5/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1188 - accuracy: 0.7767
# Epoch 6/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0911 - accuracy: 0.7959
# Epoch 7/100
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0809 - accuracy: 0.7959
# Epoch 8/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0820 - accuracy: 0.7959
# Epoch 9/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0853 - accuracy: 0.7959
# Epoch 10/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0872 - accuracy: 0.7959
# Epoch 11/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0879 - accuracy: 0.7873
# TASK 81
# TASK 82
# TASK 83
# TASK 84
# TASK 85
# TASK 86
# TASK 87
# TASK 88
# TASK 89
# TASK 90
# TASK 91
# TASK 92
# TASK 93
# TASK 94
# TASK 95
# TASK 96
# TASK 97
# TASK 98
# TASK 99
# TASK 100
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.2424 - accuracy: 0.4972
# Epoch 2/100
# 1/1 [==============================] - 1s 916ms/step - loss: 0.2412 - accuracy: 0.7408
# Epoch 3/100
# 1/1 [==============================] - 1s 902ms/step - loss: 0.2384 - accuracy: 0.7832
# Epoch 4/100
# 1/1 [==============================] - 1s 996ms/step - loss: 0.2304 - accuracy: 0.8245
# Epoch 5/100
# 1/1 [==============================] - 1s 893ms/step - loss: 0.2107 - accuracy: 0.8563
# Epoch 6/100
# 1/1 [==============================] - 1s 987ms/step - loss: 0.1709 - accuracy: 0.8810
# Epoch 7/100
# 1/1 [==============================] - 1s 935ms/step - loss: 0.1096 - accuracy: 0.9078
# Epoch 8/100
# 1/1 [==============================] - 1s 923ms/step - loss: 0.0478 - accuracy: 0.9180
# Epoch 9/100
# 1/1 [==============================] - 1s 940ms/step - loss: 0.0139 - accuracy: 0.9297
# Epoch 10/100
# 1/1 [==============================] - 1s 899ms/step - loss: 0.0034 - accuracy: 0.9309
# Epoch 11/100
# 1/1 [==============================] - 1s 943ms/step - loss: 0.0014 - accuracy: 0.9309
# Epoch 12/100
# 1/1 [==============================] - 1s 901ms/step - loss: 0.0013 - accuracy: 0.9309
# Epoch 13/100
# 1/1 [==============================] - 1s 919ms/step - loss: 0.0013 - accuracy: 0.9309
# Epoch 14/100
# 1/1 [==============================] - 1s 910ms/step - loss: 0.0013 - accuracy: 0.9309
# Epoch 15/100
# 1/1 [==============================] - 1s 942ms/step - loss: 0.0013 - accuracy: 0.9309
# TASK 101
# TASK 102
# TASK 103
# TASK 104
# TASK 105
# TASK 106
# TASK 107
# TASK 108
# TASK 109
# TASK 110
# TASK 111
# TASK 112
# TASK 113
# TASK 114
# TASK 115
# TASK 116
# TASK 117
# TASK 118
# TASK 119
# TASK 120
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2433 - accuracy: 0.4881
# Epoch 2/100
# 1/1 [==============================] - 0s 220ms/step - loss: 0.2364 - accuracy: 0.8100
# Epoch 3/100
# 1/1 [==============================] - 0s 270ms/step - loss: 0.2212 - accuracy: 0.8747
# Epoch 4/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.1885 - accuracy: 0.9136
# Epoch 5/100
# 1/1 [==============================] - 0s 298ms/step - loss: 0.1358 - accuracy: 0.9393
# Epoch 6/100
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0755 - accuracy: 0.9487
# Epoch 7/100
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0303 - accuracy: 0.9606
# Epoch 8/100
# 1/1 [==============================] - 0s 227ms/step - loss: 0.0089 - accuracy: 0.9665
# Epoch 9/100
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0032 - accuracy: 0.9665
# Epoch 10/100
# 1/1 [==============================] - 0s 298ms/step - loss: 0.0027 - accuracy: 0.9665
# Epoch 11/100
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0027 - accuracy: 0.9665
# Epoch 12/100
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0026 - accuracy: 0.9665
# Epoch 13/100
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0027 - accuracy: 0.9665
# TASK 121
# TASK 122
# TASK 123
# TASK 124
# TASK 125
# TASK 126
# TASK 127
# TASK 128
# TASK 129
# TASK 130
# TASK 131
# TASK 132
# TASK 133
# TASK 134
# TASK 135
# TASK 136
# TASK 137
# TASK 138
# TASK 139
# TASK 140
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2395 - accuracy: 0.4781
# Epoch 2/100
# 1/1 [==============================] - 1s 656ms/step - loss: 0.2380 - accuracy: 0.7677
# Epoch 3/100
# 1/1 [==============================] - 1s 596ms/step - loss: 0.2354 - accuracy: 0.8248
# Epoch 4/100
# 1/1 [==============================] - 1s 633ms/step - loss: 0.2292 - accuracy: 0.8561
# Epoch 5/100
# 1/1 [==============================] - 1s 630ms/step - loss: 0.2149 - accuracy: 0.8827
# Epoch 6/100
# 1/1 [==============================] - 1s 630ms/step - loss: 0.1864 - accuracy: 0.9053
# Epoch 7/100
# 1/1 [==============================] - 1s 630ms/step - loss: 0.1397 - accuracy: 0.9286
# Epoch 8/100
# 1/1 [==============================] - 1s 637ms/step - loss: 0.0835 - accuracy: 0.9359
# Epoch 9/100
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0418 - accuracy: 0.9414
# Epoch 10/100
# 1/1 [==============================] - 1s 623ms/step - loss: 0.0250 - accuracy: 0.9414
# Epoch 11/100
# 1/1 [==============================] - 1s 621ms/step - loss: 0.0215 - accuracy: 0.9414
# Epoch 12/100
# 1/1 [==============================] - 1s 683ms/step - loss: 0.0215 - accuracy: 0.9414
# Epoch 13/100
# 1/1 [==============================] - 1s 667ms/step - loss: 0.0216 - accuracy: 0.9414
# Epoch 14/100
# 1/1 [==============================] - 1s 609ms/step - loss: 0.0217 - accuracy: 0.9414
# TASK 141
# TASK 142
# TASK 143
# TASK 144
# TASK 145
# TASK 146
# TASK 147
# TASK 148
# TASK 149
# TASK 150
# TASK 151
# TASK 152
# TASK 153
# TASK 154
# TASK 155
# TASK 156
# TASK 157
# TASK 158
# TASK 159
# TASK 160
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.2375 - accuracy: 0.4654
# Epoch 2/100
# 1/1 [==============================] - 1s 835ms/step - loss: 0.2319 - accuracy: 0.7140
# Epoch 3/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2147 - accuracy: 0.7807
# Epoch 4/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1739 - accuracy: 0.8282
# Epoch 5/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1127 - accuracy: 0.8610
# Epoch 6/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0613 - accuracy: 0.8847
# Epoch 7/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0365 - accuracy: 0.9012
# Epoch 8/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0249 - accuracy: 0.9168
# Epoch 9/100
# 1/1 [==============================] - 1s 940ms/step - loss: 0.0187 - accuracy: 0.9266
# Epoch 10/100
# 1/1 [==============================] - 1s 950ms/step - loss: 0.0166 - accuracy: 0.9295
# Epoch 11/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0166 - accuracy: 0.9295
# Epoch 12/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0166 - accuracy: 0.9295
# Epoch 13/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0166 - accuracy: 0.9295
# Epoch 14/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0166 - accuracy: 0.9295
# Epoch 15/100
# 1/1 [==============================] - 1s 959ms/step - loss: 0.0166 - accuracy: 0.9295
# TASK 161
# TASK 162
# TASK 163
# TASK 164
# TASK 165
# TASK 166
# TASK 167
# TASK 168
# TASK 169
# TASK 170
# TASK 171
# TASK 172
# TASK 173
# TASK 174
# TASK 175
# TASK 176
# TASK 177
# TASK 178
# TASK 179
# TASK 180
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2129 - accuracy: 0.4498
# Epoch 2/100
# 1/1 [==============================] - 0s 116ms/step - loss: 0.2002 - accuracy: 0.7175
# Epoch 3/100
# 1/1 [==============================] - 0s 323ms/step - loss: 0.1804 - accuracy: 0.7390
# Epoch 4/100
# 1/1 [==============================] - 0s 252ms/step - loss: 0.1487 - accuracy: 0.7600
# Epoch 5/100
# 1/1 [==============================] - 0s 235ms/step - loss: 0.1111 - accuracy: 0.7908
# Epoch 6/100
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0837 - accuracy: 0.7915
# Epoch 7/100
# 1/1 [==============================] - 0s 229ms/step - loss: 0.0748 - accuracy: 0.7949
# Epoch 8/100
# 1/1 [==============================] - 0s 261ms/step - loss: 0.0748 - accuracy: 0.7987
# Epoch 9/100
# 1/1 [==============================] - 0s 238ms/step - loss: 0.0757 - accuracy: 0.8013
# Epoch 10/100
# 1/1 [==============================] - 0s 174ms/step - loss: 0.0751 - accuracy: 0.8013
# Epoch 11/100
# 1/1 [==============================] - 0s 339ms/step - loss: 0.0728 - accuracy: 0.7940
# Epoch 12/100
# 1/1 [==============================] - 0s 164ms/step - loss: 0.0712 - accuracy: 0.7919
# Epoch 13/100
# 1/1 [==============================] - 0s 209ms/step - loss: 0.0708 - accuracy: 0.7910
# Epoch 14/100
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0684 - accuracy: 0.7950
# TASK 181
# TASK 182
# TASK 183
# TASK 184
# TASK 185
# TASK 186
# TASK 187
# TASK 188
# TASK 189
# TASK 190
# TASK 191
# TASK 192
# TASK 193
# TASK 194
# TASK 195
# TASK 196
# TASK 197
# TASK 198
# TASK 199
# TASK 200
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2266 - accuracy: 0.4354
# Epoch 2/100
# 1/1 [==============================] - 0s 437ms/step - loss: 0.2185 - accuracy: 0.7848
# Epoch 3/100
# 1/1 [==============================] - 0s 380ms/step - loss: 0.2006 - accuracy: 0.8349
# Epoch 4/100
# 1/1 [==============================] - 0s 391ms/step - loss: 0.1649 - accuracy: 0.8474
# Epoch 5/100
# 1/1 [==============================] - 0s 413ms/step - loss: 0.1150 - accuracy: 0.8531
# Epoch 6/100
# 1/1 [==============================] - 0s 457ms/step - loss: 0.0679 - accuracy: 0.8650
# Epoch 7/100
# 1/1 [==============================] - 0s 348ms/step - loss: 0.0387 - accuracy: 0.8664
# Epoch 8/100
# 1/1 [==============================] - 0s 400ms/step - loss: 0.0285 - accuracy: 0.8668
# Epoch 9/100
# 1/1 [==============================] - 0s 361ms/step - loss: 0.0272 - accuracy: 0.8668
# Epoch 10/100
# 1/1 [==============================] - 0s 412ms/step - loss: 0.0275 - accuracy: 0.8668
# Epoch 11/100
# 1/1 [==============================] - 0s 394ms/step - loss: 0.0276 - accuracy: 0.8668
# Epoch 12/100
# 1/1 [==============================] - 0s 453ms/step - loss: 0.0277 - accuracy: 0.8668
# Epoch 13/100
# 1/1 [==============================] - 0s 363ms/step - loss: 0.0276 - accuracy: 0.8668
# TASK 201
# TASK 202
# TASK 203
# TASK 204
# TASK 205
# TASK 206
# TASK 207
# TASK 208
# TASK 209
# TASK 210
# TASK 211
# TASK 212
# TASK 213
# TASK 214
# TASK 215
# TASK 216
# TASK 217
# TASK 218
# TASK 219
# TASK 220
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.2394 - accuracy: 0.4456
# Epoch 2/100
# 1/1 [==============================] - 1s 592ms/step - loss: 0.2385 - accuracy: 0.7242
# Epoch 3/100
# 1/1 [==============================] - 1s 886ms/step - loss: 0.2370 - accuracy: 0.7627
# Epoch 4/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2339 - accuracy: 0.7963
# Epoch 5/100
# 1/1 [==============================] - 1s 867ms/step - loss: 0.2270 - accuracy: 0.8300
# Epoch 6/100
# 1/1 [==============================] - 1s 857ms/step - loss: 0.2125 - accuracy: 0.8693
# Epoch 7/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1848 - accuracy: 0.8964
# Epoch 8/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1401 - accuracy: 0.9201
# Epoch 9/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0846 - accuracy: 0.9337
# Epoch 10/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0394 - accuracy: 0.9381
# Epoch 11/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0178 - accuracy: 0.9448
# Epoch 12/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0109 - accuracy: 0.9491
# Epoch 13/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0090 - accuracy: 0.9510
# Epoch 14/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0087 - accuracy: 0.9510
# Epoch 15/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0087 - accuracy: 0.9510
# Epoch 16/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0087 - accuracy: 0.9510
# Epoch 17/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0087 - accuracy: 0.9510
# Epoch 18/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0087 - accuracy: 0.9510
# TASK 221
# TASK 222
# TASK 223
# TASK 224
# TASK 225
# TASK 226
# TASK 227
# TASK 228
# TASK 229
# TASK 230
# TASK 231
# TASK 232
# TASK 233
# TASK 234
# TASK 235
# TASK 236
# TASK 237
# TASK 238
# TASK 239
# TASK 240
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.2083 - accuracy: 0.3752
# Epoch 2/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1984 - accuracy: 0.8035
# Epoch 3/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1852 - accuracy: 0.8128
# Epoch 4/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1645 - accuracy: 0.8128
# Epoch 5/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1360 - accuracy: 0.8128
# Epoch 6/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1036 - accuracy: 0.8128
# Epoch 7/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0747 - accuracy: 0.8128
# Epoch 8/100
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0554 - accuracy: 0.8128
# TASK 241
# TASK 242
# TASK 243
# TASK 244
# TASK 245
# TASK 246
# TASK 247
# TASK 248
# TASK 249
# TASK 250
# TASK 251
# TASK 252
# TASK 253
# TASK 254
# TASK 255
# TASK 256
# TASK 257
# TASK 258
# TASK 259
# TASK 260
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2347 - accuracy: 0.3123
# Epoch 2/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.2227 - accuracy: 0.8835
# Epoch 3/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.2076 - accuracy: 0.8963
# Epoch 4/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1842 - accuracy: 0.8963
# Epoch 5/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1507 - accuracy: 0.8963
# Epoch 6/100
# 1/1 [==============================] - 0s 100ms/step - loss: 0.1089 - accuracy: 0.8963
# Epoch 7/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0668 - accuracy: 0.8963
# Epoch 8/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0344 - accuracy: 0.8963
# TASK 261
# TASK 262
# TASK 263
# TASK 264
# TASK 265
# TASK 266
# TASK 267
# TASK 268
# TASK 269
# TASK 270
# TASK 271
# TASK 272
# TASK 273
# TASK 274
# TASK 275
# TASK 276
# TASK 277
# TASK 278
# TASK 279
# TASK 280
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2117 - accuracy: 0.3746
# Epoch 2/100
# 1/1 [==============================] - 0s 413ms/step - loss: 0.2078 - accuracy: 0.6569
# Epoch 3/100
# 1/1 [==============================] - 0s 418ms/step - loss: 0.1997 - accuracy: 0.6906
# Epoch 4/100
# 1/1 [==============================] - 0s 471ms/step - loss: 0.1815 - accuracy: 0.7153
# Epoch 5/100
# 1/1 [==============================] - 0s 485ms/step - loss: 0.1479 - accuracy: 0.7366
# Epoch 6/100
# 1/1 [==============================] - 0s 478ms/step - loss: 0.1001 - accuracy: 0.7510
# Epoch 7/100
# 1/1 [==============================] - 0s 407ms/step - loss: 0.0542 - accuracy: 0.7616
# Epoch 8/100
# 1/1 [==============================] - 0s 442ms/step - loss: 0.0300 - accuracy: 0.7622
# Epoch 9/100
# 1/1 [==============================] - 0s 402ms/step - loss: 0.0235 - accuracy: 0.7660
# Epoch 10/100
# 1/1 [==============================] - 1s 518ms/step - loss: 0.0233 - accuracy: 0.7660
# Epoch 11/100
# 1/1 [==============================] - 0s 405ms/step - loss: 0.0240 - accuracy: 0.7660
# Epoch 12/100
# 1/1 [==============================] - 0s 454ms/step - loss: 0.0244 - accuracy: 0.7660
# Epoch 13/100
# 1/1 [==============================] - 0s 440ms/step - loss: 0.0245 - accuracy: 0.7660
# Epoch 14/100
# 1/1 [==============================] - 0s 467ms/step - loss: 0.0245 - accuracy: 0.7660
# TASK 281
# TASK 282
# TASK 283
# TASK 284
# TASK 285
# TASK 286
# TASK 287
# TASK 288
# TASK 289
# TASK 290
# TASK 291
# TASK 292
# TASK 293
# TASK 294
# TASK 295
# TASK 296
# TASK 297
# TASK 298
# TASK 299
# TASK 300
# Epoch 1/100
# 1/1 [==============================] - 1s 871ms/step - loss: 0.2285 - accuracy: 0.4230
# Epoch 2/100
# 1/1 [==============================] - 0s 166ms/step - loss: 0.2222 - accuracy: 0.7485
# Epoch 3/100
# 1/1 [==============================] - 0s 279ms/step - loss: 0.2112 - accuracy: 0.8237
# Epoch 4/100
# 1/1 [==============================] - 0s 287ms/step - loss: 0.1901 - accuracy: 0.8477
# Epoch 5/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.1569 - accuracy: 0.8620
# Epoch 6/100
# 1/1 [==============================] - 0s 322ms/step - loss: 0.1164 - accuracy: 0.8688
# Epoch 7/100
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0786 - accuracy: 0.8743
# Epoch 8/100
# 1/1 [==============================] - 0s 251ms/step - loss: 0.0516 - accuracy: 0.8840
# Epoch 9/100
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0378 - accuracy: 0.8840
# Epoch 10/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0333 - accuracy: 0.8840
# Epoch 11/100
# 1/1 [==============================] - 0s 317ms/step - loss: 0.0321 - accuracy: 0.8840
# Epoch 12/100
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0314 - accuracy: 0.8815
# Epoch 13/100
# 1/1 [==============================] - 0s 324ms/step - loss: 0.0317 - accuracy: 0.8765
# TASK 301
# TASK 302
# TASK 303
# TASK 304
# TASK 305
# TASK 306
# TASK 307
# TASK 308
# TASK 309
# TASK 310
# TASK 311
# TASK 312
# TASK 313
# TASK 314
# TASK 315
# TASK 316
# TASK 317
# TASK 318
# TASK 319
# TASK 320
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2368 - accuracy: 0.4538
# Epoch 2/100
# 1/1 [==============================] - 1s 560ms/step - loss: 0.2291 - accuracy: 0.7686
# Epoch 3/100
# 1/1 [==============================] - 1s 509ms/step - loss: 0.2136 - accuracy: 0.8343
# Epoch 4/100
# 1/1 [==============================] - 1s 719ms/step - loss: 0.1809 - accuracy: 0.8742
# Epoch 5/100
# 1/1 [==============================] - 1s 557ms/step - loss: 0.1281 - accuracy: 0.8934
# Epoch 6/100
# 1/1 [==============================] - 1s 514ms/step - loss: 0.0699 - accuracy: 0.9182
# Epoch 7/100
# 1/1 [==============================] - 1s 529ms/step - loss: 0.0313 - accuracy: 0.9240
# Epoch 8/100
# 1/1 [==============================] - 1s 509ms/step - loss: 0.0152 - accuracy: 0.9261
# Epoch 9/100
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0104 - accuracy: 0.9317
# Epoch 10/100
# 1/1 [==============================] - 1s 807ms/step - loss: 0.0091 - accuracy: 0.9316
# Epoch 11/100
# 1/1 [==============================] - 1s 657ms/step - loss: 0.0079 - accuracy: 0.9311
# Epoch 12/100
# 1/1 [==============================] - 1s 719ms/step - loss: 0.0092 - accuracy: 0.9259
# Epoch 13/100
# 1/1 [==============================] - 1s 672ms/step - loss: 0.0086 - accuracy: 0.9264
# Epoch 14/100
# 1/1 [==============================] - 1s 834ms/step - loss: 0.0077 - accuracy: 0.9309
# TASK 321
# TASK 322
# TASK 323
# TASK 324
# TASK 325
# TASK 326
# TASK 327
# TASK 328
# TASK 329
# TASK 330
# TASK 331
# TASK 332
# TASK 333
# TASK 334
# TASK 335
# TASK 336
# TASK 337
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-366b5ab95903> in <module>
#      47     pred_train = (decoded_imgs_train.reshape(outp_shape[0:2]))*10
#      48
# ---> 49     encoded_imgs_test = base_model.encoder(Xs_test_aug[idx][:1]).numpy()
#      50     decoded_imgs_test = base_model.decoder(encoded_imgs_test).numpy()
#      51
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     976     if any(isinstance(x, (
#     977         np_arrays.ndarray, np.ndarray, float, int)) for x in input_list):
# --> 978       inputs = nest.map_structure(_convert_numpy_or_python_types, inputs)
#     979       input_list = nest.flatten(inputs)
#     980
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in _convert_numpy_or_python_types(x)
#    3226 def _convert_numpy_or_python_types(x):
#    3227   if isinstance(x, (np_arrays.ndarray, np.ndarray, float, int)):
# -> 3228     return ops.convert_to_tensor_v2_with_dispatch(x)
#    3229   return x
#    3230
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1429   """
#    1430   return convert_to_tensor_v2(
# -> 1431       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#    1432
#    1433
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1439       name=name,
#    1440       preferred_dtype=dtype_hint,
# -> 1441       as_ref=False)
#    1442
#    1443
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     263   """
#     264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 265                         allow_broadcast=True)
#     266
#     267
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# /opt/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type numpy.ndarray).

# %%
base_model.encoder.summary()

# %%
base_model.decoder.summary()

# %%
Xs_test_aug[47][:1].shape
# Out:
# (1, 8, 8, 1)

# %%
len(pred_train_li)
# Out:
# 337

# %%
len(Xs_test_aug[337])
# Out:
# 2

# %%
Xs_test_aug[337][1].shape

# %%
Xs_test_aug[337][1].shape
# Out:
# (25, 25, 1)

# %% [markdown]
# ## PLOT PREDICTIONS

# %%
x=40 #### choose which one to display in all below

# %%
cmap = colors.ListedColormap(
            ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
             '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
norm = colors.Normalize(vmin=0, vmax=9)
fig, ax = plt.subplots(1, 5, figsize=(20,20))
for idx in range(x,x+1,20):
  
    ax[0].imshow((Xs_train_aug[idx][0])*10, cmap=cmap, norm=norm)
    ax[0].set_title(f'Train Input {idx}')
    ax[1].imshow((ys_train_aug[idx][0])*10, cmap=cmap, norm=norm)
    ax[1].set_title(f'Train output {idx}')
    ax[2].imshow((pred_train_li[idx]), cmap=cmap, norm=norm)
    ax[2].set_title(f'Train Prediction {idx}')       
    ax[3].imshow((Xs_test_aug[idx][0])*10, cmap=cmap, norm=norm)
    ax[3].set_title(f'Test Input {idx}')
    ax[4].imshow(pred_test_li[idx], cmap=cmap, norm=norm)
    ax[4].set_title(f'Test Prediction {idx}')

# %%
cmap = colors.ListedColormap(
            ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
             '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
norm = colors.Normalize(vmin=0, vmax=9)
fig, ax = plt.subplots(15, 10, figsize=(25,25))
for i in range(15):
    for j in range(10):
        idx = i+j+3*i
        
        ax[i,j].imshow((Xs_train_aug[x][idx])*10, cmap=cmap, norm=norm)
        ax[i,j].set_title(f'Train Input {idx}')

# %%
cmap = colors.ListedColormap(
            ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
             '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
norm = colors.Normalize(vmin=0, vmax=9)
fig, ax = plt.subplots(1, 3, figsize=(25,25))
for i in range(1):
    for j in range(3):
        idx = j
        
        ax[j].imshow((Xs_train_aug[x][idx])*10, cmap=cmap, norm=norm)
        ax[j].set_title(f'Train Input {idx}')
